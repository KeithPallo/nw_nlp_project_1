# %%
# Out:
# Loading file...
# Number of tweets: 174643
# Parsing tweets for relevant information...(this might take awhile)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-08ad5b42ea77> in <module>()
#     194 CALL THE MAIN FUNCTION TO RUN THE PROGRAM.
#     195 '''
# --> 196 main()
#
# <ipython-input-4-08ad5b42ea77> in main()
#     166
#     167         print('Parsing tweets for relevant information...(this might take awhile)')
# --> 168         results = get_winners(data)
#     169         awards = get_awards()
#     170
#
# <ipython-input-4-08ad5b42ea77> in get_winners(tweets)
#      51
#      52 def get_winners(tweets):
# ---> 53         presenters = AwardCounter()
#      54         winners = AwardCounter()
#      55         presenters_result = {}
#
# NameError: name 'AwardCounter' is not defined

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import nltk
from nltk import untag
from nltk.collocations import *;
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.probability import FreqDist
from nltk.tokenize import TweetTokenizer
from nltk import ngrams

from textblob import TextBlob

# %%
data_13 = pd.read_json('../gg2013.json')
data_13 = pd.DataFrame(data_13)

# %%
data_15 = pd.read_json('../gg2015.json')
data_15 = pd.DataFrame(data_15)

# %%
data_13
# data_13['text'][4]
# Out:
#                         id                                               text  \
# 0       290620657987887104             JLo's dress! #eredcarpet #GoldenGlobes
# 1       290620657887219713  What's making Sofia Vergara's boobs stay like ...
# 2       290620657828524032  RT @FabSugar: Kerry Washington is EVERYTHING. ...
# 3       290620657799159809     Anne Hathaway has got me living. #GoldenGlobes
# 4       290620657778188288  Jennifer Lopez's lace dress? Thoughts? #Golden...
# 5       290620657719455745  Podrán criticar a #Adele de su moda y su maniq...
# 6       290620657715273728                           US, Weakly #GoldenGlobes
# 7       290620657715253248  RT @BillMc7: "Wait. What's that smell?!" (ever...
# 8       290620657706872832        Hugh Jackman is so awesome!!! #goldenglobes
# 9       290620657560084480  It was awkward. RT @hollywoodhwife: They cut t...
# 10      290620657551671297                    hellen mirren *O* #goldenglobes
# 11      290620657526505475  Jennifer Lopez's dress is jaw droppingly amazi...
# 12      290620657316794368  Jessica Alba is absolutely flawless, omg❤ #red...
# 13      290620657274855424  Werk @kerrywashington Stunning!!! #GoldenGlobe...
# 14      290620657232908289  Sofia Vergara este bueno ella es Sofia Vergara...
# 15      290620657178378240  “@amsdiva: Kate Hudson's smile is as infectiou...
# 16      290620657170014208  Why did I just flip out? Because one of the be...
# 17      290620657161613313  What's up with this I'm wearing lace/a tattoo ...
# 18      290620657157406720  Hugh Jackman is looking a bit too bronzed. Ora...
# 19      290620656972869632  RT @AudrinaPatridge: @SofiaVergara is my favor...
# 20      290620656951914497  Who's that teenage boy standing behind Jessica...
# 21      290620656943509505  Poor Al Roker. He is just too easy a target. #...
# 22      290620656834453504  #SofiaVergara is gorgeous. Loved her dress.  #...
# 23      290620656683462656  mi programa de domingo a la noche va a ser ver...
# 24      290620656461168640  RT @Chrishell7: If all these beautiful actress...
# 25      290620656456982528  My Baby Leo DiCaprio.aaaaaah estava esperando ...
# 26      290620656394051584      Kerry Washington is perfect!!!! #GoldenGlobes
# 27      290620656314351616  It should be illegal to look as good as Ewan M...
# 28      290620656276631552  .@kerrywashington's nude &amp; sheer = yes. Je...
# 29      290620656209498112  Ok the moms are shutting it down tonight! Just...
# ...                    ...                                                ...
# 174613  290675890113880064  'Girls' Night: HBO Series Nabs Two Golden Glob...
# 174614  290675890013216769  Golden Globes 2013: What the Stars Wore! http:...
# 174615  290675889849643008  Love how Meryl Streep doesn't go to the Golden...
# 174616  290675889581207555  It will be an award in &amp; of itself if I ca...
# 174617  290675889107238912  Latest: 'Girls' Night: HBO Series Nabs Two Gol...
# 174618  290675888981434368  Golden Globes 2013: What the Stars Wore! http:...
# 174619  290675888830443520  NYTimes: 'Argo,' 'Les Miz,' Homeland' and 'Gir...
# 174620  290675888729780224  RT @theblcklst: Black List scripts have now wo...
# 174621  290675888700407808  Jodie Foster Officially Comes Out as Gay in Mo...
# 174622  290675888620699650  #UCWRadio  'Argo,' 'Les Mis' win at Golden Glo...
# 174623  290675892714352640  RT @HuffPostTV: "We're going home with Jodie F...
# 174624  290675892630462464  Soooo I'll be seeing "Argo" and "Les Miserable...
# 174625  290675892261359616  RT @brian_hanson: RED / OUR MOVIE REALLY SUUUU...
# 174626  290675892215242753  All of the TV award winners at the #GoldenGlob...
# 174627  290675891070173185  See your "Wonderful World of #Downton" t-shirt...
# 174628  290675890889826304  RT @RobbieSherwood: Caught the second half of ...
# 174629  290675890885623808  RT @easyweezie: The #awkward moment when #Tayl...
# 174630  290675890818527232  @goldenglobes \n\nSilver Linings Superior to L...
# 174631  290675890482970624  RT @NickYoussef: Lea Michele's spray tan is bo...
# 174632  290675890445225984  RT @piersmorgan: Great #goldenglobes - amusing...
# 174633  290675890227118080  kamprets bener aja, server situs donlot pelem ...
# 174634  290675890189381633  RT @goldenglobes: Best Television Series Actor...
# 174635  290675889837051904  "@nbcsnl: Just thinking ahead, but like should...
# 174636  290675889736384513  thank god anne hathaway and hugh jackman won f...
# 174637  290675889556041728  Ben Affleck celebrates his win backstage. #gol...
# 174638  290675889379876864  RT @authorViviAnna: I was sad that Mandy Patin...
# 174639  290675889128230914  RT @_ItzelMartinez_: Jennifer Lawrence aceptan...
# 174640  290675893024747523  Golden Globes, lots of fashion messes...but gl...
# 174641  290675888763314178  Did they have mug shots at the golden globes?!...
# 174642  290675893494484992  Says @BenAffleck: "I also didn't get the Actin...
#
#               timestamp_ms                                               user
# 0      2013-01-14 00:45:38      {'screen_name': 'Dozaaa_xo', 'id': 557374298}
# 1      2013-01-14 00:45:38    {'screen_name': 'theAmberShow', 'id': 14648726}
# 2      2013-01-14 00:45:38        {'screen_name': 'SweetyPW', 'id': 35498686}
# 3      2013-01-14 00:45:38  {'screen_name': '_NicoleEdwards', 'id': 144430...
# 4      2013-01-14 00:45:38  {'screen_name': 'lolaogunnaike', 'id': 134953223}
# 5      2013-01-14 00:45:38     {'screen_name': 'SabyOnford', 'id': 404554221}
# 6      2013-01-14 00:45:38  {'screen_name': 'alejandraoleary', 'id': 45748...
# 7      2013-01-14 00:45:38    {'screen_name': 'xtinavickers', 'id': 92139052}
# 8      2013-01-14 00:45:38        {'screen_name': 'Boaz_173', 'id': 31504713}
# 9      2013-01-14 00:45:38    {'screen_name': 'KateSpencer1', 'id': 21571382}
# 10     2013-01-14 00:45:38     {'screen_name': 'ItsBlerena', 'id': 359715651}
# 11     2013-01-14 00:45:38  {'screen_name': 'noirlashlounge', 'id': 21706403}
# 12     2013-01-14 00:45:38    {'screen_name': '_VickiAnne_', 'id': 371344639}
# 13     2013-01-14 00:45:38   {'screen_name': 'LisaFranceCNN', 'id': 52752875}
# 14     2013-01-14 00:45:38   {'screen_name': 'OrsiniRobert', 'id': 750218220}
# 15     2013-01-14 00:45:38     {'screen_name': 'PhilToochi', 'id': 285620930}
# 16     2013-01-14 00:45:38  {'screen_name': 'mo_JOE_marino', 'id': 286809109}
# 17     2013-01-14 00:45:38   {'screen_name': 'RachelTRAFFIC', 'id': 30718025}
# 18     2013-01-14 00:45:38        {'screen_name': 'NolaBeth', 'id': 18909973}
# 19     2013-01-14 00:45:38  {'screen_name': 'melissapenagos', 'id': 178463...
# 20     2013-01-14 00:45:38      {'screen_name': 'mylifeslap', 'id': 19845495}
# 21     2013-01-14 00:45:38    {'screen_name': 'ronaldfsuber', 'id': 60428693}
# 22     2013-01-14 00:45:38     {'screen_name': 'ErickaWoode', 'id': 15087056}
# 23     2013-01-14 00:45:38      {'screen_name': 'paligomez', 'id': 137765371}
# 24     2013-01-14 00:45:38     {'screen_name': 'panthergrrl', 'id': 14095512}
# 25     2013-01-14 00:45:38         {'screen_name': 'TVDPLL', 'id': 175201062}
# 26     2013-01-14 00:45:38  {'screen_name': 'FringePhalanges', 'id': 32439...
# 27     2013-01-14 00:45:38   {'screen_name': 'ACaryGrantFan', 'id': 71066469}
# 28     2013-01-14 00:45:38  {'screen_name': 'OnScreenStyle', 'id': 818609779}
# 29     2013-01-14 00:45:38      {'screen_name': 'BabyShopa', 'id': 275043891}
# ...                    ...                                                ...
# 174613 2013-01-14 04:25:07  {'screen_name': 'jimmylandaburu', 'id': 83610910}
# 174614 2013-01-14 04:25:07  {'screen_name': 'CelebrityPoints', 'id': 34495...
# 174615 2013-01-14 04:25:07      {'screen_name': 'faithkelly', 'id': 24090508}
# 174616 2013-01-14 04:25:07   {'screen_name': 'AmourColette', 'id': 177307264}
# 174617 2013-01-14 04:25:07  {'screen_name': 'putupthesound', 'id': 705579864}
# 174618 2013-01-14 04:25:07  {'screen_name': 'GoCelebrityUS', 'id': 1013430...
# 174619 2013-01-14 04:25:07     {'screen_name': 'Geancarlla', 'id': 454212768}
# 174620 2013-01-14 04:25:07       {'screen_name': 'andrecole', 'id': 15146681}
# 174621 2013-01-14 04:25:07  {'screen_name': 'CelebrityPoints', 'id': 34495...
# 174622 2013-01-14 04:25:07         {'screen_name': 'UCWNews', 'id': 55232967}
# 174623 2013-01-14 04:25:07      {'screen_name': 'NerdHeather', 'id': 7784792}
# 174624 2013-01-14 04:25:07  {'screen_name': 'HolliGolightly_', 'id': 16557...
# 174625 2013-01-14 04:25:07     {'screen_name': 'LaceAlayna', 'id': 255256892}
# 174626 2013-01-14 04:25:07       {'screen_name': 'DayWayLo', 'id': 464905414}
# 174627 2013-01-14 04:25:07   {'screen_name': 'DowntonTees1', 'id': 838451754}
# 174628 2013-01-14 04:25:07   {'screen_name': 'Tweetontweets', 'id': 20276211}
# 174629 2013-01-14 04:25:07         {'screen_name': 'kel3463', 'id': 80878209}
# 174630 2013-01-14 04:25:07         {'screen_name': 'Imused', 'id': 294324510}
# 174631 2013-01-14 04:25:07      {'screen_name': 'bumblebme', 'id': 328839069}
# 174632 2013-01-14 04:25:07        {'screen_name': 'NrePace', 'id': 298974112}
# 174633 2013-01-14 04:25:07     {'screen_name': 'constantane', 'id': 57517177}
# 174634 2013-01-14 04:25:07  {'screen_name': 'manuelaferri5', 'id': 151819770}
# 174635 2013-01-14 04:25:07      {'screen_name': 'NickAspel', 'id': 291493551}
# 174636 2013-01-14 04:25:07  {'screen_name': 'victoria_pillar', 'id': 20588...
# 174637 2013-01-14 04:25:07   {'screen_name': 'Mer_Contreras', 'id': 35919432}
# 174638 2013-01-14 04:25:07        {'screen_name': 'dana1204', 'id': 18091543}
# 174639 2013-01-14 04:25:07  {'screen_name': 'IamTrisEverdeen', 'id': 55126...
# 174640 2013-01-14 04:25:08   {'screen_name': 'Dpharmakis23', 'id': 852045842}
# 174641 2013-01-14 04:25:08  {'screen_name': 'reynaramirez22', 'id': 22732662}
# 174642 2013-01-14 04:25:08    {'screen_name': 'goldenglobes', 'id': 18667907}
#
# [174643 rows x 4 columns]

# %%
test1 = 'woiwajer beautiful wonderful huzzah'
test2 = 'evil perfect nice good happy yay congratulations baby'

# %%
# BEST DRESSED:
#     SENTIMENT ANALYSIS = +
#     &
#     "DRESS" "LOOK" "FASION"+ BIGRAM OF ACTRESS' NAME

#     Check 1 person & no kb

def bestDressed():
    None

# %%
# WORST/CONTROVERSIAL DRESSED:
#     SENTIMENT ANALYSIS = -
#     &
#     "DRESS" + BIGRAM OF ACTRESS' NAME

def worstDressed():
    None

# %%
# BEST COUPLE:
#     SENTIMENT ANALYSIS = +
#     &
#     BIGRAM OF ACTRESS + BIGRAM OF ACTOR'S NAME

def bestCouple():
    None

# %%
# BAD COUPLE:
#     SENTIMENT ANALYSIS = -
#     &
#     BIGRAM OF ACTRESS + BIGRAM OF ACTOR'S NAME

def worstCouple():
    None

# %%
# JOKE:
#     SENTIMENT ANALYSIS = +
#     &
#     WORDS LIKE "FUNNY" "DYING" "DEAD" "LAUGHING" "LOL" ETC.
#     &
#     BIGRAM OF ACTOR/ACTRESS' NAME

def jokster():
    None

# %%
# PARTIES:
#     SENTIMENT ANALYSIS. = +
#     &
#     MOST USE OF BIGRAM OF ACTOR/ACTRESS' NAME
#     &
#     ALONG WITH "AFTERPARTY" OR RELATED WORDS

def theAfterparty():
    None

# %%
# ANIMAL:
#     MENTIONS OF ANIMALS?

def theyBroughtAPuppy():
    None

# %%
# UNDERDOG (WHO SHOULD HAVE WON):
#     SENTIMENT ANALYSIS = -
#         &
#     BEST WINNER OF AWARD (INCL. MOVIE & DIRECTOR & ACTOR/ACTRESS)
#     WHILE COMPARING W/
#     &
#     SENTIMENT ANALYSIS = +
#         &
#     BEST OF NOMINEES

def underDog():
    None

# %%
# DRINKS (WHO'S BEEN DRINKING TOO MUCH):
#     DRINK NAME
#     &
#     BIGRAM OF ACTOR/ACTRESS' NAME

def drunkStories():
    None

# %%
# FAMOUS PEOPLE:
#     GREATEST FREQ OF BIGRAM MENTIONED
#     &
#     NOT AN ACTOR/ACTRESS/DIRECTOR IN THE KB

def doesntBelong():
    None

# %%
# BAD/CONTROVERSIAL HOST:
#     SENTIMENT ANALYSIS = -
#     &
#     GREATEST FREQ OF BIGRAM MENTIONED RELATED TO HOST

def worstHost():
    None

# %%
# PLOT SENTIMENT ANALYSIS W/ ACTORS/ACTRESSES FROM GOOD TO BAD, FREQUENCY FROM 0 TO + !!

def sentiDist():
    None

# %%
# HIGHEST NOMINATION TO WIN RATIO AMONG WINNERS & NOMINEES?

def lossRatio():
    None
