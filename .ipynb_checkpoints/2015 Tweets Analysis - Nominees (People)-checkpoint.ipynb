# %%
import pandas as pd
import numpy as np

import nltk
from nltk.probability import FreqDist
from nltk.tokenize import TweetTokenizer
from nltk.corpus import stopwords
from stop_words import get_stop_words

import string
import re
from collections import Counter
from collections import OrderedDict
import unidecode
import requests
import json
from pprint import pprint

# %%
def main_exec(kb_p,kb_m):
    """
    Main execution file - how you run the program
    Itype: kb_p and kb_m are sets for our built KB's
    """
    
    # Call host search function
    # // To Do // - Insert function call (should write to JSON / return a variable to write later )
    
    # Call award entity recognition function
    # // To Do // - Insert function call (should write to JSON / return a variable to write later)
    
    # Set a variable to the hardcoded list
    hardcoded = GG_OFFICIAL_AWARDS
    
    # Segment out awards award categories
    people_awards, media_awards = seperateAwards(hardcoded)
    
    
    ## Functions below need to return a dictionary with following structure
    ## Key 1: Award Name, Value: Dictionary
    ## Key 2: [ Nominees, Winners, Presenters] 
    
    
    # Call people award search function - winner, nominee, presenter (potentially swap last two)
    ## // To DO // - Insert function call (only write to easy_comp now)
    
    
    # Call people award search function - winner, nominee, presenter (potentially swap last two)
    ## // To DO // - Insert function call ( only write to easy_comp now)
    
    
    # Merge dictionaries from two above functions
    # Return single dict for easy_comp

# %%
with open('gg2015answers.json') as f:
    answers = json.load(f)
    
true_dict = answers['award_data'] # use this for true dict in the below function

# %%
data = pd.read_json('../gg2015.json')
data = pd.DataFrame(data)

# %%
data = data['text'].values.tolist()

# %%
#print(data[:10])

# %%
people = set()

# %%
url = 'https://query.wikidata.org/sparql'

# %%
query = """
# ALL PERSONS required for awards
SELECT DISTINCT ?person ?personLabel WHERE {
# FIRST: uncomment occupation:
  # ?person wdt:P31 wd:Q5;
           wdt:P106/wdt:P279* wd:Q2526255; #uncomment for     FILM director (no award for TV director)
  FILTER NOT EXISTS { ?person wdt:P570 ?date. } #person is alive
  
# SECOND: uncomment gender if applicable (for actor/actress):
#          wdt:P21 wd:Q6581097;    #male
#          wdt:P21 wd:Q6581072;    #female
  SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
}
"""
r = requests.get(url, params = {'format': 'json', 'query': query})
kb = r.json()
for item in kb['results']['bindings']:
    people.add(unidecode.unidecode(item['personLabel']['value']))

# %%
query = """
# ALL PERSONS required for awards
SELECT DISTINCT ?person ?personLabel WHERE {
# FIRST: uncomment occupation:
  # ?person wdt:P31 wd:Q5;
           wdt:P106/wdt:P279* wd:Q10800557; #uncomment for    FILM actor (don't just use actor)
  FILTER NOT EXISTS { ?person wdt:P570 ?date. } #person is alive
  
# SECOND: uncomment gender if applicable (for actor/actress):
#          wdt:P21 wd:Q6581097;    #male
#          wdt:P21 wd:Q6581072;    #female
  SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
}
"""
r1 = requests.get(url, params = {'format': 'json', 'query': query})
kb1 = r1.json()
for item in kb1['results']['bindings']:
    people.add(unidecode.unidecode(item['personLabel']['value']))

# %%
query = """
# ALL PERSONS required for awards
SELECT DISTINCT ?person ?personLabel WHERE {
# FIRST: uncomment occupation:
  # ?person wdt:P31 wd:Q5;
           wdt:P106/wdt:P279* wd:Q10798782; #uncomment for    TV actor (don't just use actor)
  FILTER NOT EXISTS { ?person wdt:P570 ?date. } #person is alive
  
# SECOND: uncomment gender if applicable (for actor/actress):
#          wdt:P21 wd:Q6581097;    #male
#          wdt:P21 wd:Q6581072;    #female
  SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
}
"""
r = requests.get(url, params = {'format': 'json', 'query': query})
kb = r.json()
for item in kb['results']['bindings']:
    people.add(unidecode.unidecode(item['personLabel']['value']))

# %%
query = """
# ALL PERSONS required for awards
SELECT DISTINCT ?person ?personLabel WHERE {
# FIRST: uncomment occupation:
  # ?person wdt:P31 wd:Q5;
           wdt:P106/wdt:P279* wd:Q36834; #uncomment for       composer (cannot use songwriter)
  FILTER NOT EXISTS { ?person wdt:P570 ?date. } #person is alive
  
# SECOND: uncomment gender if applicable (for actor/actress):
#          wdt:P21 wd:Q6581097;    #male
#          wdt:P21 wd:Q6581072;    #female
  SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
}
"""
r = requests.get(url, params = {'format': 'json', 'query': query})
kb = r.json()
for item in kb['results']['bindings']:
    people.add(unidecode.unidecode(item['personLabel']['value']))

# %%
query = """
# ALL PERSONS required for awards
SELECT DISTINCT ?person ?personLabel WHERE {
# FIRST: uncomment occupation:
  # ?person wdt:P31 wd:Q5;
           wdt:P106/wdt:P279* wd:Q28389; #uncomment for       screenwriter
  FILTER NOT EXISTS { ?person wdt:P570 ?date. } #person is alive
  
# SECOND: uncomment gender if applicable (for actor/actress):
#          wdt:P21 wd:Q6581097;    #male
#          wdt:P21 wd:Q6581072;    #female
  SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
}
"""
r = requests.get(url, params = {'format': 'json', 'query': query})
kb = r.json()
for item in kb['results']['bindings']:
    people.add(unidecode.unidecode(item['personLabel']['value']))

# %%
#print(tv_actors)

# %%
f = open('english.txt', 'r')
stop_words = f.read().splitlines()
#print(stopwords)

# %%
OFFICIAL_AWARDS_1315 = ['cecil b. demille award',
                        'best performance by an actress in a motion picture - drama', 
                        'best performance by an actor in a motion picture - drama',
                        'best performance by an actress in a motion picture - comedy or musical', 
                        'best performance by an actor in a motion picture - comedy or musical',
                        'best performance by an actress in a supporting role in a motion picture', 
                        'best performance by an actor in a supporting role in a motion picture', 
                        'best director - motion picture', 
                        'best screenplay - motion picture', 
                        'best original score - motion picture',
                        'best performance by an actress in a television series - drama', 
                        'best performance by an actor in a television series - drama',
                        'best performance by an actress in a television series - comedy or musical', 
                        'best performance by an actor in a television series - comedy or musical', 
                        'best performance by an actress in a mini-series or motion picture made for television', 
                        'best performance by an actor in a mini-series or motion picture made for television', 
                        'best performance by an actress in a supporting role in a series, mini-series or motion picture made for television', 
                        'best performance by an actor in a supporting role in a series, mini-series or motion picture made for television']

# %%
def parseAward(award):
    award = re.split('\W+', award)
    award = [i for i in award if i not in stop_words]
    award = list(set(award))
    return award

# %%
def getCategoriesDict():
    categories_dict = dict()
    for a in OFFICIAL_AWARDS_1315:
        terms = parseAward(a)
        categories_dict[a] = terms

    return categories_dict

# %%
categories_dict = getCategoriesDict()

# %%
categories_dict
# Out:
# {'cecil b. demille award': ['demille', 'cecil', 'award'],
#  'best performance by an actress in a motion picture - drama': ['performance',
#   'drama',
#   'picture',
#   'actress',
#   'motion'],
#  'best performance by an actor in a motion picture - drama': ['actor',
#   'performance',
#   'drama',
#   'picture',
#   'motion'],
#  'best performance by an actress in a motion picture - comedy or musical': ['performance',
#   'picture',
#   'actress',
#   'musical',
#   'motion',
#   'comedy'],
#  'best performance by an actor in a motion picture - comedy or musical': ['actor',
#   'performance',
#   'picture',
#   'musical',
#   'motion',
#   'comedy'],
#  'best performance by an actress in a supporting role in a motion picture': ['supporting',
#   'performance',
#   'motion',
#   'picture',
#   'actress',
#   'role'],
#  'best performance by an actor in a supporting role in a motion picture': ['supporting',
#   'actor',
#   'performance',
#   'motion',
#   'picture',
#   'role'],
#  'best director - motion picture': ['picture', 'director', 'motion'],
#  'best screenplay - motion picture': ['picture', 'screenplay', 'motion'],
#  'best original score - motion picture': ['picture',
#   'original',
#   'motion',
#   'score'],
#  'best performance by an actress in a television series - drama': ['performance',
#   'drama',
#   'actress',
#   'series',
#   'television'],
#  'best performance by an actor in a television series - drama': ['actor',
#   'performance',
#   'drama',
#   'series',
#   'television'],
#  'best performance by an actress in a television series - comedy or musical': ['performance',
#   'actress',
#   'musical',
#   'series',
#   'television',
#   'comedy'],
#  'best performance by an actor in a television series - comedy or musical': ['actor',
#   'performance',
#   'musical',
#   'series',
#   'television',
#   'comedy'],
#  'best performance by an actress in a mini-series or motion picture made for television': ['performance',
#   'mini',
#   'picture',
#   'actress',
#   'series',
#   'motion',
#   'television'],
#  'best performance by an actor in a mini-series or motion picture made for television': ['actor',
#   'performance',
#   'mini',
#   'picture',
#   'series',
#   'motion',
#   'television'],
#  'best performance by an actress in a supporting role in a series, mini-series or motion picture made for television': ['supporting',
#   'performance',
#   'mini',
#   'motion',
#   'picture',
#   'actress',
#   'series',
#   'role',
#   'television'],
#  'best performance by an actor in a supporting role in a series, mini-series or motion picture made for television': ['supporting',
#   'actor',
#   'performance',
#   'mini',
#   'motion',
#   'picture',
#   'series',
#   'role',
#   'television']}

# %%
def filter0(data, list1):
    synonyms = {
        'motion' : ['motion picture', 'motion', 'picture', 'movie'],
        'picture' : ['motion picture', 'motion', 'picture', 'movie'],
        'television' : ['television', 'tv'],
        'mini' : ['mini-series', 'mini', 'series', 'miniseries'],
        'series' : ['mini-series', 'mini', 'series', 'miniseries']
    }
    
    result = []
    
    list1 = [i for i in list1 if i != 'performance' and i != 'role']

    for tweet in data:
        cond = True
        for i in list1:
            if i in synonyms:
                if all(j not in tweet.lower() for j in synonyms[i]):
                    cond = False
            elif i not in tweet.lower():
                cond = False
        if cond:
            result.append(tweet)

    return result

# %%
def extractNominees(data, list1):
    #print(data[0])
    result = []
       
    #tt = TweetTokenizer(strip_handles=True, reduce_len=True, preserve_case=True)
    translator = str.maketrans('', '', string.punctuation)
    remove_terms = ['#goldenglobes', 'golden globes', '#goldenglobe', 'golden globe', 'goldenglobes', 'goldenglobe', 'rt', 'golden', 'globe', 'globes']
    stop = remove_terms + list1
    
    for tweet in data:
        #print(tweet)
        tweet = re.sub("\d+", "", tweet) #strip nums
        tweet = re.sub(r'http\S+', '', tweet) #strip urls
        tweet = re.sub(r'#\S+', '', tweet) #strip hashtags
        tweet = tweet.translate(translator) #strip non-alphanumeric characters
        tweet = tweet.split() #tokenize
        tweet = [term for term in tweet if term.lower() not in stop_words] #remove stop words
        for i in stop:
            for j in tweet:
                if i.lower() in j.lower():
                    tweet.remove(j)
        result.append(tweet)
        
    #print(result[:20])
        
    grams = [];

    for tweet in result:
        if tweet:
            gram = list(nltk.everygrams(tweet, 2, 3))
            #print(bigram[:10])
            for g in gram:
                if len(g) == 2:
                    if bool(re.match(r'\b[A-Z][a-z]+\b', g[0])) and bool(re.match(r'\b[A-Z][a-z]+\b', g[1])):
                        grams.append(g)
                else:
                    if bool(re.match(r'\b[A-Z][a-z]+\b', g[0])) and bool(re.match(r'\b[A-Z][a-z]+\b', g[1])) and bool(re.match(r'\b[A-Z][a-z]+\b', g[2])):
                        grams.append(g)

  
    fdist = nltk.FreqDist(grams)
    #print(fdist)

    try:
        names = fdist.most_common()
        #names = [' '.join(i[0]) for i in fdist.most_common()]
    except:
        names = "nothing here"
    
    return names

# %%
def getNominees():
    d = {}
    for award in OFFICIAL_AWARDS_1315:
        d["{0}".format(award)] = filter0(data, categories_dict[award])
            
    nominees = {}
    for award in OFFICIAL_AWARDS_1315:
        nominees["{0}".format(award)] = extractNominees(d[award], categories_dict[award])
    
    return nominees

# %%
import timeit
start_time = timeit.default_timer()
nominees = getNominees()
elapsed = timeit.default_timer() - start_time
print(elapsed)
# Out:
# 295.6920909390001

# %%
nominees.keys()
# Out:
# dict_keys(['cecil b. demille award', 'best performance by an actress in a motion picture - drama', 'best performance by an actor in a motion picture - drama', 'best performance by an actress in a motion picture - comedy or musical', 'best performance by an actor in a motion picture - comedy or musical', 'best performance by an actress in a supporting role in a motion picture', 'best performance by an actor in a supporting role in a motion picture', 'best director - motion picture', 'best screenplay - motion picture', 'best original score - motion picture', 'best performance by an actress in a television series - drama', 'best performance by an actor in a television series - drama', 'best performance by an actress in a television series - comedy or musical', 'best performance by an actor in a television series - comedy or musical', 'best performance by an actress in a mini-series or motion picture made for television', 'best performance by an actor in a mini-series or motion picture made for television', 'best performance by an actress in a supporting role in a series, mini-series or motion picture made for television', 'best performance by an actor in a supporting role in a series, mini-series or motion picture made for television'])

# %%
nominees
# Out:
# {'cecil b. demille award': [(('George', 'Clooney'), 2440),
#   (('George', 'Clooneys'), 873),
#   (('Congratulations', 'George'), 472),
#   (('Recipient', 'George'), 434),
#   (('Recipient', 'George', 'Clooney'), 434),
#   (('Congratulations', 'George', 'Clooney'), 345),
#   (('Judy', 'Garland'), 139),
#   (('Variety', 'Judy'), 133),
#   (('Variety', 'Judy', 'Garland'), 133),
#   (('George', 'Brains'), 123),
#   (('Brains', 'Leslies'), 123),
#   (('Leslies', 'Ideal'), 123),
#   (('Ideal', 'Clooney'), 123),
#   (('Congratulations', 'George', 'Brains'), 123),
#   (('George', 'Brains', 'Leslies'), 123),
#   (('Brains', 'Leslies', 'Ideal'), 123),
#   (('Leslies', 'Ideal', 'Clooney'), 123),
#   (('Variety', 'George'), 87),
#   (('Variety', 'George', 'Clooney'), 87),
#   (('Clooney', 'Wins'), 71),
#   (('George', 'Clooney', 'Wins'), 71),
#   (('Lifetime', 'Achievement'), 68),
#   (('Wins', 'George'), 59),
#   (('Clooney', 'Wins', 'George'), 59),
#   (('Congrats', 'George'), 58),
#   (('Congrats', 'George', 'Clooney'), 58),
#   (('Wins', 'George', 'Clooney'), 57),
#   (('Backstage', 'Congrats'), 36),
#   (('Backstage', 'Congrats', 'George'), 36),
#   (('Julianna', 'Margulies'), 30),
#   (('Clooney', 'Receives'), 26),
#   (('George', 'Clooney', 'Receives'), 26),
#   (('Cheadle', 'George'), 22),
#   (('Cheadle', 'George', 'Clooney'), 22),
#   (('Amal', 'Alamuddin'), 16),
#   (('Watch', 'George'), 15),
#   (('Clooney', 'Lifetime'), 14),
#   (('George', 'Clooney', 'Lifetime'), 13),
#   (('Watch', 'George', 'Clooneys'), 13),
#   (('Audrey', 'Hepburn'), 12),
#   (('Clooney', 'Lifetime', 'Achievement'), 12),
#   (('George', 'Cloony'), 12),
#   (('Trophies', 'Perspective'), 11),
#   (('Perspective', 'Speech'), 11),
#   (('Trophies', 'Perspective', 'Speech'), 11),
#   (('Receives', 'Alejandro'), 10),
#   (('Alejandro', 'Gonzalez'), 10),
#   (('Clooney', 'Receives', 'Alejandro'), 10),
#   (('Receives', 'Alejandro', 'Gonzalez'), 10),
#   (('Clooney', 'Trophies'), 10),
#   (('George', 'Clooney', 'Trophies'), 10),
#   (('Clooney', 'Trophies', 'Perspective'), 10),
#   (('Clooney', 'Amal'), 9),
#   (('George', 'Clooney', 'Amal'), 9),
#   (('Margulies', 'Cheadle'), 9),
#   (('Julianna', 'Margulies', 'Cheadle'), 9),
#   (('Lauren', 'Bacall'), 9),
#   (('Gonzalez', 'Inarritu'), 9),
#   (('Alejandro', 'Gonzalez', 'Inarritu'), 9),
#   (('Photo', 'Bank'), 9),
#   (('Bank', 'George'), 9),
#   (('Photo', 'Bank', 'George'), 9),
#   (('Bank', 'George', 'Clooney'), 9),
#   (('Lifetime', 'Achievment'), 8),
#   (('Clooney', 'Honored'), 8),
#   (('Honored', 'Lifetime'), 8),
#   (('George', 'Clooney', 'Honored'), 8),
#   (('Clooney', 'Honored', 'Lifetime'), 8),
#   (('Honored', 'Lifetime', 'Achievement'), 8),
#   (('Deadline', 'George'), 8),
#   (('Deadline', 'George', 'Clooney'), 8),
#   (('Photo', 'Reuters'), 7),
#   (('Clooney', 'Photo'), 7),
#   (('George', 'Clooney', 'Photo'), 7),
#   (('Inarritu', 'Nicolas'), 7),
#   (('Nicolas', 'Giac'), 7),
#   (('Gonzalez', 'Inarritu', 'Nicolas'), 7),
#   (('Inarritu', 'Nicolas', 'Giac'), 7),
#   (('Achievement', 'Motion'), 7),
#   (('Lifetime', 'Achievement', 'Motion'), 7),
#   (('Flashback', 'George'), 6),
#   (('Flashback', 'George', 'Clooney'), 6),
#   (('Clooney', 'Amal', 'Alamuddin'), 6),
#   (('Margulies', 'Cheadle', 'George'), 6),
#   (('Clooney', 'Talks'), 6),
#   (('Talks', 'French'), 6),
#   (('French', 'Terror'), 6),
#   (('Terror', 'Attacks'), 6),
#   (('Attacks', 'Acceptance'), 6),
#   (('Acceptance', 'Speech'), 6),
#   (('George', 'Clooney', 'Talks'), 6),
#   (('Clooney', 'Talks', 'French'), 6),
#   (('Talks', 'French', 'Terror'), 6),
#   (('French', 'Terror', 'Attacks'), 6),
#   (('Terror', 'Attacks', 'Acceptance'), 6),
#   (('Attacks', 'Acceptance', 'Speech'), 6),
#   (('Motion', 'Pictures'), 6),
#   (('Achievement', 'Motion', 'Pictures'), 6),
#   (('Julianna', 'Marguiles'), 5),
#   (('Liza', 'Minnelli'), 5),
#   (('Minnelli', 'Elizabeth'), 5),
#   (('Elizabeth', 'Taylor'), 5),
#   (('Liza', 'Minnelli', 'Elizabeth'), 5),
#   (('Minnelli', 'Elizabeth', 'Taylor'), 5),
#   (('Hollywood', 'Foreign'), 5),
#   (('Foreign', 'Press'), 5),
#   (('Hollywood', 'Foreign', 'Press'), 5),
#   (('El', 'George'), 5),
#   (('El', 'George', 'Clooney'), 5),
#   (('Michael', 'Keaton'), 5),
#   (('Rumor', 'George'), 4),
#   (('Rumor', 'George', 'Clooney'), 4),
#   (('Achievement', 'George'), 4),
#   (('Lifetime', 'Achievement', 'George'), 4),
#   (('Achievement', 'George', 'Clooney'), 4),
#   (('Jsuis', 'Charlie'), 4),
#   (('Amal', 'Speech'), 4),
#   (('Annual', 'January'), 3),
#   (('Marguiles', 'Cheadle'), 3),
#   (('Julianna', 'Marguiles', 'Cheadle'), 3),
#   (('Marguiles', 'Cheadle', 'George'), 3),
#   (('Clooney', 'Congratulations'), 3),
#   (('George', 'Clooney', 'Congratulations'), 3),
#   (('Margulies', 'George'), 3),
#   (('Julianna', 'Margulies', 'George'), 3),
#   (('Margulies', 'George', 'Clooney'), 3),
#   (('Meryl', 'Streep'), 3),
#   (('Hathaway', 'Doug'), 3),
#   (('Doug', 'Ross'), 3),
#   (('Hathaway', 'Doug', 'Ross'), 3),
#   (('South', 'Park'), 3),
#   (('Clooney', 'Winner'), 3),
#   (('George', 'Clooney', 'Winner'), 3),
#   (('Speech', 'George'), 3),
#   (('Speech', 'George', 'Clooney'), 3),
#   (('Ironic', 'Michael'), 3),
#   (('Ironic', 'Michael', 'Keaton'), 3),
#   (('George', 'Clooney”'), 3),
#   (('Margulies', 'Clooney'), 2),
#   (('Julianna', 'Margulies', 'Clooney'), 2),
#   (('Clooney', 'George'), 2),
#   (('George', 'Clooney', 'George'), 2),
#   (('Jim', 'Carrey'), 2),
#   (('Clooney', 'Meryl'), 2),
#   (('George', 'Clooney', 'Meryl'), 2),
#   (('Clooney', 'Red'), 2),
#   (('Red', 'Carpet'), 2),
#   (('George', 'Clooney', 'Red'), 2),
#   (('Clooney', 'Red', 'Carpet'), 2),
#   (('Jodie', 'Foster'), 2),
#   (('Carol', 'Hathaway'), 2),
#   (('Carol', 'Hathaway', 'Doug'), 2),
#   (('Life', 'Return'), 2),
#   (('Return', 'Killer'), 2),
#   (('Killer', 'Tomatoes'), 2),
#   (('Life', 'Return', 'Killer'), 2),
#   (('Return', 'Killer', 'Tomatoes'), 2),
#   (('Friend', 'George'), 2),
#   (('Winner', 'George'), 2),
#   (('Winner', 'George', 'Clooney'), 2),
#   (('Achievement', 'Hollywood'), 2),
#   (('Lifetime', 'Achievement', 'Hollywood'), 2),
#   (('Achievement', 'Hollywood', 'Foreign'), 2),
#   (('Max', 'Nikias'), 2),
#   (('Batman', 'Robin'), 2),
#   (('Bball', 'Congrats'), 2),
#   (('Clooney', 'Award'), 2),
#   (('George', 'Clooney', 'Award'), 2),
#   (('Tonights', 'Humanitarian'), 2),
#   (('Humanitarian', 'Recipient'), 2),
#   (('Tonights', 'Humanitarian', 'Recipient'), 2),
#   (('Humanitarian', 'Recipient', 'George'), 2),
#   (('Clooney', 'Recibe'), 2),
#   (('George', 'Clooney', 'Recibe'), 2),
#   (('Clooney', 'Pic'), 2),
#   (('George', 'Clooney', 'Pic'), 2),
#   (('Commonwealth', 'Kentucky'), 2),
#   (('Kentucky', 'George'), 2),
#   (('Commonwealth', 'Kentucky', 'George'), 2),
#   (('Kentucky', 'George', 'Clooneys'), 2),
#   (('Swoon', 'Cloon'), 2),
#   (('Cloon', 'George'), 2),
#   (('Swoon', 'Cloon', 'George'), 2),
#   (('Cloon', 'George', 'Clooney'), 2),
#   (('Clooney', 'Amal', 'Speech'), 2),
#   (('Clooney', 'Speech'), 2),
#   (('George', 'Clooney', 'Speech'), 2),
#   (('Actor', 'George'), 2),
#   (('Actor', 'George', 'Clooney'), 2),
#   (('Wins', 'Lifetime'), 2),
#   (('Wins', 'Lifetime', 'Achievement'), 2),
#   (('Clooney', 'Pay'), 2),
#   (('Pay', 'Tribute'), 2),
#   (('Tribute', 'Wife'), 2),
#   (('Wife', 'Amal'), 2),
#   (('Watch', 'George', 'Clooney'), 2),
#   (('George', 'Clooney', 'Pay'), 2),
#   (('Clooney', 'Pay', 'Tribute'), 2),
#   (('Pay', 'Tribute', 'Wife'), 2),
#   (('Tribute', 'Wife', 'Amal'), 2),
#   (('Wife', 'Amal', 'Speech'), 2),
#   (('Amal', 'Speech', 'George'), 2),
#   (('Flash', 'George'), 2),
#   (('Flash', 'George', 'Clooney'), 2),
#   (('Loved', 'George'), 2),
#   (('Loved', 'George', 'Clooneys'), 2),
#   (('Clooney', 'Gushes'), 2),
#   (('George', 'Clooney', 'Gushes'), 2),
#   (('Clooney', 'Admittd'), 2),
#   (('Admittd', 'Recycld'), 2),
#   (('Recycld', 'Weddin'), 2),
#   (('Weddin', 'Tuxedo'), 2),
#   (('George', 'Clooney', 'Admittd'), 2),
#   (('Clooney', 'Admittd', 'Recycld'), 2),
#   (('Admittd', 'Recycld', 'Weddin'), 2),
#   (('Recycld', 'Weddin', 'Tuxedo'), 2),
#   (('Disgusting', 'Variety'), 1),
#   (('Disgusting', 'Variety', 'George'), 1),
#   (('Return', 'Horror'), 1),
#   (('Horror', 'George'), 1),
#   (('Return', 'Horror', 'George'), 1),
#   (('Horror', 'George', 'Clooney'), 1),
#   (('Newlywed', 'George'), 1),
#   (('Newlywed', 'George', 'Clooney'), 1),
#   (('Achievment', 'George'), 1),
#   (('Lifetime', 'Achievment', 'George'), 1),
#   (('Achievment', 'George', 'Clooney'), 1),
#   (('Watching', 'Awesome'), 1),
#   (('Awesome', 'George'), 1),
#   (('Watching', 'Awesome', 'George'), 1),
#   (('Awesome', 'George', 'Clooney'), 1),
#   (('Clooney', 'Congratulations', 'George'), 1),
#   (('Clooney', 'George', 'Clooney'), 1),
#   (('Wow', 'Amal'), 1),
#   (('Amal', 'Naisss'), 1),
#   (('Naisss', 'Recipient'), 1),
#   (('Wow', 'Amal', 'Naisss'), 1),
#   (('Amal', 'Naisss', 'Recipient'), 1),
#   (('Naisss', 'Recipient', 'George'), 1),
#   (('Clooney', 'Stunning'), 1),
#   (('George', 'Clooney', 'Stunning'), 1),
#   (('Love', 'Clooney'), 1),
#   (('Amal', 'Amauddin'), 1),
#   (('Hey', 'Cher'), 1),
#   (('Oscar', 'Grammy'), 1),
#   (('Silicon', 'Valley'), 1),
#   (('Gary', 'Busey'), 1),
#   (('Clooney', 'Meryl', 'Streep'), 1),
#   (('Tonight', 'George'), 1),
#   (('Tonight', 'George', 'Clooney'), 1),
#   (('Doug', 'Carol'), 1),
#   (('Downey', 'Jr'), 1),
#   (('Jr', 'Jodie'), 1),
#   (('Downey', 'Jr', 'Jodie'), 1),
#   (('Jr', 'Jodie', 'Foster'), 1),
#   (('Paging', 'George'), 1),
#   (('Paging', 'George', 'Clooney'), 1),
#   (('Pia', 'Zadora'), 1),
#   (('Zadora', 'Idiots'), 1),
#   (('Pia', 'Zadora', 'Idiots'), 1),
#   (('Kevin', 'Spacey'), 1),
#   (('Julianne', 'George'), 1),
#   (('Julianne', 'George', 'Clooney'), 1),
#   (('Love', 'George'), 1),
#   (('Love', 'George', 'Clooney'), 1),
#   (('Matt', 'Damon'), 1),
#   (('Awwhhh', 'Nurse'), 1),
#   (('Nurse', 'Hathaway'), 1),
#   (('Awwhhh', 'Nurse', 'Hathaway'), 1),
#   (('Nurse', 'Hathaway', 'Doug'), 1),
#   (('Marguiles', 'George'), 1),
#   (('Julianna', 'Marguiles', 'George'), 1),
#   (('Marguiles', 'George', 'Clooney'), 1),
#   (('Red', 'Wedding'), 1),
#   (('Movies', 'Earned'), 1),
#   (('Earned', 'Friend'), 1),
#   (('Movies', 'Earned', 'Friend'), 1),
#   (('Earned', 'Friend', 'George'), 1),
#   (('Friend', 'George', 'Clooney'), 1),
#   (('Humanitarian', 'George'), 1),
#   (('Humanitarian', 'George', 'Clooney'), 1),
#   (('Walt', 'Disney'), 1),
#   (('Julianne', 'Margulies'), 1),
#   (('Clooney', 'Friend'), 1),
#   (('George', 'Clooney', 'Friend'), 1),
#   (('Clooney', 'Friend', 'George'), 1),
#   (('Surprise', 'George'), 1),
#   (('Surprise', 'George', 'Clooney'), 1),
#   (('Sincerity', 'Hollywood'), 1),
#   (('Life', 'George'), 1),
#   (('Life', 'George', 'Clooney'), 1),
#   (('King', 'Clooney'), 1),
#   (('Clooney', 'Tribute'), 1),
#   (('Tribute', 'Time🌟👍🏆'), 1),
#   (('King', 'Clooney', 'Tribute'), 1),
#   (('Clooney', 'Tribute', 'Time🌟👍🏆'), 1),
#   (('Clooney', 'Disney’s'), 1),
#   (('Disney’s', 'Tomorrowland'), 1),
#   (('Tomorrowland', 'Summer'), 1),
#   (('George', 'Clooney', 'Disney’s'), 1),
#   (('Clooney', 'Disney’s', 'Tomorrowland'), 1),
#   (('Disney’s', 'Tomorrowland', 'Summer'), 1),
#   (('Alicia', 'Florrick'), 1),
#   (('Florrick', 'Col'), 1),
#   (('Col', 'Rhodes'), 1),
#   (('Alicia', 'Florrick', 'Col'), 1),
#   (('Florrick', 'Col', 'Rhodes'), 1),
#   (('Kelsey', 'Grammars'), 1),
#   (('Gorgeous', 'Juliana'), 1),
#   (('Juliana', 'Margolis'), 1),
#   (('Gorgeous', 'Juliana', 'Margolis'), 1),
#   (('Alamuddin', 'Award'), 1),
#   (('Amal', 'Alamuddin', 'Award'), 1),
#   (('Clooney', 'Handsome'), 1),
#   (('Handsome', 'Helpful'), 1),
#   (('George', 'Clooney', 'Handsome'), 1),
#   (('Clooney', 'Handsome', 'Helpful'), 1),
#   (('Bruce', 'Wayne'), 1),
#   (('Alamuddin', 'Awar…'), 1),
#   (('Amal', 'Alamuddin', 'Awar…'), 1),
#   (('Dakota', 'Fanning'), 1),
#   (('Achievement', 'Beverly…'), 1),
#   (('Lifetime', 'Achievement', 'Beverly…'), 1),
#   (('George', 'Clooneyrecipient'), 1),
#   (('Congratulations', 'George', 'Clooneyrecipient'), 1),
#   (('Yeah', 'Jodi'), 1),
#   (('Jodi', 'Foster'), 1),
#   (('Yeah', 'Jodi', 'Foster'), 1),
#   (('Yeah', 'Jodie'), 1),
#   (('Yeah', 'Jodie', 'Foster'), 1),
#   (('George', 'Cheadle'), 1),
#   (('Angelina', 'Jolie'), 1),
#   (('Clooney', 'Life'), 1),
#   (('Life', 'Robbed'), 1),
#   (('Clooney', 'Life', 'Robbed'), 1),
#   (('Favorite', 'George'), 1),
#   (('Favorite', 'George', 'Clooney'), 1),
#   (('Guys', 'George'), 1),
#   (('Guys', 'George', 'Clooney'), 1),
#   (('Life', 'Roseanne'), 1),
#   (('Sid', 'Krofft'), 1),
#   (('Krofft', 'Ricky'), 1),
#   (('Ricky', 'Schroeder'), 1),
#   (('Sid', 'Krofft', 'Ricky'), 1),
#   (('Krofft', 'Ricky', 'Schroeder'), 1),
#   (('Accepting', 'Lifetime'), 1),
#   (('Accepting', 'Lifetime', 'Achievement'), 1),
#   (('Life', 'Roseanne…'), 1),
#   (('Booker', 'Roseanne'), 1),
#   (('Roseanne', 'George'), 1),
#   (('Booker', 'Roseanne', 'George'), 1),
#   (('Roseanne', 'George', 'Clooney'), 1),
#   (('Danny', 'Ocean'), 1),
#   (('Shades', 'Grey'), 1),
#   (('Poignant', 'Beautiful'), 1),
#   (('Beautiful', 'Speech'), 1),
#   (('Poignant', 'Beautiful', 'Speech'), 1),
#   (('Gracious', 'Lifetime'), 1),
#   (('Gracious', 'Lifetime', 'Achievement'), 1),
#   (('Clooney', 'Team'), 1),
#   (('Team', 'Marvin'), 1),
#   (('Marvin', 'Hamlisch'), 1),
#   (('George', 'Clooney', 'Team'), 1),
#   (('Clooney', 'Team', 'Marvin'), 1),
#   (('Team', 'Marvin', 'Hamlisch'), 1),
#   (('Clooney', 'Awesome'), 1),
#   (('Commercial', 'Break'), 1),
#   (('George”', 'Class'), 1),
#   (('Harrison', 'Ford'), 1),
#   (('Clooney', 'Awards'), 1),
#   (('George', 'Clooney', 'Awards'), 1),
#   (('Hollywood', 'Niros'), 1),
#   (('Niros', 'Pacinos'), 1),
#   (('Pacinos', 'Clooney'), 1),
#   (('Hollywood', 'Niros', 'Pacinos'), 1),
#   (('Niros', 'Pacinos', 'Clooney'), 1),
#   (('Richard', 'Linklater'), 1),
#   (('Shades', 'Greyout'), 1),
#   (('Robin', 'Williams'), 1),
#   (('Williams', 'Lauren'), 1),
#   (('Robin', 'Williams', 'Lauren'), 1),
#   (('Williams', 'Lauren', 'Bacall'), 1),
#   (('Daniel', 'Day'), 1),
#   (('Day', 'Lewis'), 1),
#   (('Lewis', 'George'), 1),
#   (('Daniel', 'Day', 'Lewis'), 1),
#   (('Day', 'Lewis', 'George'), 1),
#   (('Lewis', 'George', 'Clooney'), 1),
#   (('Watching', 'George'), 1),
#   (('Watching', 'George', 'Clooney'), 1),
#   (('George', 'Darlenes'), 1),
#   (('Ha', 'Cleverly'), 1),
#   (('Clooney', 'Actor'), 1),
#   (('Actor', 'Michael'), 1),
#   (('George', 'Clooney', 'Actor'), 1),
#   (('Clooney', 'Actor', 'Michael'), 1),
#   (('Actor', 'Michael', 'Keaton'), 1),
#   (('George', 'Clooneya'), 1),
#   (('Batman', 'Batman'), 1),
#   (('Batman', 'Actor'), 1),
#   (('Batman', 'Batman', 'Actor'), 1),
#   (('Clooney', 'Speech', 'George'), 1),
#   (('Actor', 'Clooney'), 1),
#   (('Clooney', 'Wins', 'Lifetime'), 1),
#   (('Robin', 'George'), 1),
#   (('Leatherheads', 'Nicest'), 1),
#   (('Inarritu', 'Ace'), 1),
#   (('Ace', 'Biz'), 1),
#   (('Gonzalez', 'Inarritu', 'Ace'), 1),
#   (('Inarritu', 'Ace', 'Biz'), 1),
#   (('Inarritu', 'Nico'), 1),
#   (('Gonzalez', 'Inarritu', 'Nico'), 1),
#   (('Cool', 'George'), 1),
#   (('Cool', 'George', 'Clooneys'), 1),
#   (('Video', 'George'), 1),
#   (('Video', 'George', 'Clooney'), 1),
#   (('Memorium', 'Clooney'), 1),
#   (('Check', 'George'), 1),
#   (('Check', 'George', 'Clooneys'), 1),
#   (('Pres', 'Max'), 1),
#   (('Pres', 'Max', 'Nikias'), 1),
#   (('Supercut', 'George'), 1),
#   (('Supercut', 'George', 'Clooney'), 1),
#   (('Swoon', 'Wait'), 1),
#   (('Movies', 'George'), 1),
#   (('Movies', 'George', 'Clooney'), 1),
#   (('Kerala', 'George'), 1),
#   (('Kerala', 'George', 'Clooney'), 1),
#   (('Speech', 'Matt'), 1),
#   (('Matt', 'Donnelly'), 1),
#   (('Acceptance', 'Speech', 'Matt'), 1),
#   (('Speech', 'Matt', 'Donnelly'), 1),
#   (('Clooney', 'Winners'), 1),
#   (('Winners', 'Nominees'), 1),
#   (('Clooney', 'Winners', 'Nominees'), 1),
#   (('Clooney', 'Couple'), 1),
#   (('George', 'Clooney', 'Couple'), 1),
#   (('Cheadle', 'Julianna'), 1),
#   (('Cheadle', 'Julianna', 'Margulies'), 1),
#   (('Photo', 'George'), 1),
#   (('Rukmini', 'Chopra'), 1),
#   (('Photo', 'George', 'Cloony'), 1),
#   (('Clooney', 'Recipient'), 1),
#   (('George', 'Clooney', 'Recipient'), 1),
#   (('Omg', 'George'), 1),
#   (('Omg', 'George', 'Clooneys'), 1),
#   (('Local', 'Search'), 1),
#   (('Search', 'George'), 1),
#   (('Local', 'Search', 'George'), 1),
#   (('Search', 'George', 'Clooney'), 1),
#   (('Inspiration', 'Superhero'), 1),
#   (('Superhero', 'Winner'), 1),
#   (('Winner', 'Congrats'), 1),
#   (('Inspiration', 'Superhero', 'Winner'), 1),
#   (('Superhero', 'Winner', 'Congrats'), 1),
#   (('Amal', 'Stage'), 1),
#   (('Amal', 'Clooney'), 1),
#   (('Sexy', 'White'), 1),
#   (('White', 'Hair'), 1),
#   (('Hair', 'George'), 1),
#   (('Sexy', 'White', 'Hair'), 1),
#   (('White', 'Hair', 'George'), 1),
#   (('Hair', 'George', 'Clooney'), 1)],
#  'best performance by an actress in a motion picture - drama': [(('Julianne',
#     'Moore'),
#    3298),
#   (('Moore', 'Alice'), 808),
#   (('Julianne', 'Moore', 'Alice'), 795),
#   (('Congratulations', 'Julianne'), 208),
#   (('Congratulations', 'Julianne', 'Moore'), 208),
#   (('Moore', 'Wins'), 160),
#   (('Julianne', 'Moore', 'Wins'), 160),
#   (('Winnner', 'Julianne'), 109),
#   (('Winnner', 'Julianne', 'Moore'), 109),
#   (('Ruth', 'Wilson'), 52),
#   (('Congrats', 'Julianne'), 49),
#   (('Congrats', 'Julianne', 'Moore'), 49),
#   (('Wearing', 'Givenchy'), 43),
#   (('Wins', 'Award'), 34),
#   (('Moore', 'Wins', 'Award'), 34),
#   (('Moore', 'Freundlich'), 29),
#   (('Julianne', 'Moore', 'Freundlich'), 29),
#   (('Rosamund', 'Pike'), 22),
#   (('Award', 'Woo'), 20),
#   (('Wins', 'Award', 'Woo'), 20),
#   (('Jennifer', 'Aniston'), 14),
#   (('Girl', 'Julianne'), 13),
#   (('Girl', 'Julianne', 'Moore'), 13),
#   (('Patricia', 'Arquette'), 11),
#   (('Moore', 'Rosamund'), 11),
#   (('Moore', 'Rosamund', 'Pike'), 11),
#   (('Reese', 'Witherspoon'), 9),
#   (('Julianne', 'Moore', 'Rosamund'), 9),
#   (('Winner', 'Julianne'), 9),
#   (('Winner', 'Julianne', 'Moore'), 8),
#   (('Pemenang', 'Julianne'), 8),
#   (('Pemenang', 'Julianne', 'Moore'), 8),
#   (('Felicity', 'Jones'), 7),
#   (('Amy', 'Adams'), 7),
#   (('Winning', 'Julianne'), 7),
#   (('Winning', 'Julianne', 'Moore'), 7),
#   (('Eddie', 'Redmayne'), 7),
#   (('Culturalist', 'Congratulations'), 6),
#   (('Shailene', 'Woodley'), 6),
#   (('Julianna', 'Moore'), 5),
#   (('Julieanne', 'Moore'), 5),
#   (('Julieanne', 'Moore', 'Alice'), 5),
#   (('Julliane', 'Moore'), 5),
#   (('Fandango', 'Congrats'), 5),
#   (('Fandango', 'Congrats', 'Julianne'), 5),
#   (('Wins', 'Sunday'), 5),
#   (('Moore', 'Wins', 'Sunday'), 5),
#   (('Winner', 'Shailene'), 5),
#   (('Winner', 'Shailene', 'Woodley'), 5),
#   (('Alice', 'Moore'), 5),
#   (('Aniston', 'Black'), 4),
#   (('Black', 'List'), 4),
#   (('Jennifer', 'Aniston', 'Black'), 4),
#   (('Aniston', 'Black', 'List'), 4),
#   (('Musical', 'Comedy'), 4),
#   (('Television', 'Series'), 4),
#   (('Series', 'Ruth'), 4),
#   (('Television', 'Series', 'Ruth'), 4),
#   (('Series', 'Ruth', 'Wilson'), 4),
#   (('Moore', 'Alice”'), 4),
#   (('Julianne', 'Moore', 'Alice”'), 4),
#   (('Juliane', 'Moore'), 4),
#   (('Redmayne', 'Julianne'), 4),
#   (('Moore', 'Actor'), 4),
#   (('Eddie', 'Redmayne', 'Julianne'), 4),
#   (('Redmayne', 'Julianne', 'Moore'), 4),
#   (('Julianne', 'Moore', 'Actor'), 4),
#   (('Video', 'Julianne'), 4),
#   (('Moore', 'Photo'), 4),
#   (('Julianne', 'Moore', 'Photo'), 4),
#   (('Aniston', 'Felicity'), 3),
#   (('Jones', 'Julianne'), 3),
#   (('Pike', 'Reese'), 3),
#   (('Aniston', 'Felicity', 'Jones'), 3),
#   (('Felicity', 'Jones', 'Julianne'), 3),
#   (('Jones', 'Julianne', 'Moore'), 3),
#   (('Rosamund', 'Pike', 'Reese'), 3),
#   (('Pike', 'Reese', 'Witherspoon'), 3),
#   (('Comedy', 'Patricia'), 3),
#   (('Musical', 'Comedy', 'Patricia'), 3),
#   (('Comedy', 'Patricia', 'Arquette'), 3),
#   (('Affair', 'Track'), 3),
#   (('Eyes', 'Movie'), 3),
#   (('Julianne', 'Alice'), 3),
#   (('Movie', 'Julianne'), 3),
#   (('Movie', 'Julianne', 'Moore'), 3),
#   (('Mel', 'Julianne'), 3),
#   (('Mel', 'Julianne', 'Moore'), 3),
#   (('Congrats', 'Julianna'), 3),
#   (('Congrats', 'Julianna', 'Moore'), 3),
#   (('Alice', 'Track'), 3),
#   (('Matthew', 'Mcconaughey'), 3),
#   (('Itsoktobeyouorg', 'Video'), 3),
#   (('Award', 'Alice'), 3),
#   (('Itsoktobeyouorg', 'Video', 'Julianne'), 3),
#   (('Boyhood', 'Director'), 2),
#   (('Pike', 'Girl'), 2),
#   (('Rosamund', 'Pike', 'Girl'), 2),
#   (('Arquette', 'Boyhood'), 2),
#   (('Patricia', 'Arquette', 'Boyhood'), 2),
#   (('Jennifer', 'Aniston', 'Felicity'), 2),
#   (('Congrats', 'Patricia'), 2),
#   (('Congrats', 'Patricia', 'Arquette'), 2),
#   (('Wilson', 'Affair'), 2),
#   (('Ruth', 'Wilson', 'Affair'), 2),
#   (('Movie', 'Ruth'), 2),
#   (('Wilson', 'Wins'), 2),
#   (('Wins', 'Affair'), 2),
#   (('Eyes', 'Movie', 'Ruth'), 2),
#   (('Movie', 'Ruth', 'Wilson'), 2),
#   (('Ruth', 'Wilson', 'Wins'), 2),
#   (('Wilson', 'Wins', 'Affair'), 2),
#   (('Aniston', 'Rosamund'), 2),
#   (('Jennifer', 'Aniston', 'Rosamund'), 2),
#   (('Aniston', 'Rosamund', 'Pike'), 2),
#   (('Jen', 'Aniston'), 2),
#   (('Julianna', 'Moore', 'Alice'), 2),
#   (('Alice', 'Congrats'), 2),
#   (('Civil', 'War'), 2),
#   (('Zapit', 'Julianne'), 2),
#   (('Zapit', 'Julianne', 'Moore'), 2),
#   (('Juliane', 'Moore', 'Rosamund'), 2),
#   (('Awards', 'Winners'), 2),
#   (('Actor', 'Eddie'), 2),
#   (('Culturalist', 'Retweet'), 2),
#   (('News', 'Fandango'), 2),
#   (('News', 'Fandango', 'Congrats'), 2),
#   (('Linklater', 'Arquette'), 2),
#   (('Ruth', 'Wilsons'), 2),
#   (('Wilsons', 'Win'), 2),
#   (('Win', 'Rounds'), 2),
#   (('Rounds', 'Winner'), 2),
#   (('Winner', 'List'), 2),
#   (('Ruth', 'Wilsons', 'Win'), 2),
#   (('Wilsons', 'Win', 'Rounds'), 2),
#   (('Win', 'Rounds', 'Winner'), 2),
#   (('Rounds', 'Winner', 'List'), 2),
#   (('Wins', 'Moore'), 2),
#   (('Moore', 'Wins', 'Moore'), 2),
#   (('Beautiful', 'Accept'), 2),
#   (('Jake', 'Rose'), 1),
#   (('Rose', 'Pike'), 1),
#   (('Jake', 'Rose', 'Pike'), 1),
#   (('Kstewartfans', 'Congratulations'), 1),
#   (('Witherspoon', 'Wild'), 1),
#   (('Reese', 'Witherspoon', 'Wild'), 1),
#   (('Director', 'Richard'), 1),
#   (('Richard', 'Linklater'), 1),
#   (('Linklater', 'Screenplay'), 1),
#   (('Screenplay', 'Birdman'), 1),
#   (('Birdman', 'Julianne'), 1),
#   (('Boyhood', 'Director', 'Richard'), 1),
#   (('Director', 'Richard', 'Linklater'), 1),
#   (('Richard', 'Linklater', 'Screenplay'), 1),
#   (('Linklater', 'Screenplay', 'Birdman'), 1),
#   (('Screenplay', 'Birdman', 'Julianne'), 1),
#   (('Birdman', 'Julianne', 'Moore'), 1),
#   (('Predictions', 'Rosamund'), 1),
#   (('Predictions', 'Rosamund', 'Pike'), 1),
#   (('Predictions', 'Patricia'), 1),
#   (('Predictions', 'Patricia', 'Arquette'), 1),
#   (('Movie', 'Jennifer'), 1),
#   (('Movie', 'Jennifer', 'Aniston'), 1),
#   (('Witherspoon', 'Felicity'), 1),
#   (('Jones', 'Jennifer'), 1),
#   (('Reese', 'Witherspoon', 'Felicity'), 1),
#   (('Witherspoon', 'Felicity', 'Jones'), 1),
#   (('Felicity', 'Jones', 'Jennifer'), 1),
#   (('Jones', 'Jennifer', 'Aniston'), 1),
#   (('Pike', 'Musical'), 1),
#   (('Grand', 'Budapest'), 1),
#   (('Budapest', 'Hotel'), 1),
#   (('Grand', 'Budapest', 'Hotel'), 1),
#   (('Boyhood', 'Jennifer'), 1),
#   (('Boyhood', 'Jennifer', 'Aniston'), 1),
#   (('Boyhood', 'Comedy'), 1),
#   (('Comedy', 'Birdman'), 1),
#   (('Birdman', 'Actor'), 1),
#   (('Actor', 'Redmayne'), 1),
#   (('Redmayne', 'Comedy'), 1),
#   (('Comedy', 'Keaton'), 1),
#   (('Keaton', 'Moore'), 1),
#   (('Moore', 'Comedy'), 1),
#   (('Comedy', 'Adams'), 1),
#   (('Boyhood', 'Comedy', 'Birdman'), 1),
#   (('Comedy', 'Birdman', 'Actor'), 1),
#   (('Birdman', 'Actor', 'Redmayne'), 1),
#   (('Actor', 'Redmayne', 'Comedy'), 1),
#   (('Redmayne', 'Comedy', 'Keaton'), 1),
#   (('Comedy', 'Keaton', 'Moore'), 1),
#   (('Keaton', 'Moore', 'Comedy'), 1),
#   (('Moore', 'Comedy', 'Adams'), 1),
#   (('Adams', 'Eyes'), 1),
#   (('Amy', 'Adams', 'Eyes'), 1),
#   (('Movie', 'Amy'), 1),
#   (('Movie', 'Amy', 'Adams'), 1),
#   (('Congratulations', 'Amy'), 1),
#   (('Congratulations', 'Amy', 'Adams'), 1),
#   (('Comedy', 'Amy'), 1),
#   (('Musical', 'Comedy', 'Amy'), 1),
#   (('Comedy', 'Amy', 'Adams'), 1),
#   (('Movie', 'Maggie'), 1),
#   (('Maggie', 'Honorable'), 1),
#   (('Honorable', 'Woman'), 1),
#   (('Movie', 'Maggie', 'Honorable'), 1),
#   (('Maggie', 'Honorable', 'Woman'), 1),
#   (('Series', 'Check'), 1),
#   (('Ruth', 'Wislon'), 1),
#   (('Shoulda', 'Ava'), 1),
#   (('Ava', 'Viola'), 1),
#   (('Shoulda', 'Ava', 'Viola'), 1),
#   (('Jones', 'Rosemund'), 1),
#   (('Rosemund', 'Pike'), 1),
#   (('Felicity', 'Jones', 'Rosemund'), 1),
#   (('Jones', 'Rosemund', 'Pike'), 1),
#   (('Pike', 'Felicity'), 1),
#   (('Moore', 'Reese'), 1),
#   (('Rosamund', 'Pike', 'Felicity'), 1),
#   (('Pike', 'Felicity', 'Jones'), 1),
#   (('Julianne', 'Moore', 'Reese'), 1),
#   (('Moore', 'Reese', 'Witherspoon'), 1),
#   (('Jones', 'Jen'), 1),
#   (('Felicity', 'Jones', 'Jen'), 1),
#   (('Jones', 'Jen', 'Aniston'), 1),
#   (('Julianne', 'Moree'), 1),
#   (('Moree', 'Alice'), 1),
#   (('Julianne', 'Moree', 'Alice'), 1),
#   (('Yay', 'Julianne'), 1),
#   (('Yay', 'Julianne', 'Moore'), 1),
#   (('Julian', 'Moore'), 1),
#   (('Awww', 'Julianne'), 1),
#   (('Awww', 'Julianne', 'Moore'), 1),
#   (('Alice', 'Love'), 1),
#   (('Alice', 'Damn'), 1),
#   (('Damn', 'Hollywood'), 1),
#   (('Hollywood', 'Foreign'), 1),
#   (('Foreign', 'Press'), 1),
#   (('Moore', 'Alice', 'Damn'), 1),
#   (('Alice', 'Damn', 'Hollywood'), 1),
#   (('Damn', 'Hollywood', 'Foreign'), 1),
#   (('Hollywood', 'Foreign', 'Press'), 1),
#   (('Yessssss', 'Julianne'), 1),
#   (('Yessssss', 'Julianne', 'Moore'), 1),
#   (('Moore', 'Alice', 'Congrats'), 1),
#   (('Alice', 'Heard'), 1),
#   (('Moore', 'Alice', 'Heard'), 1),
#   (('Movie', 'Alice'), 1),
#   (('Moore', 'Maps'), 1),
#   (('Maps', 'Stars'), 1),
#   (('Julianne', 'Moore', 'Maps'), 1),
#   (('Moore', 'Maps', 'Stars'), 1),
#   (('Film', 'Julianne'), 1),
#   (('Film', 'Julianne', 'Moore'), 1),
#   (('Julliane', 'Moore', 'Alice'), 1),
#   (('Alice', 'Nbc'), 1),
#   (('Juliane', 'Moore', 'Alice'), 1),
#   (('Alice', 'Awesome'), 1),
#   (('Alice', 'Yessss'), 1),
#   (('Moore', 'Alice', 'Yessss'), 1),
#   (('Moore', 'Glen'), 1),
#   (('Glen', 'Coco'), 1),
#   (('Julianne', 'Moore', 'Glen'), 1),
#   (('Moore', 'Glen', 'Coco'), 1),
#   (('Alice', 'Felicity'), 1),
#   (('Moore', 'Beauty'), 1),
#   (('Julianne', 'Moore', 'Beauty'), 1),
#   (('Moore', 'Canadian'), 1),
#   (('Julianne', 'Moore', 'Canadian'), 1),
#   (('Lead', 'Julianne'), 1),
#   (('Lead', 'Julianne', 'Moore'), 1),
#   (('Yay', 'Congrats'), 1),
#   (('Jen', 'Aniston', 'Felicity'), 1),
#   (('Pike', 'Reece'), 1),
#   (('Reece', 'Witherspoon'), 1),
#   (('Rosamund', 'Pike', 'Reece'), 1),
#   (('Pike', 'Reece', 'Witherspoon'), 1),
#   (('Winners', 'Julianne'), 1),
#   (('Awards', 'Winners', 'Julianne'), 1),
#   (('Winners', 'Julianne', 'Moore'), 1),
#   (('Alice', 'Yay'), 1),
#   (('Moore', 'Alice', 'Yay'), 1),
#   (('Alice', 'Pic'), 1),
#   (('Moore', 'Alice', 'Pic'), 1),
#   (('Alice', 'Starling'), 1),
#   (('Actress', 'Julianne'), 1),
#   (('Actress', 'Julianne', 'Moore'), 1),
#   (('Tonight', 'Julianne'), 1),
#   (('Tonight', 'Julianne', 'Moore'), 1),
#   (('Yeeeah', 'Julianne'), 1),
#   (('Moore', 'Movie'), 1),
#   (('Yeeeah', 'Julianne', 'Moore'), 1),
#   (('Julianne', 'Moore', 'Movie'), 1),
#   (('Eddie', 'Redmanye'), 1),
#   (('Actor', 'Eddie', 'Redmanye'), 1),
#   (('Julianne', 'Moor'), 1),
#   (('Moor', 'Alice'), 1),
#   (('Alice', 'Noooo'), 1),
#   (('Julianne', 'Moor', 'Alice'), 1),
#   (('Moor', 'Alice', 'Noooo'), 1),
#   (('Crazy', 'Amy'), 1),
#   (('Amy', 'Julianne'), 1),
#   (('Crazy', 'Amy', 'Julianne'), 1),
#   (('Amy', 'Julianne', 'Moore'), 1),
#   (('Theater', 'News'), 1),
#   (('News', 'Fox'), 1),
#   (('Alright', 'Jennifer'), 1),
#   (('Redmayne', 'Actor'), 1),
#   (('Alright', 'Jennifer', 'Aniston'), 1),
#   (('Eddie', 'Redmayne', 'Actor'), 1),
#   (('Moore', 'Eddie'), 1),
#   (('Julianne', 'Moore', 'Eddie'), 1),
#   (('Moore', 'Eddie', 'Redmayne'), 1),
#   (('Winners', 'Actor'), 1),
#   (('Actor', 'Movie'), 1),
#   (('Simmons', 'Whiplash'), 1),
#   (('Winners', 'Actor', 'Movie'), 1),
#   (('Alice', 'Yayy'), 1),
#   (('Moore', 'Alice', 'Yayy'), 1),
#   (('Cinefo', 'News'), 1),
#   (('Cinefo', 'News', 'Fandango'), 1),
#   (('Wins', 'Alice'), 1),
#   (('Eyes', 'Movie', 'Julianne'), 1),
#   (('Moore', 'Wins', 'Alice'), 1),
#   (('Alice', 'Job'), 1),
#   (('Witherspoon', 'Nominee'), 1),
#   (('Nominee', 'Wi'), 1),
#   (('Reese', 'Witherspoon', 'Nominee'), 1),
#   (('Witherspoon', 'Nominee', 'Wi'), 1),
#   (('Congratulations', 'Winner'), 1),
#   (('Congratulations', 'Winner', 'Julianne'), 1),
#   (('Director', 'Clap'), 1),
#   (('Boyhood', 'Director', 'Clap'), 1),
#   (('Wins', 'Read'), 1),
#   (('Moore', 'Wins', 'Read'), 1),
#   (('Woodley', 'Oscar'), 1),
#   (('Shailene', 'Woodley', 'Oscar'), 1),
#   (('Affair', 'Bien'), 1),
#   (('Video', 'Julianne', 'Moore'), 1),
#   (('Actor', 'George'), 1),
#   (('George', 'Clooney'), 1),
#   (('Actor', 'George', 'Clooney'), 1),
#   (('Foto', 'Julianne'), 1),
#   (('Foto', 'Julianne', 'Moore'), 1),
#   (('Onstage', 'Moore'), 1),
#   (('Alice', 'Whooopp'), 1),
#   (('Alice', 'Oscarnow'), 1),
#   (('Congratulation', 'Julianne'), 1),
#   (('Congratulation', 'Julianne', 'Moore'), 1),
#   (('Awards', 'Lead'), 1),
#   (('Lead', 'Actor'), 1),
#   (('Redmayne', 'Lead'), 1),
#   (('Lead', 'Moore'), 1),
#   (('Awards', 'Lead', 'Actor'), 1),
#   (('Lead', 'Actor', 'Eddie'), 1),
#   (('Actor', 'Eddie', 'Redmayne'), 1),
#   (('Eddie', 'Redmayne', 'Lead'), 1),
#   (('Redmayne', 'Lead', 'Moore'), 1),
#   (('Moore', 'Acceptance'), 1),
#   (('Acceptance', 'Speech'), 1),
#   (('Julianne', 'Moore', 'Acceptance'), 1),
#   (('Moore', 'Acceptance', 'Speech'), 1)],
#  'best performance by an actor in a motion picture - drama': [(('Eddie',
#     'Redmayne'),
#    3268),
#   (('Eddie', 'Redmanye'), 2334),
#   (('Redmanye', 'Theory'), 2287),
#   (('Eddie', 'Redmanye', 'Theory'), 2286),
#   (('Redmayne', 'Theory'), 757),
#   (('Eddie', 'Redmayne', 'Theory'), 753),
#   (('Congrats', 'Eddie'), 550),
#   (('Congrats', 'Eddie', 'Redmayne'), 512),
#   (('Kevin', 'Spacey'), 415),
#   (('Theory', 'Everything’'), 365),
#   (('Winner', 'Eddie'), 240),
#   (('Winner', 'Eddie', 'Redmayne'), 239),
#   (('Redmayne', 'Wins'), 175),
#   (('Eddie', 'Redmayne', 'Wins'), 175),
#   (('Wins', 'Award'), 64),
#   (('Stephen', 'Hawking'), 62),
#   (('Redmayne', 'Wins', 'Award'), 58),
#   (('Culturalist', 'Retweet'), 41),
#   (('Hawking', 'Theory'), 40),
#   (('Congrats', 'Eddie', 'Redmanye'), 38),
#   (('Stephen', 'Hawking', 'Theory'), 38),
#   (('Theory', 'Everything”'), 28),
#   (('Redmayne', 'Winner'), 23),
#   (('Eddie', 'Redmayne', 'Winner'), 23),
#   (('Culturalist', 'Congrats'), 22),
#   (('Culturalist', 'Congrats', 'Eddie'), 22),
#   (('David', 'Oyelowo'), 14),
#   (('Theory', 'Eddie'), 14),
#   (('Benedict', 'Cumberbatch'), 13),
#   (('Wins', 'Awards'), 12),
#   (('Redmayne', 'Wins', 'Awards'), 12),
#   (('Eddie', 'Radmayne'), 11),
#   (('Radmayne', 'Theory'), 11),
#   (('Eddie', 'Radmayne', 'Theory'), 11),
#   (('Pemenang', 'Eddie'), 11),
#   (('Pemenang', 'Eddie', 'Redmayne'), 11),
#   (('Theory', 'Eddie', 'Redmayne'), 11),
#   (('Jake', 'Gyllenhaal'), 10),
#   (('House', 'Cards'), 10),
#   (('Redmayne', 'Theory', 'Everything”'), 10),
#   (('Congrats', 'School'), 9),
#   (('Movie', 'Normal'), 9),
#   (('Black', 'List'), 8),
#   (('Michael', 'Keaton'), 8),
#   (('Award', 'Theor…'), 8),
#   (('Steve', 'Carell'), 7),
#   (('Zapit', 'Congrats'), 7),
#   (('Zapit', 'Congrats', 'Eddie'), 7),
#   (('Theory', 'Everythings'), 7),
#   (('Everythings', 'Eddie'), 7),
#   (('Theory', 'Everythings', 'Eddie'), 7),
#   (('Everythings', 'Eddie', 'Redmayne'), 7),
#   (('Carell', 'Benedict'), 6),
#   (('Steve', 'Carell', 'Benedict'), 6),
#   (('Carell', 'Benedict', 'Cumberbatch'), 6),
#   (('Julianne', 'Moore'), 6),
#   (('Redmayne', 'Eddie'), 6),
#   (('Eddie', 'Wins'), 6),
#   (('Eddie', 'Redmayne', 'Eddie'), 6),
#   (('Redmayne', 'Eddie', 'Wins'), 6),
#   (('Eddie', 'Wins', 'Award'), 6),
#   (('Gwyneth', 'Paltrow'), 6),
#   (('Congratulations', 'Eddie'), 6),
#   (('Congratulations', 'Eddie', 'Redmayne'), 6),
#   (('Cumberbatch', 'Jake'), 5),
#   (('Gyllenhaal', 'David'), 5),
#   (('Benedict', 'Cumberbatch', 'Jake'), 5),
#   (('Cumberbatch', 'Jake', 'Gyllenhaal'), 5),
#   (('Jake', 'Gyllenhaal', 'David'), 5),
#   (('Theory', 'Congrats'), 5),
#   (('Theory', 'Track'), 5),
#   (('Theory', 'Gran'), 5),
#   (('Redmanye', 'Theory', 'Gran'), 5),
#   (('Yahoo', 'Eddie'), 5),
#   (('Yahoo', 'Eddie', 'Redmayne'), 5),
#   (('Awards', 'Sunday'), 5),
#   (('Wins', 'Awards', 'Sunday'), 5),
#   (('Keaton', 'Comedy'), 5),
#   (('Oyelowo', 'Black'), 4),
#   (('David', 'Oyelowo', 'Black'), 4),
#   (('Oyelowo', 'Black', 'List'), 4),
#   (('Series', 'House'), 4),
#   (('Cards', 'Track'), 4),
#   (('Series', 'House', 'Cards'), 4),
#   (('House', 'Cards', 'Track'), 4),
#   (('Theory', 'Movie'), 4),
#   (('Eddie', 'Redmaynes'), 4),
#   (('Redmayne', 'Julianne'), 4),
#   (('Moore', 'Actress'), 4),
#   (('Eddie', 'Redmayne', 'Julianne'), 4),
#   (('Redmayne', 'Julianne', 'Moore'), 4),
#   (('Julianne', 'Moore', 'Actress'), 4),
#   (('Yesssss', 'Theory'), 4),
#   (('Yesssss', 'Theory', 'Everythings'), 4),
#   (('Theory', 'Stephen'), 4),
#   (('Redmayne', 'Theory', 'Stephen'), 4),
#   (('Theory', 'Stephen', 'Hawking'), 4),
#   (('Gran', 'Estre…'), 4),
#   (('Theory', 'Gran', 'Estre…'), 4),
#   (('Congrats', 'West'), 4),
#   (('Comedy', 'Photo'), 4),
#   (('Michael', 'Keaton', 'Comedy'), 4),
#   (('Keaton', 'Comedy', 'Photo'), 4),
#   (('Movie', 'Steve'), 3),
#   (('Oyelowo', 'Eddie'), 3),
#   (('Movie', 'Steve', 'Carell'), 3),
#   (('Gyllenhaal', 'David', 'Oyelowo'), 3),
#   (('David', 'Oyelowo', 'Eddie'), 3),
#   (('Oyelowo', 'Eddie', 'Redmayne'), 3),
#   (('Spacey', 'House'), 3),
#   (('Kevin', 'Spacey', 'House'), 3),
#   (('Spacey', 'House', 'Cards'), 3),
#   (('Imitation', 'Game'), 3),
#   (('Movie', 'Eddie'), 3),
#   (('Movie', 'Eddie', 'Redmayne'), 3),
#   (('Redmayne', 'Yay'), 3),
#   (('Eddie', 'Redmayne', 'Yay'), 3),
#   (('Winning', 'Eddie'), 3),
#   (('Winning', 'Eddie', 'Redmayne'), 3),
#   (('Redmanye', 'Theory', 'Eddie'), 3),
#   (('Double', 'Eddie'), 3),
#   (('Double', 'Eddie', 'Redmanye'), 3),
#   (('Yay', 'Eddie'), 3),
#   (('Wow', 'Eddie'), 3),
#   (('Wow', 'Eddie', 'Redmanye'), 3),
#   (('Theory', 'Calls'), 3),
#   (('Redmanye', 'Theory', 'Congrats'), 3),
#   (('Wellwellwell', 'Eddie'), 3),
#   (('Redmayne', 'Brits'), 3),
#   (('Wellwellwell', 'Eddie', 'Redmayne'), 3),
#   (('Eddie', 'Redmayne', 'Brits'), 3),
#   (('Photoset', 'Benedict'), 3),
#   (('Wins', 'Redmayne'), 3),
#   (('Redmayne', 'Wins', 'Redmayne'), 3),
#   (('Cumberbatch', 'Black'), 2),
#   (('Benedict', 'Cumberbatch', 'Black'), 2),
#   (('Cumberbatch', 'Black', 'List'), 2),
#   (('Beautiful', 'Mind'), 2),
#   (('Mind', 'Day'), 2),
#   (('Beautiful', 'Mind', 'Day'), 2),
#   (('David', 'Oye…'), 2),
#   (('Gyllenhaal', 'David', 'Oye…'), 2),
#   (('Simmons', 'Whiplash'), 2),
#   (('Winner', 'Kevin'), 2),
#   (('Winner', 'Kevin', 'Spacey'), 2),
#   (('Original', 'Score'), 2),
#   (('Keaton', 'Birdman'), 2),
#   (('Michael', 'Keaton', 'Birdman'), 2),
#   (('Redmayne', 'Theory', 'Movie'), 2),
#   (('Movie', 'Theory'), 2),
#   (('Redmayne', 'Theory', 'Congrats'), 2),
#   (('Theory', 'Totally'), 2),
#   (('Newcomer', 'Eddie'), 2),
#   (('Newcomer', 'Eddie', 'Redmayne'), 2),
#   (('Cumberbatch', 'Imitation'), 2),
#   (('Benedict', 'Cumberbatch', 'Imitation'), 2),
#   (('Cumberbatch', 'Imitation', 'Game'), 2),
#   (('Finally', 'Eddie'), 2),
#   (('Finally', 'Eddie', 'Redmanye'), 2),
#   (('Mejor', 'Eddie'), 2),
#   (('Mejor', 'Eddie', 'Redmayne'), 2),
#   (('Awards', 'Winners'), 2),
#   (('Bingo', 'Eddie'), 2),
#   (('Redmayne', 'Break'), 2),
#   (('Bingo', 'Eddie', 'Redmayne'), 2),
#   (('Eddie', 'Redmayne', 'Break'), 2),
#   (('Lead', 'Eddie'), 2),
#   (('Lead', 'Eddie', 'Redmayne'), 2),
#   (('Redmanye', 'Steven'), 2),
#   (('Steven', 'Hawking'), 2),
#   (('Eddie', 'Redmanye', 'Steven'), 2),
#   (('Redmanye', 'Steven', 'Hawking'), 2),
#   (('Steven', 'Hawking', 'Theory'), 2),
#   (('Wins', 'Theory'), 2),
#   (('Redmayne', 'Wins', 'Theory'), 2),
#   (('Complete', 'List'), 2),
#   (('Theory', 'Everything”gtmerecido'), 2),
#   (('Redmanye', 'Theory', 'Everything”gtmerecido'), 2),
#   (('Wins', 'Read'), 2),
#   (('Redmayne', 'Wins', 'Read'), 2),
#   (('George', 'Clooney'), 2),
#   (('Theory', 'Photo'), 2),
#   (('Redmayne', 'Theory', 'Photo'), 2),
#   (('Redmayne', 'Woke'), 2),
#   (('Eddie', 'Redmayne', 'Woke'), 2),
#   (('Predictions', 'Film'), 1),
#   (('Rose', 'Pike'), 1),
#   (('Awards', 'Steve'), 1),
#   (('Awards', 'Steve', 'Carell'), 1),
#   (('Predictions', 'Eddie'), 1),
#   (('Predictions', 'Eddie', 'Redmayne'), 1),
#   (('Redmayne', 'Steve'), 1),
#   (('Cumberbatch', 'David'), 1),
#   (('Oyelowo', 'Jake'), 1),
#   (('Eddie', 'Redmayne', 'Steve'), 1),
#   (('Redmayne', 'Steve', 'Carell'), 1),
#   (('Benedict', 'Cumberbatch', 'David'), 1),
#   (('Cumberbatch', 'David', 'Oyelowo'), 1),
#   (('David', 'Oyelowo', 'Jake'), 1),
#   (('Oyelowo', 'Jake', 'Gyllenhaal'), 1),
#   (('Boyhood', 'Comedy'), 1),
#   (('Comedy', 'Birdman'), 1),
#   (('Birdman', 'Redmayne'), 1),
#   (('Redmayne', 'Comedy'), 1),
#   (('Comedy', 'Keaton'), 1),
#   (('Keaton', 'Actress'), 1),
#   (('Actress', 'Moore'), 1),
#   (('Moore', 'Comedy'), 1),
#   (('Comedy', 'Adams'), 1),
#   (('Boyhood', 'Comedy', 'Birdman'), 1),
#   (('Comedy', 'Birdman', 'Redmayne'), 1),
#   (('Birdman', 'Redmayne', 'Comedy'), 1),
#   (('Redmayne', 'Comedy', 'Keaton'), 1),
#   (('Comedy', 'Keaton', 'Actress'), 1),
#   (('Keaton', 'Actress', 'Moore'), 1),
#   (('Actress', 'Moore', 'Comedy'), 1),
#   (('Moore', 'Comedy', 'Adams'), 1),
#   (('Steve', 'Carrell'), 1),
#   (('Carrell', 'Jake'), 1),
#   (('Steve', 'Carrell', 'Jake'), 1),
#   (('Carrell', 'Jake', 'Gyllenhaal'), 1),
#   (('Series', 'Check'), 1),
#   (('Television', 'Series'), 1),
#   (('Series', 'Kevin'), 1),
#   (('Television', 'Series', 'Kevin'), 1),
#   (('Series', 'Kevin', 'Spacey'), 1),
#   (('Boy', 'Kevin'), 1),
#   (('Award', 'House'), 1),
#   (('Boy', 'Kevin', 'Spacey'), 1),
#   (('Award', 'House', 'Cards'), 1),
#   (('Spacey', 'Original'), 1),
#   (('Score', 'Movie'), 1),
#   (('Movie', 'Imitation'), 1),
#   (('Kevin', 'Spacey', 'Original'), 1),
#   (('Spacey', 'Original', 'Score'), 1),
#   (('Original', 'Score', 'Movie'), 1),
#   (('Score', 'Movie', 'Imitation'), 1),
#   (('Movie', 'Imitation', 'Game'), 1),
#   (('Keaton', 'Batman'), 1),
#   (('Stellar', 'Birdman'), 1),
#   (('Michael', 'Keaton', 'Batman'), 1),
#   (('Keaton', 'Grand'), 1),
#   (('Grand', 'Budapest'), 1),
#   (('Keaton', 'Grand', 'Budapest'), 1),
#   (('Female', 'Julianne'), 1),
#   (('Moore', 'Alice'), 1),
#   (('Female', 'Julianne', 'Moore'), 1),
#   (('Julianne', 'Moore', 'Alice'), 1),
#   (('Theory', 'Nbc'), 1),
#   (('Eddie', 'Redemayne'), 1),
#   (('Redemayne', 'Theory'), 1),
#   (('Eddie', 'Redemayne', 'Theory'), 1),
#   (('Theory', 'Nominees'), 1),
#   (('Redmayne', 'Theory', 'Nominees'), 1),
#   (('Redmayne', 'Congrats'), 1),
#   (('Winner', 'Eddie', 'Redmanye'), 1),
#   (('Award', 'Theory'), 1),
#   (('Redmayne', 'Fuck'), 1),
#   (('Eddie', 'Redmayne', 'Fuck'), 1),
#   (('Whoa', 'Bye'), 1),
#   (('Benedict', 'Eddie'), 1),
#   (('Benedict', 'Eddie', 'Redmayne'), 1),
#   (('Wow', 'Amazing'), 1),
#   (('Amazing', 'Congrats'), 1),
#   (('Wow', 'Amazing', 'Congrats'), 1),
#   (('Amazing', 'Congrats', 'Eddie'), 1),
#   (('Theory', 'Yay'), 1),
#   (('Theory', 'Yay', 'Eddie'), 1),
#   (('Plottwist', 'Eddie'), 1),
#   (('Plottwist', 'Eddie', 'Redmanye'), 1),
#   (('Theory', 'Woooo'), 1),
#   (('Redmanye', 'Theory', 'Woooo'), 1),
#   (('Theory', 'Yaaaas🙌'), 1),
#   (('Inspiring', 'Stephen'), 1),
#   (('Inspiring', 'Stephen', 'Hawking'), 1),
#   (('Redmanye', 'Theory', 'Everything”'), 1),
#   (('Gwan', 'Eddie'), 1),
#   (('Eddie', 'Eddie'), 1),
#   (('Gwan', 'Eddie', 'Eddie'), 1),
#   (('Eddie', 'Eddie', 'Redmanye'), 1),
#   (('Boom', 'Eddie'), 1),
#   (('Boom', 'Eddie', 'Redmayne'), 1),
#   (('Eddie', 'Raynmane'), 1),
#   (('Beat', 'Theory'), 1),
#   (('Theory', 'Enfim'), 1),
#   (('Redmanye', 'Theory', 'Enfim'), 1),
#   (('Wins', 'Movie'), 1),
#   (('Congrats', 'Eddie💙💜💛'), 1),
#   (('Theory', 'Congrats', 'Eddie💙💜💛'), 1),
#   (('Theory', 'Yeaahh'), 1),
#   (('Eddie', 'Redmayne”'), 1),
#   (('Theory', 'Cong…'), 1),
#   (('Redmanye', 'Theory', 'Cong…'), 1),
#   (('Everything”', 'Yay'), 1),
#   (('Theory', 'Everything”', 'Yay'), 1),
#   (('Foxactress', 'Eddie'), 1),
#   (('Foxactress', 'Eddie', 'Redmanye'), 1),
#   (('Cumberbitch', 'Oscars'), 1),
#   (('Redmayne', 'Theory', 'Everything’'), 1),
#   (('Theory', 'Loved'), 1),
#   (('Winners', 'Eddie'), 1),
#   (('Awards', 'Winners', 'Eddie'), 1),
#   (('Winners', 'Eddie', 'Redmayne'), 1),
#   (('Redmayne', 'Amazing'), 1),
#   (('Eddie', 'Redmayne', 'Amazing'), 1),
#   (('News', 'Congrats'), 1),
#   (('News', 'Congrats', 'Eddie'), 1),
#   (('Male', 'Eddie'), 1),
#   (('Male', 'Eddie', 'Redmayne'), 1),
#   (('Redmayne', 'Award'), 1),
#   (('Award', 'Lead'), 1),
#   (('Eddie', 'Redmayne', 'Award'), 1),
#   (('Redmayne', 'Award', 'Lead'), 1),
#   (('Congrats', 'Eddie❗❗❗❗❗❗❗❗❗❗'), 1),
#   (('Theory', 'Congrats', 'Eddie❗❗❗❗❗❗❗❗❗❗'), 1),
#   (('Theory', 'Hawking'), 1),
#   (('Redmanye', 'Theory', 'Hawking'), 1),
#   (('Redmayne', 'Movie'), 1),
#   (('Eddie', 'Redmayne', 'Movie'), 1),
#   (('Redmayne', 'Movie', 'Theory'), 1),
#   (('Theater', 'News'), 1),
#   (('Redmayne', 'Stephen'), 1),
#   (('Eddie', 'Redmayne', 'Stephen'), 1),
#   (('Redmayne', 'Stephen', 'Hawking'), 1),
#   (('Gran', 'Estreno'), 1),
#   (('Estreno', 'Enero'), 1),
#   (('Theory', 'Gran', 'Estreno'), 1),
#   (('Gran', 'Estreno', 'Enero'), 1),
#   (('Theory', 'Jamie'), 1),
#   (('Redmanye', 'Theory', 'Jamie'), 1),
#   (('Hay', 'Eddie'), 1),
#   (('Hay', 'Eddie', 'Redmanye'), 1),
#   (('Coopstv', 'Wellwellwell'), 1),
#   (('Coopstv', 'Wellwellwell', 'Eddie'), 1),
#   (('Alright', 'Jennifer'), 1),
#   (('Jennifer', 'Aniston'), 1),
#   (('Actress', 'Eddie'), 1),
#   (('Alright', 'Jennifer', 'Aniston'), 1),
#   (('Actress', 'Eddie', 'Redmayne'), 1),
#   (('Yay', 'Eddie', 'Redmayne'), 1),
#   (('Theory', 'Original'), 1),
#   (('Theory', 'Original', 'Score'), 1),
#   (('Woooow', 'Congrats'), 1),
#   (('Brilliant', 'Eddie'), 1),
#   (('Brilliant', 'Eddie', 'Redmayne'), 1),
#   (('Theory', 'Everything”👏👏👏'), 1),
#   (('Wins', 'Theory', 'Movie'), 1),
#   (('Moore', 'Eddie'), 1),
#   (('Julianne', 'Moore', 'Eddie'), 1),
#   (('Moore', 'Eddie', 'Redmayne'), 1),
#   (('List', 'Winners'), 1),
#   (('Complete', 'List', 'Winners'), 1),
#   (('Redmayne', 'Deserve💜'), 1),
#   (('Eddie', 'Redmayne', 'Deserve💜'), 1),
#   (('Winners', 'Movie'), 1),
#   (('Whiplash', 'Actress'), 1),
#   (('Simmons', 'Whiplash', 'Actress'), 1),
#   (('Eddie', 'Remayne'), 1),
#   (('Eddie', 'Redmay'), 1),
#   (('Wow', 'Expected'), 1),
#   (('Category', 'Congrats'), 1),
#   (('Redmayne', 'Theor'), 1),
#   (('Eddie', 'Redmayne', 'Theor'), 1),
#   (('Congrats', 'Eddie😍'), 1),
#   (('Theory', 'Congrats', 'Eddie😍'), 1),
#   (('Yeayyyyyyyyyyyy', 'Eddie'), 1),
#   (('Yeayyyyyyyyyyyy', 'Eddie', 'Redmanye'), 1),
#   (('Eyes', 'Movie'), 1),
#   (('Theory', 'Eve'), 1),
#   (('Eyes', 'Movie', 'Eddie'), 1),
#   (('Wins', 'Theory', 'Eve'), 1),
#   (('People', 'Eddie'), 1),
#   (('People', 'Eddie', 'Redmayne'), 1),
#   (('Congrats', 'Kristens'), 1),
#   (('Award', 'Winners'), 1),
#   (('Award', 'George'), 1),
#   (('Clooney', 'Boyhood'), 1),
#   (('Award', 'George', 'Clooney'), 1),
#   (('George', 'Clooney', 'Boyhood'), 1),
#   (('Theory', 'Redmayne'), 1),
#   (('Redmanye', 'Theory', 'Redmayne'), 1),
#   (('Theory', 'Aqualice'), 1),
#   (('Redmayne', 'Theory', 'Aqualice'), 1),
#   (('Redmayne', 'Congratulations'), 1),
#   (('Eddie', 'Redmayne', 'Congratulations'), 1),
#   (('Award', 'Kim'), 1),
#   (('Kim', 'Jung'), 1),
#   (('Jung', 'Dumb'), 1),
#   (('Wins', 'Award', 'Kim'), 1),
#   (('Award', 'Kim', 'Jung'), 1),
#   (('Kim', 'Jung', 'Dumb'), 1),
#   (('Yeeeees', 'Eddie'), 1),
#   (('Yeeeees', 'Eddie', 'Redmanye'), 1),
#   (('Redmayne', 'Totally'), 1),
#   (('Eddie', 'Redmayne', 'Totally'), 1),
#   (('Spacey', 'Bleeped'), 1),
#   (('Bleeped', 'Accepting'), 1),
#   (('Accepting', 'Series'), 1),
#   (('Series', 'Frank'), 1),
#   (('Kevin', 'Spacey', 'Bleeped'), 1),
#   (('Spacey', 'Bleeped', 'Accepting'), 1),
#   (('Bleeped', 'Accepting', 'Series'), 1),
#   (('Accepting', 'Series', 'Frank'), 1),
#   (('Frank', 'Underwood'), 1),
#   (('Theory', 'Everything”a'), 1),
#   (('Boyhood', 'Wins'), 1),
#   (('Wins', 'Film'), 1),
#   (('Film', 'Winner'), 1),
#   (('Winner', 'List'), 1),
#   (('List', 'Unveiled'), 1),
#   (('Unveiled', 'Eddie'), 1),
#   (('Boyhood', 'Wins', 'Film'), 1),
#   (('Wins', 'Film', 'Winner'), 1),
#   (('Film', 'Winner', 'List'), 1),
#   (('Winner', 'List', 'Unveiled'), 1),
#   (('List', 'Unveiled', 'Eddie'), 1),
#   (('Unveiled', 'Eddie', 'Redmayne'), 1),
#   (('Brilliant“IMDb', 'Winner'), 1),
#   (('Brilliant“IMDb', 'Winner', 'Eddie'), 1),
#   (('Theory', 'Deserved'), 1),
#   (('Redmayne', 'Theory', 'Deserved'), 1),
#   (('Theory', 'Brb'), 1),
#   (('Redmanye', 'Theory', 'Brb'), 1),
#   (('Actress', 'George'), 1),
#   (('Actress', 'George', 'Clooney'), 1),
#   (('Zen', 'Events'), 1),
#   (('Events', 'Eddie'), 1),
#   (('Zen', 'Events', 'Eddie'), 1),
#   (('Events', 'Eddie', 'Redmayne'), 1),
#   (('Foto', 'Eddie'), 1),
#   (('Foto', 'Eddie', 'Redmayne'), 1),
#   (('Congrats', 'Eddieeeee'), 1),
#   (('Eddieeeee', 'Eddie'), 1),
#   (('Congrats', 'Eddieeeee', 'Eddie'), 1),
#   (('Eddieeeee', 'Eddie', 'Redmanye'), 1),
#   (('Theory', 'Brendameiqi'), 1),
#   (('Redmanye', 'Theory', 'Brendameiqi'), 1),
#   (('Photoset', 'Eddie'), 1),
#   (('Photoset', 'Eddie', 'Redmayne'), 1),
#   (('Bilderserie', 'Benedict'), 1),
#   (('Winners', 'Complete'), 1),
#   (('Eddie', 'Redma'), 1),
#   (('Winners', 'Complete', 'List'), 1),
#   (('Awards', 'Lead'), 1),
#   (('Redmayne', 'Lead'), 1),
#   (('Awards', 'Lead', 'Eddie'), 1),
#   (('Eddie', 'Redmayne', 'Lead'), 1),
#   (('Yay', 'Eddie', 'Redmanye'), 1)],
#  'best performance by an actress in a motion picture - comedy or musical': [(('Amy',
#     'Adams'),
#    3511),
#   (('Adams', 'Eyes'), 2325),
#   (('Amy', 'Adams', 'Eyes'), 2320),
#   (('Adams', 'Takes'), 166),
#   (('Amy', 'Adams', 'Takes'), 166),
#   (('Congratulations', 'Amy'), 111),
#   (('Congratulations', 'Amy', 'Adams'), 111),
#   (('Gina', 'Rodriguez'), 86),
#   (('Variety', 'Amy'), 76),
#   (('Variety', 'Amy', 'Adams'), 76),
#   (('Adams', 'Wins'), 69),
#   (('Amy', 'Adams', 'Wins'), 69),
#   (('Congrats', 'Amy'), 44),
#   (('Congrats', 'Amy', 'Adams'), 34),
#   (('Marilyn', 'Monroe'), 23),
#   (('Monroe', 'Hot'), 23),
#   (('Marilyn', 'Monroe', 'Hot'), 23),
#   (('Adams', 'Movie'), 18),
#   (('Amy', 'Adams', 'Movie'), 18),
#   (('Zapit', 'Congrats'), 16),
#   (('Pemenang', 'Amy'), 13),
#   (('Pemenang', 'Amy', 'Adams'), 13),
#   (('Winner', 'Amy'), 12),
#   (('Winner', 'Amy', 'Adams'), 12),
#   (('Movie', 'Amy'), 9),
#   (('Movie', 'Amy', 'Adams'), 9),
#   (('Congrats', 'Henry'), 9),
#   (('Henry', 'Cavills'), 9),
#   (('Congrats', 'Henry', 'Cavills'), 9),
#   (('Adams', 'Reuters'), 9),
#   (('Amy', 'Adams', 'Reuters'), 9),
#   (('Eyes', 'Congrats'), 8),
#   (('Emily', 'Blunt'), 7),
#   (('Adams', 'Eyes', 'Congrats'), 7),
#   (('Wins', 'Awards'), 7),
#   (('Adams', 'Wins', 'Awards'), 7),
#   (('Jane', 'Virgin'), 6),
#   (('Eyes', 'Congrats', 'Amy'), 6),
#   (('Eyes', 'Photo'), 6),
#   (('Adams', 'Eyes', 'Photo'), 6),
#   (('Patricia', 'Arquette'), 6),
#   (('Amy', 'Amy'), 5),
#   (('Amy', 'Amy', 'Adams'), 5),
#   (('Wins', 'Awar'), 5),
#   (('Adams', 'Wins', 'Awar'), 5),
#   (('Helen', 'Mirren'), 4),
#   (('Ricky', 'Gervais'), 4),
#   (('Adams', 'Winner'), 4),
#   (('Amy', 'Adams', 'Winner'), 4),
#   (('Congrats', 'Amy', 'Amy'), 4),
#   (('Amy', 'Ada'), 4),
#   (('Julianne', 'Moore'), 3),
#   (('Adams', 'Emily'), 3),
#   (('Blunt', 'Helen'), 3),
#   (('Amy', 'Adams', 'Emily'), 3),
#   (('Adams', 'Emily', 'Blunt'), 3),
#   (('Emily', 'Blunt', 'Helen'), 3),
#   (('Blunt', 'Helen', 'Mirren'), 3),
#   (('Series', 'Gina'), 3),
#   (('Series', 'Gina', 'Rodriguez'), 3),
#   (('Lead', 'Amy'), 3),
#   (('Lead', 'Amy', 'Adams'), 3),
#   (('Culturalist', 'Congrats'), 3),
#   (('Culturalist', 'Congrats', 'Amy'), 3),
#   (('News', 'Amy'), 3),
#   (('News', 'Amy', 'Adams'), 3),
#   (('Zellweger', 'Chicago'), 3),
#   (('Drama', 'Patricia'), 3),
#   (('Drama', 'Patricia', 'Arquette'), 3),
#   (('Marshatimothy', 'Amy'), 3),
#   (('Marshatimothy', 'Amy', 'Adams'), 3),
#   (('Grand', 'Budapest'), 2),
#   (('Budapest', 'Hotel'), 2),
#   (('Grand', 'Budapest', 'Hotel'), 2),
#   (('Mirren', 'Julianne'), 2),
#   (('Helen', 'Mirren', 'Julianne'), 2),
#   (('Mirren', 'Julianne', 'Moore'), 2),
#   (('Amy', 'Adam'), 2),
#   (('Adam', 'Eyes'), 2),
#   (('Amy', 'Adam', 'Eyes'), 2),
#   (('Linda', 'Linda'), 2),
#   (('Blunt', 'Amy'), 2),
#   (('Emily', 'Blunt', 'Amy'), 2),
#   (('Winning', 'Amy'), 2),
#   (('Winning', 'Amy', 'Adams'), 2),
#   (('Congrats', 'Winning'), 2),
#   (('Awards', 'Winners'), 2),
#   (('Adams', 'Amy'), 2),
#   (('Amy', 'Adams', 'Amy'), 2),
#   (('Adams', 'Amy', 'Adams'), 2),
#   (('Eyes', 'Variety'), 2),
#   (('Arquette', 'Boyhood'), 2),
#   (('Patricia', 'Arquette', 'Boyhood'), 2),
#   (('Amy', 'Hoo…'), 2),
#   (('Congrats', 'Amy', 'Hoo…'), 2),
#   (('Kstewartfans', 'Congrats'), 1),
#   (('Birdman', 'Emily'), 1),
#   (('Blunt', 'Actor'), 1),
#   (('Actor', 'Michael'), 1),
#   (('Michael', 'Keaton'), 1),
#   (('Birdman', 'Emily', 'Blunt'), 1),
#   (('Emily', 'Blunt', 'Actor'), 1),
#   (('Blunt', 'Actor', 'Michael'), 1),
#   (('Actor', 'Michael', 'Keaton'), 1),
#   (('Predictions', 'Amy'), 1),
#   (('Predictions', 'Amy', 'Adams'), 1),
#   (('Moore', 'Amy'), 1),
#   (('Julianne', 'Moore', 'Amy'), 1),
#   (('Moore', 'Amy', 'Adams'), 1),
#   (('Pike', 'Grand'), 1),
#   (('Pike', 'Grand', 'Budapest'), 1),
#   (('Television', 'Series'), 1),
#   (('Rodriguez', 'Jane'), 1),
#   (('Television', 'Series', 'Gina'), 1),
#   (('Gina', 'Rodriguez', 'Jane'), 1),
# ...
#   (('Freeman', 'Movie'), 1),
#   (('Movie', 'Award'), 1),
#   (('Fargo', 'True'), 1),
#   (('Thornton', 'Fargo', 'True'), 1),
#   (('Fargo', 'True', 'Detective'), 1),
#   (('Mark', 'Euffalo'), 1),
#   (('Movie', 'Offuckingcourse'), 1),
#   (('Love', 'Billy'), 1),
#   (('Love', 'Billy', 'Bob'), 1),
#   (('Congrats', 'Movie', 'Billy'), 1),
#   (('Agreed', 'Movie'), 1),
#   (('Agreed', 'Movie', 'Billy'), 1),
#   (('Fargo', 'Mashable'), 1),
#   (('Thornton', 'Fargo', 'Mashable'), 1),
#   (('Winners', 'Movie'), 1),
#   (('Winners', 'Movie', 'Billy'), 1),
#   (('Fargo', 'Movie', 'Fargo'), 1),
#   (('Awards', 'Movie', 'Billy'), 1),
#   (('Aces', 'Lorne'), 1),
#   (('Lorne', 'Malvo'), 1),
#   (('Malvo', 'Billy'), 1),
#   (('Aces', 'Lorne', 'Malvo'), 1),
#   (('Lorne', 'Malvo', 'Billy'), 1),
#   (('Malvo', 'Billy', 'Bob'), 1),
#   (('Movie', 'Awards'), 1),
#   (('Wins', 'Movie', 'Awards'), 1),
#   (('Katie', 'Holmes'), 1),
#   (('Holmes', 'Seth'), 1),
#   (('Seth', 'Meyers'), 1),
#   (('Katie', 'Holmes', 'Seth'), 1),
#   (('Holmes', 'Seth', 'Meyers'), 1),
#   (('Bomer', 'Deserved'), 1),
#   (('Matt', 'Bomer', 'Deserved'), 1),
#   (('Award', 'Movie', 'Matt'), 1),
#   (('Role', 'Matt…'), 1),
#   (('Bomer', 'Alan'), 1),
#   (('Alan', 'Cumming'), 1),
#   (('Cumming', 'Colin'), 1),
#   (('Colin', 'Hanks'), 1),
#   (('Hanks', 'Murray'), 1),
#   (('Murray', 'Jon'), 1),
#   (('Matt', 'Bomer', 'Alan'), 1),
#   (('Bomer', 'Alan', 'Cumming'), 1),
#   (('Alan', 'Cumming', 'Colin'), 1),
#   (('Cumming', 'Colin', 'Hanks'), 1),
#   (('Colin', 'Hanks', 'Murray'), 1),
#   (('Hanks', 'Murray', 'Jon'), 1),
#   (('Murray', 'Jon', 'Voight'), 1),
#   (('Normal', 'Fantastic'), 1),
#   (('Bomer', 'Normal', 'Fantastic'), 1),
#   (('Normal', 'Cute'), 1),
#   (('Movie', 'Normal', 'Cute'), 1),
#   (('Movie', 'Movie'), 1),
#   (('Bomer', 'Movie', 'Movie'), 1),
#   (('Murray', 'Angelina'), 1),
#   (('Angelina', 'Jolies'), 1),
#   (('Murray', 'Angelina', 'Jolies'), 1),
#   (('Supporting', 'Series'), 1),
#   (('Normal', 'Supporting', 'Series'), 1),
#   (('Supporting', 'Series', 'Movie'), 1),
#   (('Earned', 'Deserved'), 1),
#   (('Deserved', 'Movie'), 1),
#   (('Earned', 'Deserved', 'Movie'), 1),
#   (('Deserved', 'Movie', 'Matt'), 1),
#   (('Movie', 'Mark'), 1),
#   (('Ruffalo', 'Normal'), 1),
#   (('Normal', 'Congrats'), 1),
#   (('Movie', 'Mark', 'Ruffalo'), 1),
#   (('Mark', 'Ruffalo', 'Normal'), 1),
#   (('Ruffalo', 'Normal', 'Congrats'), 1),
#   (('Movie', 'Norma…'), 1),
#   (('Award', 'Movie', 'Norma…'), 1),
#   (('Normal', 'Awesome'), 1),
#   (('Bomer', 'Normal', 'Awesome'), 1),
#   (('Movie', 'Hungry'), 1),
#   (('Wins', 'Movie', 'Hungry'), 1),
#   (('Yaaaaaaay', 'Congrats'), 1),
#   (('Yaaaaaaay', 'Congrats', 'Matt'), 1),
#   (('Movie', 'Check'), 1),
#   (('Congratulations', 'Matt'), 1),
#   (('Bomer', 'Series'), 1),
#   (('Congratulations', 'Matt', 'Bomer'), 1),
#   (('Matt', 'Bomer', 'Series'), 1),
#   (('Bomer', 'Series', 'Movie'), 1),
#   (('Yay', 'Congrats'), 1),
#   (('Matt', 'Normal'), 1),
#   (('Movie', 'Matt', 'Normal'), 1),
#   (('Kristiturnquist', 'Matt'), 1),
#   (('Kristiturnquist', 'Matt', 'Bomer'), 1),
#   (('Bomer', 'Yay'), 1),
#   (('Matt', 'Bomer', 'Yay'), 1),
#   (('Comedy', 'Movie'), 1),
#   (('Movie', 'Jeffrey'), 1),
#   (('Jeffrey', 'Tambour'), 1),
#   (('Tambour', 'Transparent'), 1),
#   (('Comedy', 'Movie', 'Jeffrey'), 1),
#   (('Movie', 'Jeffrey', 'Tambour'), 1),
#   (('Jeffrey', 'Tambour', 'Transparent'), 1),
#   (('Movie', 'Photo'), 1),
#   (('Thornton', 'Movie', 'Photo'), 1),
#   (('Normal', 'Phot'), 1),
#   (('Movie', 'Normal', 'Phot'), 1),
#   (('Transparent', 'Track'), 1),
#   (('Comedy', 'Musical'), 1),
#   (('Musical', 'Transparent'), 1),
#   (('Comedy', 'Musical', 'Transparent'), 1),
#   (('Photo', 'Bomer'), 1),
#   (('Movie', 'Honorable'), 1),
#   (('Honorable', 'Woman'), 1),
#   (('Actress', 'Movie', 'Honorable'), 1),
#   (('Movie', 'Honorable', 'Woman'), 1),
#   (('Drama', 'Check'), 1),
#   (('Drama', 'Kevin'), 1),
#   (('Spacey', 'House'), 1),
#   (('Drama', 'Kevin', 'Spacey'), 1),
#   (('Kevin', 'Spacey', 'House'), 1),
#   (('Spacey', 'House', 'Cards'), 1),
#   (('Normal', 'Yay'), 1),
#   (('Bomer', 'Normal', 'Yay'), 1),
#   (('Leviathan', 'Drama'), 1),
#   (('Spacey', 'Original'), 1),
#   (('Original', 'Score'), 1),
#   (('Score', 'Movie'), 1),
#   (('Movie', 'Imitation'), 1),
#   (('Imitation', 'Game'), 1),
#   (('Kevin', 'Spacey', 'Original'), 1),
#   (('Spacey', 'Original', 'Score'), 1),
#   (('Original', 'Score', 'Movie'), 1),
#   (('Score', 'Movie', 'Imitation'), 1),
#   (('Movie', 'Imitation', 'Game'), 1),
#   (('Wins', 'Hooray'), 1),
#   (('Bomer', 'Wins', 'Hooray'), 1),
#   (('Movie', 'The…'), 1),
#   (('Bomer', 'Movie', 'The…'), 1),
#   (('Foto', 'Matt'), 1),
#   (('Foto', 'Matt', 'Bomer'), 1),
#   (('Bomer', 'Waaaah'), 1),
#   (('Waaaah', 'Wife'), 1),
#   (('Matt', 'Bomer', 'Waaaah'), 1),
#   (('Bomer', 'Waaaah', 'Wife'), 1),
#   (('Thornton', 'Movie', 'Fargo'), 1),
#   (('Grand', 'Budapest'), 1),
#   (('Budapest', 'Boyhood'), 1),
#   (('Grand', 'Budapest', 'Boyhood'), 1),
#   (('Spacey', 'Bleeped'), 1),
#   (('Bleeped', 'Accepting'), 1),
#   (('Accepting', 'Drama'), 1),
#   (('Drama', 'Frank'), 1),
#   (('Kevin', 'Spacey', 'Bleeped'), 1),
#   (('Spacey', 'Bleeped', 'Accepting'), 1),
#   (('Bleeped', 'Accepting', 'Drama'), 1),
#   (('Accepting', 'Drama', 'Frank'), 1),
#   (('Frank', 'Underwood'), 1),
#   (('Variety', 'Congrats'), 1),
#   (('Wonderful', 'Movie'), 1),
#   (('Wonderful', 'Movie', 'Billy'), 1)],
#  'best performance by an actress in a supporting role in a series, mini-series or motion picture made for television': [(('Joanne',
#     'Froggatt'),
#    2172),
#   (('Downton', 'Abbey'), 1863),
#   (('Movie', 'Joanne'), 1723),
#   (('Movie', 'Joanne', 'Froggatt'), 1716),
#   (('Froggatt', 'Downton'), 513),
#   (('Joanne', 'Froggatt', 'Downton'), 510),
#   (('Froggatt', 'Downton', 'Abbey'), 500),
#   (('Wins', 'Movie'), 105),
#   (('Froggatt', 'Wins'), 99),
#   (('Joanne', 'Froggatt', 'Wins'), 99),
#   (('Froggatt', 'Wins', 'Movie'), 99),
#   (('Movie', 'Downton'), 91),
#   (('Movie', 'Downton', 'Abbey'), 87),
#   (('Variety', 'Joanne'), 52),
#   (('Variety', 'Joanne', 'Froggatt'), 52),
#   (('Abbey', 'Joanne'), 34),
#   (('Downton', 'Abbey', 'Joanne'), 34),
#   (('Abbey', 'Joanne', 'Froggatt'), 34),
#   (('Movie', 'Wonderful'), 27),
#   (('Wins', 'Movie', 'Downton'), 21),
#   (('Movie', 'For…'), 18),
#   (('Wins', 'Movie', 'For…'), 18),
#   (('Movie', 'Dow'), 12),
#   (('Wins', 'Movie', 'Dow'), 12),
#   (('Joanne', 'Froggat'), 11),
#   (('Downton', 'Abbey”'), 10),
#   (('Froggat', 'Downton'), 9),
#   (('Joanne', 'Froggat', 'Downton'), 9),
#   (('Froggatt', 'Downton', 'Abbey”'), 9),
#   (('Froggat', 'Downton', 'Abbey'), 8),
#   (('Congrats', 'Joanne'), 8),
#   (('Congrats', 'Joanne', 'Froggatt'), 8),
#   (('Joanne', 'Fraggott'), 8),
#   (('Movie', 'Downt'), 8),
#   (('Wins', 'Movie', 'Downt'), 8),
#   (('Froggatt', 'Movie'), 7),
#   (('Winner', 'Movie'), 7),
#   (('Maggie', 'Gyllenhaal'), 7),
#   (('Movie', 'Joanne', 'Froggat'), 6),
#   (('Downton', 'Abbeys'), 5),
#   (('Abbeys', 'Joanne'), 5),
#   (('Downton', 'Abbeys', 'Joanne'), 5),
#   (('Abbeys', 'Joanne', 'Froggatt'), 5),
#   (('Fraggott', 'Movie'), 5),
#   (('Joanne', 'Fraggott', 'Movie'), 5),
#   (('Fraggott', 'Movie', 'Downton'), 5),
#   (('Movie', 'Awards'), 5),
#   (('Wins', 'Movie', 'Awards'), 5),
#   (('Movie', 'Maggie'), 5),
#   (('Movie', 'Maggie', 'Gyllenhaal'), 5),
#   (('Joanne', 'Froggatt', 'Movie'), 4),
#   (('Anna', 'Bates'), 4),
#   (('Culturalist', 'Congrats'), 4),
#   (('Abbey', 'Wins'), 4),
#   (('Abbey', 'Wins', 'Movie'), 4),
#   (('Movie', 'Winner'), 4),
#   (('Winner', 'Joanne'), 4),
#   (('Movie', 'Winner', 'Joanne'), 4),
#   (('Winner', 'Joanne', 'Froggatt'), 4),
#   (('Joann', 'Froggatt'), 4),
#   (('Downton', 'Abbe'), 3),
#   (('Froggatt', 'Downton', 'Abbe'), 3),
#   (('Downtown', 'Abbey'), 3),
#   (('Downton', 'Abbey', 'Wins'), 3),
#   (('Yay', 'Congrats'), 3),
#   (('Congrats', 'Joann'), 3),
#   (('Yay', 'Congrats', 'Joann'), 3),
#   (('Congrats', 'Joann', 'Froggatt'), 3),
#   (('Joann', 'Froggatt', 'Movie'), 3),
#   (('Abbey', 'Season'), 3),
#   (('Downton', 'Abbey', 'Season'), 3),
#   (('Movie', 'Froggatt'), 3),
#   (('Hey', 'Mister'), 3),
#   (('Mister', 'Bates'), 3),
#   (('Bates', 'Movie'), 3),
#   (('Hey', 'Mister', 'Bates'), 3),
#   (('Mister', 'Bates', 'Movie'), 3),
#   (('Fraggott', 'Movie…'), 3),
#   (('Joanne', 'Fraggott', 'Movie…'), 3),
#   (('Honorable', 'Woman’'), 3),
#   (('Honorable', 'Woman'), 3),
#   (('Movie', 'Downton', 'Abbeys'), 2),
#   (('Series', 'Movie'), 2),
#   (('Series', 'Movie', 'Joanne'), 2),
#   (('Movie', 'Joanna'), 2),
#   (('Deggans', 'Joanne'), 2),
#   (('Deggans', 'Joanne', 'Froggatt'), 2),
#   (('Winner', 'Movie', 'Joanne'), 2),
#   (('Yay', 'Joanne'), 2),
#   (('Joanne', 'Wins'), 2),
#   (('Joanne', 'Wins', 'Movie'), 2),
#   (('Gyllenhaal', 'Honorable'), 2),
#   (('Maggie', 'Gyllenhaal', 'Honorable'), 2),
#   (('Gyllenhaal', 'Honorable', 'Woman'), 2),
#   (('Awards', 'Movie'), 2),
#   (('Awards', 'Movie', 'Joanne'), 2),
#   (('Uzo', 'Aduba'), 1),
#   (('Yay', 'Anna'), 1),
#   (('Yay', 'Anna', 'Bates'), 1),
#   (('Surprise', 'Movie'), 1),
#   (('Surprise', 'Movie', 'Joanne'), 1),
#   (('Movie', 'Award'), 1),
#   (('Joanna', 'Froggatt'), 1),
#   (('Movie', 'Joanna', 'Froggatt'), 1),
#   (('Jane', 'Froggatt'), 1),
#   (('Congratulations', 'Joanne'), 1),
#   (('Congratulations', 'Joanne', 'Froggatt'), 1),
#   (('Movie”', 'Awesome'), 1),
#   (('Joanna', 'Frogatt'), 1),
#   (('Movie', 'Joanna', 'Frogatt'), 1),
#   (('Love', 'Movie'), 1),
#   (('Love', 'Movie', 'Joanne'), 1),
#   (('Joanne', 'Froghatt'), 1),
#   (('Froghatt', 'Downton'), 1),
#   (('Joanne', 'Froghatt', 'Downton'), 1),
#   (('Froghatt', 'Downton', 'Abbey'), 1),
#   (('Johane', 'Frogat'), 1),
#   (('Frogat', 'Downton'), 1),
#   (('Abbey', 'Movie'), 1),
#   (('Johane', 'Frogat', 'Downton'), 1),
#   (('Frogat', 'Downton', 'Abbey'), 1),
#   (('Downton', 'Abbey', 'Movie'), 1),
#   (('Kathy', 'Bates'), 1),
#   (('Downton', 'Abby'), 1),
#   (('Froggat', 'Downton', 'Abby'), 1),
#   (('Abbey', 'Julia'), 1),
#   (('Downton', 'Abbey', 'Julia'), 1),
#   (('Froggatt', 'Downtown'), 1),
#   (('Joanne', 'Froggatt', 'Downtown'), 1),
#   (('Froggatt', 'Downtown', 'Abbey'), 1),
#   (('Downtown', 'Abbey', 'Wins'), 1),
#   (('Abbey', 'Deserved'), 1),
#   (('Downton', 'Abbey', 'Deserved'), 1),
#   (('Congrats', 'Downton'), 1),
#   (('Congrats', 'Downton', 'Abbeys'), 1),
#   (('Movie', 'Joannie'), 1),
#   (('Joannie', 'Froggatt'), 1),
#   (('Movie', 'Joannie', 'Froggatt'), 1),
#   (('Movie', 'Congrats'), 1),
#   (('Movie', 'Congrats', 'Joanne'), 1),
#   (('Movie', 'Anna'), 1),
#   (('Yay', 'Joanne', 'Froggatt'), 1),
#   (('Dakota', 'Johnson'), 1),
#   (('Coopstv', 'Movie'), 1),
#   (('Coopstv', 'Movie', 'Joanne'), 1),
#   (('Froggatt', 'Yay'), 1),
#   (('Joanne', 'Froggatt', 'Yay'), 1),
#   (('Froggatt', 'Yay', 'Joanne'), 1),
#   (('Movie', 'Check'), 1),
#   (('Abbey”', 'Yaaaay'), 1),
#   (('Yaaaay', 'Anna'), 1),
#   (('Downton', 'Abbey”', 'Yaaaay'), 1),
#   (('Abbey”', 'Yaaaay', 'Anna'), 1),
#   (('Wooho', 'Movie'), 1),
#   (('Wooho', 'Movie', 'Joanne'), 1),
#   (('News', 'Joanne'), 1),
#   (('News', 'Joanne', 'Froggatt'), 1),
#   (('Movie', 'Golde'), 1),
#   (('Wins', 'Movie', 'Golde'), 1),
#   (('Anna', 'Movie'), 1),
#   (('Lovely', 'Maggie'), 1),
#   (('Maggie', 'Movie'), 1),
#   (('Movie', 'Honourable'), 1),
#   (('Honourable', 'Woman'), 1),
#   (('Woman', 'Luv'), 1),
#   (('Lovely', 'Maggie', 'Movie'), 1),
#   (('Maggie', 'Movie', 'Honourable'), 1),
#   (('Movie', 'Honourable', 'Woman'), 1),
#   (('Honourable', 'Woman', 'Luv'), 1),
#   (('Movie', 'Peoplemag'), 1),
#   (('Wins', 'Movie', 'Peoplemag'), 1),
#   (('Movie', 'Downton…'), 1),
#   (('Wins', 'Movie', 'Downton…'), 1),
#   (('Movie', 'Froggatt', 'Downton'), 1)],
#  'best performance by an actor in a supporting role in a series, mini-series or motion picture made for television': [(('Matt',
#     'Bomer'),
#    1255),
#   (('Bomer', 'Normal'), 615),
#   (('Matt', 'Bomer', 'Normal'), 584),
#   (('Movie', 'Matt'), 568),
#   (('Movie', 'Matt', 'Bomer'), 565),
#   (('Variety', 'Matt'), 245),
#   (('Variety', 'Matt', 'Bomer'), 245),
#   (('Movie', 'Normal'), 171),
#   (('Culturalist', 'Retweet'), 135),
#   (('Congrats', 'Matt'), 48),
#   (('Congrats', 'Matt', 'Bomer'), 48),
#   (('Bomer', 'Movie'), 35),
#   (('Matt', 'Bomer', 'Movie'), 35),
#   (('Movie', 'Reuters'), 27),
#   (('Bomer', 'Movie', 'Reuters'), 27),
#   (('Bomer', 'Wins'), 26),
#   (('Matt', 'Bomer', 'Wins'), 26),
#   (('Matthew', 'Bomer'), 24),
#   (('Matthew', 'Bomer', 'Normal'), 24),
#   (('Wins', 'Movie'), 21),
#   (('Bomer', 'Wins', 'Movie'), 21),
#   (('Movie', 'Matthew'), 12),
#   (('Movie', 'Matthew', 'Bomer'), 12),
#   (('Winner', 'Movie'), 12),
#   (('Pemenang', 'Movie'), 10),
#   (('Pemenang', 'Movie', 'Matt'), 10),
#   (('Series', 'Movie'), 8),
#   (('Culturalist', 'Congratulations'), 7),
#   (('Movie', 'Winner'), 7),
#   (('Winner', 'Matt'), 7),
#   (('Movie', 'Winner', 'Matt'), 7),
#   (('Winner', 'Matt', 'Bomer'), 7),
#   (('Series', 'Movie', 'Matt'), 6),
#   (('Seires', 'Movie'), 5),
#   (('Award', 'Movie'), 4),
#   (('Bomer', 'Movie…'), 4),
#   (('Actress', 'Movie'), 3),
#   (('Congrats', 'Movie'), 3),
#   (('Bomer', 'Movie', 'Normal'), 3),
#   (('Drama', 'Comedy'), 2),
#   (('Billy', 'Bob'), 2),
#   (('Bob', 'Thornton'), 2),
#   (('Billy', 'Bob', 'Thornton'), 2),
#   (('Matt', 'Bomber'), 2),
#   (('Bomber', 'Normal'), 2),
#   (('Movie', 'Matt', 'Bomber'), 2),
#   (('Matt', 'Bomber', 'Normal'), 2),
#   (('Winner', 'Movie', 'Matt'), 2),
#   (('Jon', 'Voight'), 2),
#   (('Bomer', 'Award'), 2),
#   (('Matt', 'Bomer', 'Award'), 2),
#   (('Bomer', 'Award', 'Movie'), 2),
#   (('Award', 'Movie', 'Normal'), 2),
#   (('News', 'Matt'), 2),
#   (('News', 'Matt', 'Bomer'), 2),
#   (('Yay', 'Movie'), 2),
#   (('Yay', 'Movie', 'Matt'), 2),
#   (('Matt', 'Bomer', 'Movie…'), 2),
#   (('Joanne', 'Froggatt'), 1),
#   (('Froggatt', 'Downton'), 1),
#   (('Downton', 'Abbey'), 1),
#   (('Joanne', 'Froggatt', 'Downton'), 1),
#   (('Froggatt', 'Downton', 'Abbey'), 1),
#   (('Movie', 'Billy'), 1),
#   (('Thornton', 'Killed'), 1),
#   (('Movie', 'Billy', 'Bob'), 1),
#   (('Bob', 'Thornton', 'Killed'), 1),
#   (('Bomer', 'Deserved'), 1),
#   (('Matt', 'Bomer', 'Deserved'), 1),
#   (('Award', 'Movie', 'Matt'), 1),
#   (('Bomer', 'Alan'), 1),
#   (('Alan', 'Cumming'), 1),
#   (('Cumming', 'Colin'), 1),
#   (('Colin', 'Hanks'), 1),
#   (('Hanks', 'Murray'), 1),
#   (('Murray', 'Jon'), 1),
#   (('Matt', 'Bomer', 'Alan'), 1),
#   (('Bomer', 'Alan', 'Cumming'), 1),
#   (('Alan', 'Cumming', 'Colin'), 1),
#   (('Cumming', 'Colin', 'Hanks'), 1),
#   (('Colin', 'Hanks', 'Murray'), 1),
#   (('Hanks', 'Murray', 'Jon'), 1),
#   (('Murray', 'Jon', 'Voight'), 1),
#   (('Normal', 'Fantastic'), 1),
#   (('Bomer', 'Normal', 'Fantastic'), 1),
#   (('Normal', 'Cute'), 1),
#   (('Movie', 'Normal', 'Cute'), 1),
#   (('Movie', 'Movie'), 1),
#   (('Bomer', 'Movie', 'Movie'), 1),
#   (('Murray', 'Angelina'), 1),
#   (('Angelina', 'Jolies'), 1),
#   (('Murray', 'Angelina', 'Jolies'), 1),
#   (('Normal', 'Series'), 1),
#   (('Bomer', 'Normal', 'Series'), 1),
#   (('Normal', 'Series', 'Movie'), 1),
#   (('Movie', 'Mark'), 1),
#   (('Mark', 'Ruffalo'), 1),
#   (('Ruffalo', 'Normal'), 1),
#   (('Normal', 'Congrats'), 1),
#   (('Movie', 'Mark', 'Ruffalo'), 1),
#   (('Mark', 'Ruffalo', 'Normal'), 1),
#   (('Ruffalo', 'Normal', 'Congrats'), 1),
#   (('Movie', 'Norma…'), 1),
#   (('Award', 'Movie', 'Norma…'), 1),
#   (('Normal', 'Awesome'), 1),
#   (('Bomer', 'Normal', 'Awesome'), 1),
#   (('Movie', 'Hungry'), 1),
#   (('Wins', 'Movie', 'Hungry'), 1),
#   (('Yaaaaaaay', 'Congrats'), 1),
#   (('Yaaaaaaay', 'Congrats', 'Matt'), 1),
#   (('Movie', 'Check'), 1),
#   (('Congratulations', 'Matt'), 1),
#   (('Bomer', 'Series'), 1),
#   (('Congratulations', 'Matt', 'Bomer'), 1),
#   (('Matt', 'Bomer', 'Series'), 1),
#   (('Bomer', 'Series', 'Movie'), 1),
#   (('Yay', 'Congrats'), 1),
#   (('Matt', 'Normal'), 1),
#   (('Movie', 'Matt', 'Normal'), 1),
#   (('Kristiturnquist', 'Matt'), 1),
#   (('Kristiturnquist', 'Matt', 'Bomer'), 1),
#   (('Bomer', 'Yay'), 1),
#   (('Matt', 'Bomer', 'Yay'), 1),
#   (('Normal', 'Phot'), 1),
#   (('Movie', 'Normal', 'Phot'), 1),
#   (('Photo', 'Bomer'), 1),
#   (('Normal', 'Yay'), 1),
#   (('Bomer', 'Normal', 'Yay'), 1),
#   (('Wins', 'Hooray'), 1),
#   (('Bomer', 'Wins', 'Hooray'), 1),
#   (('Movie', 'The…'), 1),
#   (('Bomer', 'Movie', 'The…'), 1),
#   (('Foto', 'Matt'), 1),
#   (('Foto', 'Matt', 'Bomer'), 1),
#   (('Bomer', 'Waaaah'), 1),
#   (('Waaaah', 'Wife'), 1),
#   (('Matt', 'Bomer', 'Waaaah'), 1),
#   (('Bomer', 'Waaaah', 'Wife'), 1),
#   (('Variety', 'Congrats'), 1),
#   (('Awards', 'Movie'), 1)]}

# %%
def getWinners(nominees):
    final_winners = {}
    
    for award in nominees:
        winner = ' '.join(nominees[award][0][0])
        final_winners[award] = winner
        
    return final_winners

# %%
winners_dict = getWinners(nominees)

# %%
winners_dict
# Out:
# {'cecil b. demille award': 'George Clooney',
#  'best performance by an actress in a motion picture - drama': 'Julianne Moore',
#  'best performance by an actor in a motion picture - drama': 'Eddie Redmayne',
#  'best performance by an actress in a motion picture - comedy or musical': 'Amy Adams',
#  'best performance by an actor in a motion picture - comedy or musical': 'Michael Keaton',
#  'best performance by an actress in a supporting role in a motion picture': 'Patricia Arquette',
#  'best performance by an actor in a supporting role in a motion picture': 'Simmons Whiplash',
#  'best director - motion picture': 'Richard Linklater',
#  'best screenplay - motion picture': 'Alexander Dinelaris',
#  'best original score - motion picture': 'Johann Johannsson',
#  'best performance by an actress in a television series - drama': 'Ruth Wilson',
#  'best performance by an actor in a television series - drama': 'Kevin Spacey',
#  'best performance by an actress in a television series - comedy or musical': 'Gina Rodriguez',
#  'best performance by an actor in a television series - comedy or musical': 'Jeffrey Tambor',
#  'best performance by an actress in a mini-series or motion picture made for television': 'Joanne Froggatt',
#  'best performance by an actor in a mini-series or motion picture made for television': 'Billy Bob',
#  'best performance by an actress in a supporting role in a series, mini-series or motion picture made for television': 'Joanne Froggatt',
#  'best performance by an actor in a supporting role in a series, mini-series or motion picture made for television': 'Matt Bomer'}

# %%
def compareToKB(nominees):
    final_nominees = {}
        
    for i in nominees:
        award_nominees = []
        
        for j in nominees[i]:
            name = ' '.join(j[0])
            if name in people:
                award_nominees.append(name)
        
        final_nominees[i] = award_nominees
        
    return final_nominees

# %%
nominees_dict = compareToKB(nominees)

# %%
nominees_dict
# Out:
# {'cecil b. demille award': ['George Clooney',
#   'Julianna Margulies',
#   'Alejandro Gonzalez Inarritu',
#   'Liza Minnelli',
#   'Michael Keaton',
#   'Meryl Streep',
#   'Jim Carrey',
#   'Jodie Foster',
#   'Gary Busey',
#   'Pia Zadora',
#   'Kevin Spacey',
#   'Matt Damon',
#   'Dakota Fanning',
#   'Angelina Jolie',
#   'Richard Linklater'],
#  'best performance by an actress in a motion picture - drama': ['Julianne Moore',
#   'Rosamund Pike',
#   'Jennifer Aniston',
#   'Patricia Arquette',
#   'Reese Witherspoon',
#   'Felicity Jones',
#   'Amy Adams',
#   'Eddie Redmayne',
#   'Shailene Woodley',
#   'Richard Linklater',
#   'George Clooney'],
#  'best performance by an actor in a motion picture - drama': ['Eddie Redmayne',
#   'Kevin Spacey',
#   'David Oyelowo',
#   'Benedict Cumberbatch',
#   'Jake Gyllenhaal',
#   'Michael Keaton',
#   'Steve Carell',
#   'Julianne Moore',
#   'Gwyneth Paltrow',
#   'George Clooney',
#   'Jennifer Aniston',
#   'Frank Underwood'],
#  'best performance by an actress in a motion picture - comedy or musical': ['Amy Adams',
#   'Gina Rodriguez',
#   'Emily Blunt',
#   'Patricia Arquette',
#   'Helen Mirren',
#   'Ricky Gervais',
#   'Julianne Moore',
#   'Michael Keaton',
#   'Quvenzhane Wallis',
#   'Meryl Streep',
#   'Lana Parrilla'],
#  'best performance by an actor in a motion picture - comedy or musical': ['Michael Keaton',
#   'Jeffrey Tambor',
#   'Amy Adams',
#   'Ralph Fiennes',
#   'Joaquin Phoenix',
#   'Christoph Waltz',
#   'Emily Blunt',
#   'Jamie Foxx',
#   'Wes Anderson'],
#  'best performance by an actress in a supporting role in a motion picture': ['Patricia Arquette',
#   'Uzo Aduba',
#   'Amy Adams',
#   'Keira Knightley',
#   'Maggie Gyllenhaal',
#   'Jessica Chastain',
#   'Emma Stone',
#   'Jared Leto',
#   'Meryl Streep',
#   'Richard Linklater',
#   'Hans Zimmer',
#   'Kathy Bates',
#   'Dakota Johnson',
#   'Carrie Coon'],
#  'best performance by an actor in a supporting role in a motion picture': ['Matt Bomer',
#   'Lorne Michaels',
#   'Mark Ruffalo',
#   'Ethan Hawke',
#   'Jennifer Aniston',
#   'Patricia Arquette',
#   'Benedict Cumberbatch',
#   'Billy Bob Thornton',
#   'Jon Voight',
#   'Richard Linklater',
#   'Alan Cumming',
#   'Colin Hanks'],
#  'best director - motion picture': ['Richard Linklater',
#   'Angelina Jolie',
#   'Ellar Coltrane',
#   'Wes Anderson',
#   'Patricia Arquette',
#   'Eddie Redmayne',
#   'David Fincher',
#   'Ethan Hawke',
#   'Justin Lin',
#   'Julianne Moore',
#   'Seth Meyers',
#   'Cary Fukunaga',
#   'Andrey Zvyagintsev'],
#  'best screenplay - motion picture': ['Patricia Arquette',
#   'Kristen Wiig',
#   'Alejandro Gonzalez Inarritu',
#   'Emma Stone',
#   'Michael Keaton',
#   'Richard Linklater',
#   'Tyler Perry',
#   'Michael Bay',
#   'Mike Leigh',
#   'Julianne Moore',
#   'Gillian Flynn',
#   'Judd Apatow',
#   'Michael Mann',
#   'Adam Sandler',
#   'Wes Anderson'],
#  'best original score - motion picture': ['Hans Zimmer',
#   'Sienna Miller',
#   'Vince Vaughn',
#   'Kevin Spacey',
#   'John Legend',
#   'Emma Stone',
#   'Alexandre Desplat'],
#  'best performance by an actress in a television series - drama': ['Viola Davis',
#   'Claire Danes',
#   'Chris Pratt',
#   'Lana Parrilla',
#   'Julianna Margulies',
#   'Robin Wright',
#   'Gina Rodriguez',
#   'Anna Faris',
#   'Kevin Spacey',
#   'Angela Lansbury',
#   'Maggie Gyllenhaal',
#   'Allison Tolman',
#   'Dominic West'],
#  'best performance by an actor in a television series - drama': ['Kevin Spacey',
#   'Frank Underwood',
#   'Kate Mara',
#   'Clive Owen',
#   'Dominic West',
#   'Liev Schreiber',
#   'James Spader',
#   'Katherine Heigl',
#   'David Duchovny',
#   'Amy Adams',
#   'Billy Bob Thornton',
#   'Matt Bomer',
#   'Jeffrey Tambor',
#   'Deepika Padukone'],
#  'best performance by an actress in a television series - comedy or musical': ['Gina Rodriguez',
#   'Kerry Washington',
#   'Chloe Bennet',
#   'Bryan Cranston',
#   'Lena Dunham',
#   'Edie Falco',
#   'Taylor Schilling',
#   'Amy Adams'],
#  'best performance by an actor in a television series - comedy or musical': ['Jeffrey Tambor',
#   'Matt Bomer',
#   'Ricky Gervais',
#   'Jane Fonda',
#   'Katie Holmes',
#   'Seth Meyers',
#   'Lily Tomlin',
#   'Gina Rodriguez'],
#  'best performance by an actress in a mini-series or motion picture made for television': ['Maggie Gyllenhaal',
#   'Gina Rodriguez',
#   'Adrien Brody',
#   'Kate Beckinsale',
#   'Uzo Aduba',
#   'Kathy Bates',
#   'Dakota Johnson',
#   'Amy Adams',
#   'Allison Tolman',
#   'Judith Light'],
#  'best performance by an actor in a mini-series or motion picture made for television': ['Billy Bob Thornton',
#   'Matt Bomer',
#   'Kevin Spacey',
#   'Jeffrey Tambor',
#   'Jeremy Renner',
#   'Mark Ruffalo',
#   'Jon Voight',
#   'James Spader',
#   'Woody Harrelson',
#   'Katie Holmes',
#   'Seth Meyers',
#   'Alan Cumming',
#   'Colin Hanks',
#   'Frank Underwood'],
#  'best performance by an actress in a supporting role in a series, mini-series or motion picture made for television': ['Maggie Gyllenhaal',
#   'Uzo Aduba',
#   'Kathy Bates',
#   'Dakota Johnson'],
#  'best performance by an actor in a supporting role in a series, mini-series or motion picture made for television': ['Matt Bomer',
#   'Billy Bob Thornton',
#   'Jon Voight',
#   'Alan Cumming',
#   'Colin Hanks',
#   'Mark Ruffalo']}

# %%
our_dict = {}

for award in OFFICIAL_AWARDS_1315:
    our_dict[award] = {
        'nominees' : nominees_dict[award],
        'winner' : winners_dict[award],
        'presenters' : []
    }

# %%
our_dict
# Out:
# {'cecil b. demille award': {'nominees': ['George Clooney',
#    'Julianna Margulies',
#    'Alejandro Gonzalez Inarritu',
#    'Liza Minnelli',
#    'Michael Keaton',
#    'Meryl Streep',
#    'Jim Carrey',
#    'Jodie Foster',
#    'Gary Busey',
#    'Pia Zadora',
#    'Kevin Spacey',
#    'Matt Damon',
#    'Dakota Fanning',
#    'Angelina Jolie',
#    'Richard Linklater'],
#   'winner': 'George Clooney',
#   'presenters': []},
#  'best performance by an actress in a motion picture - drama': {'nominees': ['Julianne Moore',
#    'Rosamund Pike',
#    'Jennifer Aniston',
#    'Patricia Arquette',
#    'Reese Witherspoon',
#    'Felicity Jones',
#    'Amy Adams',
#    'Eddie Redmayne',
#    'Shailene Woodley',
#    'Richard Linklater',
#    'George Clooney'],
#   'winner': 'Julianne Moore',
#   'presenters': []},
#  'best performance by an actor in a motion picture - drama': {'nominees': ['Eddie Redmayne',
#    'Kevin Spacey',
#    'David Oyelowo',
#    'Benedict Cumberbatch',
#    'Jake Gyllenhaal',
#    'Michael Keaton',
#    'Steve Carell',
#    'Julianne Moore',
#    'Gwyneth Paltrow',
#    'George Clooney',
#    'Jennifer Aniston',
#    'Frank Underwood'],
#   'winner': 'Eddie Redmayne',
#   'presenters': []},
#  'best performance by an actress in a motion picture - comedy or musical': {'nominees': ['Amy Adams',
#    'Gina Rodriguez',
#    'Emily Blunt',
#    'Patricia Arquette',
#    'Helen Mirren',
#    'Ricky Gervais',
#    'Julianne Moore',
#    'Michael Keaton',
#    'Quvenzhane Wallis',
#    'Meryl Streep',
#    'Lana Parrilla'],
#   'winner': 'Amy Adams',
#   'presenters': []},
#  'best performance by an actor in a motion picture - comedy or musical': {'nominees': ['Michael Keaton',
#    'Jeffrey Tambor',
#    'Amy Adams',
#    'Ralph Fiennes',
#    'Joaquin Phoenix',
#    'Christoph Waltz',
#    'Emily Blunt',
#    'Jamie Foxx',
#    'Wes Anderson'],
#   'winner': 'Michael Keaton',
#   'presenters': []},
#  'best performance by an actress in a supporting role in a motion picture': {'nominees': ['Patricia Arquette',
#    'Uzo Aduba',
#    'Amy Adams',
#    'Keira Knightley',
#    'Maggie Gyllenhaal',
#    'Jessica Chastain',
#    'Emma Stone',
#    'Jared Leto',
#    'Meryl Streep',
#    'Richard Linklater',
#    'Hans Zimmer',
#    'Kathy Bates',
#    'Dakota Johnson',
#    'Carrie Coon'],
#   'winner': 'Patricia Arquette',
#   'presenters': []},
#  'best performance by an actor in a supporting role in a motion picture': {'nominees': ['Matt Bomer',
#    'Lorne Michaels',
#    'Mark Ruffalo',
#    'Ethan Hawke',
#    'Jennifer Aniston',
#    'Patricia Arquette',
#    'Benedict Cumberbatch',
#    'Billy Bob Thornton',
#    'Jon Voight',
#    'Richard Linklater',
#    'Alan Cumming',
#    'Colin Hanks'],
#   'winner': 'Simmons Whiplash',
#   'presenters': []},
#  'best director - motion picture': {'nominees': ['Richard Linklater',
#    'Angelina Jolie',
#    'Ellar Coltrane',
#    'Wes Anderson',
#    'Patricia Arquette',
#    'Eddie Redmayne',
#    'David Fincher',
#    'Ethan Hawke',
#    'Justin Lin',
#    'Julianne Moore',
#    'Seth Meyers',
#    'Cary Fukunaga',
#    'Andrey Zvyagintsev'],
#   'winner': 'Richard Linklater',
#   'presenters': []},
#  'best screenplay - motion picture': {'nominees': ['Patricia Arquette',
#    'Kristen Wiig',
#    'Alejandro Gonzalez Inarritu',
#    'Emma Stone',
#    'Michael Keaton',
#    'Richard Linklater',
#    'Tyler Perry',
#    'Michael Bay',
#    'Mike Leigh',
#    'Julianne Moore',
#    'Gillian Flynn',
#    'Judd Apatow',
#    'Michael Mann',
#    'Adam Sandler',
#    'Wes Anderson'],
#   'winner': 'Alexander Dinelaris',
#   'presenters': []},
#  'best original score - motion picture': {'nominees': ['Hans Zimmer',
#    'Sienna Miller',
#    'Vince Vaughn',
#    'Kevin Spacey',
#    'John Legend',
#    'Emma Stone',
#    'Alexandre Desplat'],
#   'winner': 'Johann Johannsson',
#   'presenters': []},
#  'best performance by an actress in a television series - drama': {'nominees': ['Viola Davis',
#    'Claire Danes',
#    'Chris Pratt',
#    'Lana Parrilla',
#    'Julianna Margulies',
#    'Robin Wright',
#    'Gina Rodriguez',
#    'Anna Faris',
#    'Kevin Spacey',
#    'Angela Lansbury',
#    'Maggie Gyllenhaal',
#    'Allison Tolman',
#    'Dominic West'],
#   'winner': 'Ruth Wilson',
#   'presenters': []},
#  'best performance by an actor in a television series - drama': {'nominees': ['Kevin Spacey',
#    'Frank Underwood',
#    'Kate Mara',
#    'Clive Owen',
#    'Dominic West',
#    'Liev Schreiber',
#    'James Spader',
#    'Katherine Heigl',
#    'David Duchovny',
#    'Amy Adams',
#    'Billy Bob Thornton',
#    'Matt Bomer',
#    'Jeffrey Tambor',
#    'Deepika Padukone'],
#   'winner': 'Kevin Spacey',
#   'presenters': []},
#  'best performance by an actress in a television series - comedy or musical': {'nominees': ['Gina Rodriguez',
#    'Kerry Washington',
#    'Chloe Bennet',
#    'Bryan Cranston',
#    'Lena Dunham',
#    'Edie Falco',
#    'Taylor Schilling',
#    'Amy Adams'],
#   'winner': 'Gina Rodriguez',
#   'presenters': []},
#  'best performance by an actor in a television series - comedy or musical': {'nominees': ['Jeffrey Tambor',
#    'Matt Bomer',
#    'Ricky Gervais',
#    'Jane Fonda',
#    'Katie Holmes',
#    'Seth Meyers',
#    'Lily Tomlin',
#    'Gina Rodriguez'],
#   'winner': 'Jeffrey Tambor',
#   'presenters': []},
#  'best performance by an actress in a mini-series or motion picture made for television': {'nominees': ['Maggie Gyllenhaal',
#    'Gina Rodriguez',
#    'Adrien Brody',
#    'Kate Beckinsale',
#    'Uzo Aduba',
#    'Kathy Bates',
#    'Dakota Johnson',
#    'Amy Adams',
#    'Allison Tolman',
#    'Judith Light'],
#   'winner': 'Joanne Froggatt',
#   'presenters': []},
#  'best performance by an actor in a mini-series or motion picture made for television': {'nominees': ['Billy Bob Thornton',
#    'Matt Bomer',
#    'Kevin Spacey',
#    'Jeffrey Tambor',
#    'Jeremy Renner',
#    'Mark Ruffalo',
#    'Jon Voight',
#    'James Spader',
#    'Woody Harrelson',
#    'Katie Holmes',
#    'Seth Meyers',
#    'Alan Cumming',
#    'Colin Hanks',
#    'Frank Underwood'],
#   'winner': 'Billy Bob',
#   'presenters': []},
#  'best performance by an actress in a supporting role in a series, mini-series or motion picture made for television': {'nominees': ['Maggie Gyllenhaal',
#    'Uzo Aduba',
#    'Kathy Bates',
#    'Dakota Johnson'],
#   'winner': 'Joanne Froggatt',
#   'presenters': []},
#  'best performance by an actor in a supporting role in a series, mini-series or motion picture made for television': {'nominees': ['Matt Bomer',
#    'Billy Bob Thornton',
#    'Jon Voight',
#    'Alan Cumming',
#    'Colin Hanks',
#    'Mark Ruffalo'],
#   'winner': 'Matt Bomer',
#   'presenters': []}}

# %%
GG_OFFICIAL_AWARDS = ['Best Motion Picture - Drama','Best Motion Picture - Musical or Comedy','Best Director - Motion Picture',
'Best Original Score - Motion Picture','Best Original Song - Motion Picture','Best Foreign Language Film','Best Animated Feature Film','Best Television Series - Drama',
'Best Television Series - Comedy Or Musical','Best Screenplay - Motion Picture','Best Performance by an Actor in a Motion Picture - Drama',
'Best Performance by an Actress in a Motion Picture - Drama','Best Performance by an Actor In A Supporting Role in a Motion Picture',
'Best Performance by an Actress In A Supporting Role in a Motion Picture','Best Performance by an Actor In A Television Series - Drama','Best Performance by an Actress In A Television Series - Drama',
'Best Performance by an Actress in a Motion Picture - Comedy Or Musical','Best Performance by an Actor in a Motion Picture - Comedy Or Musical','Best Performance by an Actor In A Television Series - Comedy Or Musical',
'Best Performance by an Actress In A Television Series - Comedy Or Musical','Best Performance by an Actress in a Supporting Role in a Series','Best Performance by an Actor in a Supporting Role in a Series',
'Best Mini-Series or Motion Picture made for Television','Best Performance by an Actor in a Mini-Series or Motion Picture Made for Television','Best Performance by an Actress In A Mini-Series or Motion Picture Made for Television']

# %%
def separateAwards(award_list):
    possible_people_awards = ['actor',' actress', 'musician', ' singer', 'composer', 'director', 'producer',
                        'screenwriter', 'stage technician', 'author']

    people_awards = set()
    media_awards = set()

    for category in award_list:
        if any(job in category.lower() for job in possible_people_awards):
            people_awards.add(category)
        else:
            media_awards.add(category)

    return people_awards, media_awards

# %%
# from pprint import pprint

def easy_comp(award_list,true_dict,our_dict):
        
    # Input 
    # Dict of dictionaries 
    # Keys - Award Name
    # Values - Dictionary with keys (nominees, presenters, winner)
    
    # Output
    # Nested List (some elements are dictionarys)

    output = []

    for award in award_list:
        output.append([award,["Guess",our_dict[award]],[["True",true_dict[award]]]])

    
    return output

# For easy printing use pprint. It works nicely for updated comparison

# %%
easy_comp(OFFICIAL_AWARDS_1315,true_dict,our_dict)
# Out:
# [['cecil b. demille award',
#   ['Guess',
#    {'nominees': ['George Clooney',
#      'Julianna Margulies',
#      'Alejandro Gonzalez Inarritu',
#      'Liza Minnelli',
#      'Michael Keaton',
#      'Meryl Streep',
#      'Jim Carrey',
#      'Jodie Foster',
#      'Gary Busey',
#      'Pia Zadora',
#      'Kevin Spacey',
#      'Matt Damon',
#      'Dakota Fanning',
#      'Angelina Jolie',
#      'Richard Linklater'],
#     'winner': 'George Clooney',
#     'presenters': []}],
#   [['True',
#     {'nominees': [],
#      'presenters': ['don cheadle', 'julianna margulies'],
#      'winner': 'george clooney'}]]],
#  ['best performance by an actress in a motion picture - drama',
#   ['Guess',
#    {'nominees': ['Julianne Moore',
#      'Rosamund Pike',
#      'Jennifer Aniston',
#      'Patricia Arquette',
#      'Reese Witherspoon',
#      'Felicity Jones',
#      'Amy Adams',
#      'Eddie Redmayne',
#      'Shailene Woodley',
#      'Richard Linklater',
#      'George Clooney'],
#     'winner': 'Julianne Moore',
#     'presenters': []}],
#   [['True',
#     {'nominees': ['jennifer aniston',
#       'felicity jones',
#       'rosamund pike',
#       'reese witherspoon'],
#      'presenters': ['matthew mcconaughey'],
#      'winner': 'julianne moore'}]]],
#  ['best performance by an actor in a motion picture - drama',
#   ['Guess',
#    {'nominees': ['Eddie Redmayne',
#      'Kevin Spacey',
#      'David Oyelowo',
#      'Benedict Cumberbatch',
#      'Jake Gyllenhaal',
#      'Michael Keaton',
#      'Steve Carell',
#      'Julianne Moore',
#      'Gwyneth Paltrow',
#      'George Clooney',
#      'Jennifer Aniston',
#      'Frank Underwood'],
#     'winner': 'Eddie Redmayne',
#     'presenters': []}],
#   [['True',
#     {'nominees': ['steve carell',
#       'benedict cumberbatch',
#       'jake gyllenhaal',
#       'david oyelowo'],
#      'presenters': ['gwyneth paltrow'],
#      'winner': 'eddie redmayne'}]]],
#  ['best performance by an actress in a motion picture - comedy or musical',
#   ['Guess',
#    {'nominees': ['Amy Adams',
#      'Gina Rodriguez',
#      'Emily Blunt',
#      'Patricia Arquette',
#      'Helen Mirren',
#      'Ricky Gervais',
#      'Julianne Moore',
#      'Michael Keaton',
#      'Quvenzhane Wallis',
#      'Meryl Streep',
#      'Lana Parrilla'],
#     'winner': 'Amy Adams',
#     'presenters': []}],
#   [['True',
#     {'nominees': ['emily blunt',
#       'helen mirren',
#       'julianne moore',
#       'quvenzhane wallis'],
#      'presenters': ['ricky gervais'],
#      'winner': 'amy adams'}]]],
#  ['best performance by an actor in a motion picture - comedy or musical',
#   ['Guess',
#    {'nominees': ['Michael Keaton',
#      'Jeffrey Tambor',
#      'Amy Adams',
#      'Ralph Fiennes',
#      'Joaquin Phoenix',
#      'Christoph Waltz',
#      'Emily Blunt',
#      'Jamie Foxx',
#      'Wes Anderson'],
#     'winner': 'Michael Keaton',
#     'presenters': []}],
#   [['True',
#     {'nominees': ['ralph fiennes',
#       'bill murray',
#       'joaquin phoenix',
#       'christoph waltz'],
#      'presenters': ['amy adams'],
#      'winner': 'michael keaton'}]]],
#  ['best performance by an actress in a supporting role in a motion picture',
#   ['Guess',
#    {'nominees': ['Patricia Arquette',
#      'Uzo Aduba',
#      'Amy Adams',
#      'Keira Knightley',
#      'Maggie Gyllenhaal',
#      'Jessica Chastain',
#      'Emma Stone',
#      'Jared Leto',
#      'Meryl Streep',
#      'Richard Linklater',
#      'Hans Zimmer',
#      'Kathy Bates',
#      'Dakota Johnson',
#      'Carrie Coon'],
#     'winner': 'Patricia Arquette',
#     'presenters': []}],
#   [['True',
#     {'nominees': ['jessica chastain',
#       'keira knightley',
#       'emma stone',
#       'meryl streep'],
#      'presenters': ['jared leto'],
#      'winner': 'patricia arquette'}]]],
#  ['best performance by an actor in a supporting role in a motion picture',
#   ['Guess',
#    {'nominees': ['Matt Bomer',
#      'Lorne Michaels',
#      'Mark Ruffalo',
#      'Ethan Hawke',
#      'Jennifer Aniston',
#      'Patricia Arquette',
#      'Benedict Cumberbatch',
#      'Billy Bob Thornton',
#      'Jon Voight',
#      'Richard Linklater',
#      'Alan Cumming',
#      'Colin Hanks'],
#     'winner': 'Simmons Whiplash',
#     'presenters': []}],
#   [['True',
#     {'nominees': ['robert duvall', 'edward norton', 'mark ruffalo'],
#      'presenters': ['jennifer aniston', 'benedict cumberbatch'],
#      'winner': 'j.k. simmons'}]]],
#  ['best director - motion picture',
#   ['Guess',
#    {'nominees': ['Richard Linklater',
#      'Angelina Jolie',
#      'Ellar Coltrane',
#      'Wes Anderson',
#      'Patricia Arquette',
#      'Eddie Redmayne',
#      'David Fincher',
#      'Ethan Hawke',
#      'Justin Lin',
#      'Julianne Moore',
#      'Seth Meyers',
#      'Cary Fukunaga',
#      'Andrey Zvyagintsev'],
#     'winner': 'Richard Linklater',
#     'presenters': []}],
#   [['True',
#     {'nominees': ['wes anderson',
#       'ava duvernay',
#       'david fincher',
#       'alejandro inarritu gonzalez'],
#      'presenters': ['harrison ford'],
#      'winner': 'richard linklater'}]]],
#  ['best screenplay - motion picture',
#   ['Guess',
#    {'nominees': ['Patricia Arquette',
#      'Kristen Wiig',
#      'Alejandro Gonzalez Inarritu',
#      'Emma Stone',
#      'Michael Keaton',
#      'Richard Linklater',
#      'Tyler Perry',
#      'Michael Bay',
#      'Mike Leigh',
#      'Julianne Moore',
#      'Gillian Flynn',
#      'Judd Apatow',
#      'Michael Mann',
#      'Adam Sandler',
#      'Wes Anderson'],
#     'winner': 'Alexander Dinelaris',
#     'presenters': []}],
#   [['True',
#     {'nominees': ['the grand budapest hotel',
#       'gone girl',
#       'boyhood',
#       'the imitation game'],
#      'presenters': ['bill hader', 'kristen wiig'],
#      'winner': 'birdman'}]]],
#  ['best original score - motion picture',
#   ['Guess',
#    {'nominees': ['Hans Zimmer',
#      'Sienna Miller',
#      'Vince Vaughn',
#      'Kevin Spacey',
#      'John Legend',
#      'Emma Stone',
#      'Alexandre Desplat'],
#     'winner': 'Johann Johannsson',
#     'presenters': []}],
#   [['True',
#     {'nominees': ['the imitation game',
#       'birdman',
#       'gone girl',
#       'interstellar'],
#      'presenters': ['sienna miller', 'vince vaughn'],
#      'winner': 'the theory of everything'}]]],
#  ['best performance by an actress in a television series - drama',
#   ['Guess',
#    {'nominees': ['Viola Davis',
#      'Claire Danes',
#      'Chris Pratt',
#      'Lana Parrilla',
#      'Julianna Margulies',
#      'Robin Wright',
#      'Gina Rodriguez',
#      'Anna Faris',
#      'Kevin Spacey',
#      'Angela Lansbury',
#      'Maggie Gyllenhaal',
#      'Allison Tolman',
#      'Dominic West'],
#     'winner': 'Ruth Wilson',
#     'presenters': []}],
#   [['True',
#     {'nominees': ['claire danes',
#       'viola davis',
#       'julianna margulies',
#       'robin wright'],
#      'presenters': ['anna faris', 'chris pratt'],
#      'winner': 'ruth wilson'}]]],
#  ['best performance by an actor in a television series - drama',
#   ['Guess',
#    {'nominees': ['Kevin Spacey',
#      'Frank Underwood',
#      'Kate Mara',
#      'Clive Owen',
#      'Dominic West',
#      'Liev Schreiber',
#      'James Spader',
#      'Katherine Heigl',
#      'David Duchovny',
#      'Amy Adams',
#      'Billy Bob Thornton',
#      'Matt Bomer',
#      'Jeffrey Tambor',
#      'Deepika Padukone'],
#     'winner': 'Kevin Spacey',
#     'presenters': []}],
#   [['True',
#     {'nominees': ['clive owen',
#       'liev schreiber',
#       'james spader',
#       'dominic west'],
#      'presenters': ['david duchovny', 'katherine heigl'],
#      'winner': 'kevin spacey'}]]],
#  ['best performance by an actress in a television series - comedy or musical',
#   ['Guess',
#    {'nominees': ['Gina Rodriguez',
#      'Kerry Washington',
#      'Chloe Bennet',
#      'Bryan Cranston',
#      'Lena Dunham',
#      'Edie Falco',
#      'Taylor Schilling',
#      'Amy Adams'],
#     'winner': 'Gina Rodriguez',
#     'presenters': []}],
#   [['True',
#     {'nominees': ['lena dunham',
#       'edie falco',
#       'julia louis-dreyfus',
#       'taylor schilling'],
#      'presenters': ['bryan cranston', 'kerry washington'],
#      'winner': 'gina rodriguez'}]]],
#  ['best performance by an actor in a television series - comedy or musical',
#   ['Guess',
#    {'nominees': ['Jeffrey Tambor',
#      'Matt Bomer',
#      'Ricky Gervais',
#      'Jane Fonda',
#      'Katie Holmes',
#      'Seth Meyers',
#      'Lily Tomlin',
#      'Gina Rodriguez'],
#     'winner': 'Jeffrey Tambor',
#     'presenters': []}],
#   [['True',
#     {'nominees': ['louis c.k.',
#       'don cheadle',
#       'ricky gervais',
#       'william h. macy'],
#      'presenters': ['jane fonda', 'lily tomlin'],
#      'winner': 'jeffrey tambor'}]]],
#  ['best performance by an actress in a mini-series or motion picture made for television',
#   ['Guess',
#    {'nominees': ['Maggie Gyllenhaal',
#      'Gina Rodriguez',
#      'Adrien Brody',
#      'Kate Beckinsale',
#      'Uzo Aduba',
#      'Kathy Bates',
#      'Dakota Johnson',
#      'Amy Adams',
#      'Allison Tolman',
#      'Judith Light'],
#     'winner': 'Joanne Froggatt',
#     'presenters': []}],
#   [['True',
#     {'nominees': ['jessica lange',
#       'frances mcdormand',
#       "frances o'connor",
#       'allison tolman'],
#      'presenters': ['kate beckinsale', 'adrien brody'],
#      'winner': 'maggie gyllenhaal'}]]],
#  ['best performance by an actor in a mini-series or motion picture made for television',
#   ['Guess',
#    {'nominees': ['Billy Bob Thornton',
#      'Matt Bomer',
#      'Kevin Spacey',
#      'Jeffrey Tambor',
#      'Jeremy Renner',
#      'Mark Ruffalo',
#      'Jon Voight',
#      'James Spader',
#      'Woody Harrelson',
#      'Katie Holmes',
#      'Seth Meyers',
#      'Alan Cumming',
#      'Colin Hanks',
#      'Frank Underwood'],
#     'winner': 'Billy Bob',
#     'presenters': []}],
#   [['True',
#     {'nominees': ['martin freeman',
#       'woody harrelson',
#       'matthew mcconaughey',
#       'mark ruffalo'],
#      'presenters': ['jennifer lopez', 'jeremy renner'],
#      'winner': 'billy bob thornton'}]]],
#  ['best performance by an actress in a supporting role in a series, mini-series or motion picture made for television',
#   ['Guess',
#    {'nominees': ['Maggie Gyllenhaal',
#      'Uzo Aduba',
#      'Kathy Bates',
#      'Dakota Johnson'],
#     'winner': 'Joanne Froggatt',
#     'presenters': []}],
#   [['True',
#     {'nominees': ['uzo aduba',
#       'kathy bates',
#       'allison janney',
#       'michelle monaghan'],
#      'presenters': ['jamie dornan', 'dakota johnson'],
#      'winner': 'joanne froggatt'}]]],
#  ['best performance by an actor in a supporting role in a series, mini-series or motion picture made for television',
#   ['Guess',
#    {'nominees': ['Matt Bomer',
#      'Billy Bob Thornton',
#      'Jon Voight',
#      'Alan Cumming',
#      'Colin Hanks',
#      'Mark Ruffalo'],
#     'winner': 'Matt Bomer',
#     'presenters': []}],
#   [['True',
#     {'nominees': ['alan cumming', 'colin hanks', 'bill murray', 'jon voight'],
#      'presenters': ['katie holmes', 'seth meyers'],
#      'winner': 'matt bomer'}]]]]

# %%
media = set()

# %%
url = 'https://query.wikidata.org/sparql'
query = """
SELECT DISTINCT ?itemLabel  WHERE {
 # ?item wdt:P31 wd:Q11424. ?item wdt:P577 ?_publication_date. ?item wdt:P136 ?_genre.
 # ?_genre rdfs:label ?_genreLabel. BIND(str(YEAR(?_publication_date)) AS ?year)
 FILTER((LANG(?_genreLabel)) = "en")
 FILTER (?_publication_date >= "2010-00-00T00:00:00Z"^^xsd:dateTime && ?_publication_date <= "2019-00-00T00:00:00Z"^^xsd:dateTime )
 SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en" .} }
"""
r = requests.get(url, params = {'format': 'json', 'query': query})
kb_m = r.json()

for item in kb_m['results']['bindings']:
    media.add(unidecode.unidecode(item['itemLabel']['value']))
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-87-017393ca4763> in <module>
#       9 """
#      10 r = requests.get(url, params = {'format': 'json', 'query': query})
# ---> 11 kb_m = r.json()
#      12
#      13 for item in kb_m['results']['bindings']:
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/requests/models.py in json(self, **kwargs)
#     895                     # used.
#     896                     pass
# --> 897         return complexjson.loads(self.text, **kwargs)
#     898
#     899     @property
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/json/__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     346             parse_int is None and parse_float is None and
#     347             parse_constant is None and object_pairs_hook is None and not kw):
# --> 348         return _default_decoder.decode(s)
#     349     if cls is None:
#     350         cls = JSONDecoder
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/json/decoder.py in decode(self, s, _w)
#     335
#     336         """
# --> 337         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338         end = _w(s, end).end()
#     339         if end != len(s):
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/json/decoder.py in raw_decode(self, s, idx)
#     351         """
#     352         try:
# --> 353             obj, end = self.scan_once(s, idx)
#     354         except StopIteration as err:
#     355             raise JSONDecodeError("Expecting value", s, err.value) from None
#
# JSONDecodeError: Invalid control character at: line 102971 column 44 (char 2227511)

# %%
query = """
SELECT DISTINCT ?itemLabel  WHERE {
  # ?item wdt:P31 wd:Q5398426.
  # ?item wdt:P580  ?_start
 FILTER (?_start >= "2000-00-00T00:00:00Z"^^xsd:dateTime && ?_start <= "2019-00-00T00:00:00Z"^^xsd:dateTime )
  SERVICE wikibase:label {bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en" .}
}
    
"""
r = requests.get(url, params = {'format': 'json', 'query': query})
kb_m = r.json()

for item in kb_m['results']['bindings']:
    media.add(unidecode.unidecode(item['itemLabel']['value']))

# %%
def extractMediaNames(data, list1):
    #print(data[0])
    result = []
       
    #tt = TweetTokenizer(strip_handles=True, reduce_len=True, preserve_case=True)
    translator = str.maketrans('', '', string.punctuation)
    remove_terms = ['#goldenglobes', 'golden globes', '#goldenglobe', 'golden globe', 'goldenglobes', 'goldenglobe', 'rt', 'golden', 'globe', 'globes']    
    stop = remove_terms + list1
    
    for tweet in data:
        #print(tweet)
        tweet = re.sub("\d+", "", tweet)      #strip nums
        tweet = re.sub(r'http\S+', '', tweet) #strip urls
        tweet = re.sub(r'#\S+', '', tweet)    #strip hashtags
        tweet = tweet.translate(translator)   #strip non-alphanumeric characters
        tweet = tweet.split()                 #tokenize
        tweet = [term for term in tweet if term.lower() not in stop_words] #remove stop words
        for i in stop:
            for j in tweet:
                if i.lower() in j.lower():
                    tweet.remove(j)
        result.append(tweet)
        
    #print(result[:20])
        
    grams = [];

    for tweet in result:
        if tweet:
            
            grams = re.findall(r"([A-Z][\w-]*(?:\s+[A-Z][\w-]*)+)",tweet)
            
            """
            gram = list(nltk.everygrams(tweet, 2, 3))
            #print(bigram[:10])
            for g in gram:
                if len(g) == 2:
                    if bool(re.match(r'\b[A-Z][a-z]+\b', g[0])) and bool(re.match(r'\b[A-Z][a-z]+\b', g[1])):
                        grams.append(g)
                else:
                    if bool(re.match(r'\b[A-Z][a-z]+\b', g[0])) and bool(re.match(r'\b[A-Z][a-z]+\b', g[1])) and bool(re.match(r'\b[A-Z][a-z]+\b', g[2])):
                        grams.append(g)
            """ 

  
    fdist = nltk.FreqDist(grams)
    #print(fdist)

    try:
        names = fdist.most_common()
        #names = [' '.join(i[0]) for i in fdist.most_common()]
    except:
        names = "nothing here"
    
    return names
