# %%
import pandas as pd
import numpy as np

import nltk
from nltk.probability import FreqDist
from nltk.tokenize import TweetTokenizer
from nltk.corpus import stopwords

import string
import re
from collections import Counter
from collections import OrderedDict


from nltk.corpus import wordnet
nltk.download('wordnet')

import unidecode
import requests
import json
from pprint import pprint
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/keithpallo/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
OFFICIAL_AWARDS_1315_media = ['best motion picture - drama', 'best motion picture - comedy or musical', 'best animated feature film', 'best foreign language film', 'best screenplay - motion picture', 'best original score - motion picture', 'best original song - motion picture', 'best television series - drama', 'best television series - comedy or musical', 'best mini-series or motion picture made for television']

# %%
with open('gg2015answers.json') as f:
    answers = json.load(f)
    
true_dict = answers['award_data'] # use this for true dict in the below function

# %%
data = pd.read_json('../gg2015.json')
data = pd.DataFrame(data)

# %%
data = data['text'].values.tolist()

# %%
people = set()

# %%
url = 'https://query.wikidata.org/sparql'

# %%
query = """
# ALL PERSONS required for awards
SELECT DISTINCT ?person ?personLabel WHERE {
# FIRST: uncomment occupation:
  # ?person wdt:P31 wd:Q5;
           wdt:P106/wdt:P279* wd:Q2526255; #uncomment for     FILM director (no award for TV director)
  FILTER NOT EXISTS { ?person wdt:P570 ?date. } #person is alive
  
# SECOND: uncomment gender if applicable (for actor/actress):
#          wdt:P21 wd:Q6581097;    #male
#          wdt:P21 wd:Q6581072;    #female
  SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
}
"""
r = requests.get(url, params = {'format': 'json', 'query': query})
kb = r.json()
for item in kb['results']['bindings']:
    people.add(unidecode.unidecode(item['personLabel']['value']))

# %%
query = """
# ALL PERSONS required for awards
SELECT DISTINCT ?person ?personLabel WHERE {
# FIRST: uncomment occupation:
  # ?person wdt:P31 wd:Q5;
           wdt:P106/wdt:P279* wd:Q10800557; #uncomment for    FILM actor (don't just use actor)
  FILTER NOT EXISTS { ?person wdt:P570 ?date. } #person is alive
  
# SECOND: uncomment gender if applicable (for actor/actress):
#          wdt:P21 wd:Q6581097;    #male
#          wdt:P21 wd:Q6581072;    #female
  SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
}
"""
r1 = requests.get(url, params = {'format': 'json', 'query': query})
kb1 = r1.json()
for item in kb1['results']['bindings']:
    people.add(unidecode.unidecode(item['personLabel']['value']))

# %%
query = """
# ALL PERSONS required for awards
SELECT DISTINCT ?person ?personLabel WHERE {
# FIRST: uncomment occupation:
  # ?person wdt:P31 wd:Q5;
           wdt:P106/wdt:P279* wd:Q10798782; #uncomment for    TV actor (don't just use actor)
  FILTER NOT EXISTS { ?person wdt:P570 ?date. } #person is alive
  
# SECOND: uncomment gender if applicable (for actor/actress):
#          wdt:P21 wd:Q6581097;    #male
#          wdt:P21 wd:Q6581072;    #female
  SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
}
"""
r = requests.get(url, params = {'format': 'json', 'query': query})
kb = r.json()
for item in kb['results']['bindings']:
    people.add(unidecode.unidecode(item['personLabel']['value']))

# %%
query = """
# ALL PERSONS required for awards
SELECT DISTINCT ?person ?personLabel WHERE {
# FIRST: uncomment occupation:
  # ?person wdt:P31 wd:Q5;
           wdt:P106/wdt:P279* wd:Q36834; #uncomment for       composer (cannot use songwriter)
  FILTER NOT EXISTS { ?person wdt:P570 ?date. } #person is alive
  
# SECOND: uncomment gender if applicable (for actor/actress):
#          wdt:P21 wd:Q6581097;    #male
#          wdt:P21 wd:Q6581072;    #female
  SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
}
"""
r = requests.get(url, params = {'format': 'json', 'query': query})
kb = r.json()
for item in kb['results']['bindings']:
    people.add(unidecode.unidecode(item['personLabel']['value']))

# %%
query = """
# ALL PERSONS required for awards
SELECT DISTINCT ?person ?personLabel WHERE {
# FIRST: uncomment occupation:
  # ?person wdt:P31 wd:Q5;
           wdt:P106/wdt:P279* wd:Q28389; #uncomment for       screenwriter
  FILTER NOT EXISTS { ?person wdt:P570 ?date. } #person is alive
  
# SECOND: uncomment gender if applicable (for actor/actress):
#          wdt:P21 wd:Q6581097;    #male
#          wdt:P21 wd:Q6581072;    #female
  SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
}
"""
r = requests.get(url, params = {'format': 'json', 'query': query})
kb = r.json()
for item in kb['results']['bindings']:
    people.add(unidecode.unidecode(item['personLabel']['value']))

# %%
media = set()

# %%
url = 'https://query.wikidata.org/sparql'
query = """
SELECT DISTINCT ?itemLabel  WHERE {
 # ?item wdt:P31 wd:Q11424. ?item wdt:P577 ?_publication_date. ?item wdt:P136 ?_genre.
 # ?_genre rdfs:label ?_genreLabel. BIND(str(YEAR(?_publication_date)) AS ?year)
 FILTER((LANG(?_genreLabel)) = "en")
 FILTER (?_publication_date >= "2010-00-00T00:00:00Z"^^xsd:dateTime && ?_publication_date <= "2019-00-00T00:00:00Z"^^xsd:dateTime )
 SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en" .} }
"""
r = requests.get(url, params = {'format': 'json', 'query': query})
kb_m = r.json()

for item in kb_m['results']['bindings']:
    media.add(unidecode.unidecode(item['itemLabel']['value']))

# %%
query = """
SELECT DISTINCT ?itemLabel  WHERE {
  # ?item wdt:P31 wd:Q5398426.
  # ?item wdt:P580  ?_start
 FILTER (?_start >= "2000-00-00T00:00:00Z"^^xsd:dateTime && ?_start <= "2019-00-00T00:00:00Z"^^xsd:dateTime )
  SERVICE wikibase:label {bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en" .}
}
    
"""
r = requests.get(url, params = {'format': 'json', 'query': query})
kb_m = r.json()

for item in kb_m['results']['bindings']:
    media.add(unidecode.unidecode(item['itemLabel']['value']))

# %%
f = open('english.txt', 'r')
stop_words = f.read().splitlines()
#print(stopwords)

# %%
OFFICIAL_AWARDS_1315_people = ['cecil b. demille award',
                        'best performance by an actress in a motion picture - drama', 
                        'best performance by an actor in a motion picture - drama',
                        'best performance by an actress in a motion picture - comedy or musical', 
                        'best performance by an actor in a motion picture - comedy or musical',
                        'best performance by an actress in a supporting role in a motion picture', 
                        'best performance by an actor in a supporting role in a motion picture', 
                        'best director - motion picture', 
                        'best screenplay - motion picture', 
                        'best original score - motion picture',
                        'best performance by an actress in a television series - drama', 
                        'best performance by an actor in a television series - drama',
                        'best performance by an actress in a television series - comedy or musical', 
                        'best performance by an actor in a television series - comedy or musical', 
                        'best performance by an actress in a mini-series or motion picture made for television', 
                        'best performance by an actor in a mini-series or motion picture made for television', 
                        'best performance by an actress in a supporting role in a series, mini-series or motion picture made for television', 
                        'best performance by an actor in a supporting role in a series, mini-series or motion picture made for television']

# %%
def parseAward(award):
    award = re.split('\W+', award)
    award = [i for i in award if i not in stop_words]
    award = list(set(award))
    return award

# %%
def getCategoriesDict(awards_list):
    categories_dict = dict()
    for a in awards_list:
        terms = parseAward(a)
        categories_dict[a] = terms

    return categories_dict

# %%
people_categories_dict = getCategoriesDict(OFFICIAL_AWARDS_1315_people)

# %%
media_categories_dict = getCategoriesDict(OFFICIAL_AWARDS_1315_media)

# %%
media_categories_dict
# Out:
# {'best motion picture - drama': ['motion', 'drama', 'picture'],
#  'best motion picture - comedy or musical': ['motion',
#   'musical',
#   'picture',
#   'comedy'],
#  'best animated feature film': ['feature', 'film', 'animated'],
#  'best foreign language film': ['film', 'foreign', 'language'],
#  'best screenplay - motion picture': ['motion', 'screenplay', 'picture'],
#  'best original score - motion picture': ['score',
#   'motion',
#   'original',
#   'picture'],
#  'best original song - motion picture': ['song',
#   'motion',
#   'original',
#   'picture'],
#  'best television series - drama': ['drama', 'series', 'television'],
#  'best television series - comedy or musical': ['comedy',
#   'musical',
#   'series',
#   'television'],
#  'best mini-series or motion picture made for television': ['mini',
#   'motion',
#   'picture',
#   'series',
#   'television']}

# %%
def filter0(data, list1, extra = False):
    synonyms = {}
    
    if extra:
        synonyms = {
            'motion' : ['motion picture', 'motion', 'picture', 'movie'],
            'picture' : ['motion picture', 'motion', 'picture', 'movie'],
            'television' : ['television', 'tv'],
            'mini' : ['mini-series', 'mini', 'series', 'miniseries'],
            'series' : ['mini-series', 'mini', 'series', 'miniseries']
        }

    
    result = []
    
    list1 = [i for i in list1 if i != 'performance' and i != 'role']

    for tweet in data:
        cond = True
        for i in list1:
            if i in synonyms:
                if all(j not in tweet.lower() for j in synonyms[i]):
                    cond = False
            elif i not in tweet.lower():
                cond = False
        if cond:
            result.append(tweet)

    return result

# %%
def extractPeople(data, list1):
    #print(data[0])
    result = []
       
    #tt = TweetTokenizer(strip_handles=True, reduce_len=True, preserve_case=True)
    translator = str.maketrans('', '', string.punctuation)
    remove_terms = ['#goldenglobes', 'golden globes', '#goldenglobe', 'golden globe', 'goldenglobes', 'goldenglobe', 'rt', 'golden', 'globe', 'globes']
    stop = remove_terms + list1
    
    for tweet in data:
        #print(tweet)
        tweet = re.sub("\d+", "", tweet) #strip nums
        tweet = re.sub(r'http\S+', '', tweet) #strip urls
        tweet = re.sub(r'#\S+', '', tweet) #strip hashtags
        tweet = tweet.translate(translator) #strip non-alphanumeric characters
        tweet = tweet.split() #tokenize
        tweet = [term for term in tweet if term.lower() not in stop_words] #remove stop words
        for i in stop:
            for j in tweet:
                if i.lower() in j.lower():
                    tweet.remove(j)
        result.append(tweet)
        
    #print(result[:20])
        
    grams = [];

    for tweet in result:
        if tweet:
            gram = list(nltk.everygrams(tweet, 2, 3))
            #print(bigram[:10])
            for g in gram:
                if len(g) == 2:
                    if bool(re.match(r'\b[A-Z][a-z]+\b', g[0])) and bool(re.match(r'\b[A-Z][a-z]+\b', g[1])):
                        grams.append(g)
                else:
                    if bool(re.match(r'\b[A-Z][a-z]+\b', g[0])) and bool(re.match(r'\b[A-Z][a-z]+\b', g[1])) and bool(re.match(r'\b[A-Z][a-z]+\b', g[2])):
                        grams.append(g)

  
    fdist = nltk.FreqDist(grams)
    #print(fdist)

    try:
        names = fdist.most_common()
        #names = [' '.join(i[0]) for i in fdist.most_common()]
    except:
        names = "nothing here"
    
    return names

# %%
def extractMedia(data, list1):
    #print(data[0])
    result = []
       
    #tt = TweetTokenizer(strip_handles=True, reduce_len=True, preserve_case=True)
    translator = str.maketrans('', '', string.punctuation)
    remove_terms = ['#goldenglobes', 'golden globes', '#goldenglobe', 'golden globe', 'goldenglobes', 'goldenglobe', 'rt', 'golden', 'globe', 'globes', 'best']    
    stop = remove_terms + list1
    
    for tweet in data:
        #print(tweet)
        tweet = re.sub("\d+", "", tweet)      #strip nums
        tweet = re.sub(r'http\S+', '', tweet) #strip urls
        tweet = re.sub(r'#\S+', '', tweet)    #strip hashtags
        tweet = tweet.translate(translator)   #strip non-alphanumeric characters
        tweet = tweet.split()                 #tokenize
        #tweet = [term for term in tweet if term.lower() not in stop_words] #remove stop words
        for i in stop:
            for j in tweet:
                if i.lower() in j.lower():
                    tweet.remove(j)
        tweet = ' '.join(tweet)
        result.append(tweet)
        
    #print(result[:20])
        
    grams = [];

    for tweet in result:
        if tweet:
            
            grams.extend(re.findall(r"([A-Z][\w-]*(?:\s+[A-Z][\w-]*)+)", tweet))
            grams.extend(re.findall(r"\b[A-Z][a-z]+\b.*\b[A-Z][a-z]+\b", tweet))
            #singular = re.findall(r"\b[A-Z][a-z]+\b", tweet)
            #singular = [i for i in singular if not wordnet.synsets(i)]
            #grams.extend(singular)
            
  
    fdist = nltk.FreqDist(grams)
    #print(fdist)

    try:
        names = fdist.most_common()
        #names = [' '.join(i[0]) for i in fdist.most_common()]
    except:
        names = "nothing here"
    
    return names

# %%
re.findall(r"((\b[A-Z][a-z]+\b)(.)*(\b[A-Z][a-z]+\b))", 'The Theory of Everything')
# Out:
# [('The Theory of Everything', 'The', ' ', 'Everything')]

# %%
def get_people_nom(award_list, categories_dict):
    d = {}
    for award in award_list:
        d["{0}".format(award)] = filter0(data, categories_dict[award])
        
    print(len(d.keys()))
            
    nominees = {}
    for award in award_list:
        nominees["{0}".format(award)] = extractPeople(d[award], categories_dict[award])
    
    return nominees

# %%
def get_category_tweets(award_list, categories_dict):
    d = {}
    for award in award_list:
        d["{0}".format(award)] = filter0(data, categories_dict[award])
                                         
    return d

# %%
def get_media_nom(award_list, categories_dict, d):

    
    nominees = {}
    for award in award_list:
        nominees["{0}".format(award)] = extractMedia(d[award], categories_dict[award])
    
    return nominees

# %%
import timeit
start_time = timeit.default_timer()
tweets = get_category_tweets(OFFICIAL_AWARDS_1315_media, media_categories_dict)
elapsed = timeit.default_timer() - start_time
print(elapsed)
# Out:
# 22.43589629099006

# %%
#tweets

# %%
print(len(tweets))
# Out:
# 10

# %%
media_nominees = get_media_nom(OFFICIAL_AWARDS_1315_media, media_categories_dict, tweets)

# %%
media_nominees
# Out:
# {'best motion picture - drama': [('Still Alice', 2422),
#   ('Julianne Moore', 2404),
#   ('Eddie Redmanye The Theory', 2273),
#   ('Actor in a Eddie Redmanye The Theory of Everything', 2203),
#   ('Eddie Redmayne', 1750),
#   ('The Theory', 1739),
#   ('Boyhood BoyhoodMovie', 1615),
#   ('Actress in a Julianne Moore juliannemoore Still Alice', 1471),
#   ('Richard Linklaters Boyhood', 439),
#   ('Actor goes to Eddie Redmayne', 429),
#   ('EW Actor', 428),
#   ('Congrats Eddie Redmayne', 427),
#   ('BBCBreaking Richard Linklaters Boyhood', 418),
#   ('Congrats Eddie Redmayne wins Actor in a for The Theory of Everything',
#    417),
#   ('Actor in a goes to Eddie Redmayne for ‘The Theory of Everything', 360),
#   ('Winner Boyhood', 300),
#   ('IMDb Winner Boyhood', 290),
#   ('Eddie Redmayne wins Actor in a for The Theory of Everything', 254),
#   ('THR Eddie Redmayne', 228),
#   ('Winner Actor in a Eddie Redmayne for The Theory of Everything', 228),
#   ('IMDb Winner Actor', 228),
#   ('Actress in a goes to Julianne Moore for Still Alice', 214),
#   ('Congratulations Julianne Moore for winning the for Actress', 189),
#   ('Eddie Redmayne The Theory', 189),
#   ('SAmoviefansite Congratulations Julianne Moore', 188),
#   ('THR Wins', 185),
#   ('Actress in a for Still Alice', 174),
#   ('Boyhood Wins', 170),
#   ('THR JulianneMoore', 167),
#   ('Boyhood’ Wins', 158),
#   ('The winner for Actress in a is Julianne Moore for Still Alice', 148),
#   ('Julianne Moore Wins Actress', 135),
#   ('Julianne Moore wins Actress', 127),
#   ('The winner for is Boyhood', 127),
#   ('Eddie Redmayne wins Actor in a for his role in The Congrats', 124),
#   ('The Congrats', 123),
#   ('Julianne Moore Still Alice', 113),
#   ('EW Julianne Moore', 112),
#   ('Winnner Performance by an Actress in a Julianne Moore for Still Alice',
#    109),
#   ('IMDb Winnner Performance', 108),
#   ('Actor in a goes to Eddie Redmayne in The Theory of Everything', 108),
#   ('HuffingtonPost Actor', 105),
#   ('Performance by an Actor in a Eddie Redmayne The Theory of Everything',
#    104),
#   ('Actress in a Welldeserved', 87),
#   ('Eddie Redmayne Wins Actor', 83),
#   ('Goes to Boyhood', 79),
#   ('Actor in a goes to Eddie Redmayne for The Theory of Everything', 76),
#   ('Actress in a goes to Julianne Moore in Still Alice', 74),
#   ('Actress In A', 74),
#   ('THR Julianne Moore Wins Actress', 74),
#   ('HuffingtonPost Actress', 72),
#   ('Eddie Redmayne Actor', 72),
#   ('Everything GMA', 71),
#   ('Boyhood GMA', 71),
#   ('ABC Actor', 70),
#   ('Actor In', 69),
#   ('ABC JUST IN', 69),
#   ('Eddie Redmayne Wins For Actor', 66),
#   ('Actor In A', 65),
#   ('Congrats to JulianneMoore on her Actress', 63),
#   ('Fox Boyhood', 56),
#   ('Boyhood Wins At Boyhood', 53),
#   ('Culturalist Retweet', 51),
#   ('Still Alice GMA', 50),
#   ('Actor in a Eddie Redmayne The Theory of Everything', 49),
#   ('ABC Actress', 48),
#   ('Eddie Redmayne Wins The Award For Actor In A His', 48),
#   ('Actress in a Julianne Moore Still Alice', 46),
#   ('BBCNewsEnts Boyhood', 46),
#   ('Wearing Givenchy', 43),
#   ('Julianne Moore wins Actress In A for Wearing Givenchy', 43),
#   ('Julianne Moore for Still Alice', 42),
#   ('WhoWhatWear Julianne Moore', 42),
#   ('Culturalist Retweet to congratulate Eddie Redmayne Actor', 41),
#   ('Boyhood Proves That Unique Storytelling Can Win Big With The Award For',
#    41),
#   ('OFFICIAL PREDICTION The', 38),
#   ('I FRANKENSTEIN', 38),
#   ('Boyhood Wins The', 38),
#   ('Actress In', 35),
#   ('Wins For', 35),
#   ('Eddie Redmayne Wins', 35),
#   ('Didnt Go To BUT Well Done', 34),
#   ('The for goes to Boyhood', 32),
#   ('Boyhood Grand Budapest Hotel', 32),
#   ('Actress in a Julianne Moore', 31),
#   ('Eddie Redmayne Wins The Award For Actor In', 31),
#   ('Congrats Eddie Redmanye for winning Actor in a The Theory of Everything',
#    30),
#   ('GuardianUS Boyhood', 30),
#   ('Eddie Redmayne Wins The Award For Actor In A', 30),
#   ('Actress Julianne Moore Actress in a with Freundlich', 29),
#   ('VisitBritain Congrats Eddie Redmanye', 29),
#   ('Actor in a Eddie Redmayne', 28),
#   ('Richard Linklaters', 28),
#   ('The Awards', 28),
#   ('ANCALERTS PHOTO Actress Julianne Moore Actress', 27),
#   ('Congratulations juliannemoore Actress', 27),
#   ('USATODAY The', 27),
#   ('Everything CB', 26),
#   ('Eddie Redmayne stock Actor in a for The Theory of Everything', 26),
#   ('Congrats to Eddie Redmayne for winning Actor in a for The Theory of Everything',
#    25),
#   ('Eddie Redmayne wins Actor in a for Theory of Everything', 24),
#   ('GMA I', 24),
#   ('TheWrap Actress', 23),
#   ('Actress in a Here', 23),
#   ('Eddie Redmayne Winner', 23),
#   ('BuzzFeedNews Boyhood', 23),
#   ('Culturalist Congrats', 22),
#   ('Culturalist Congrats to Eddie Redmayne Winner for Actor', 22),
#   ('TheInsider Actor', 22),
#   ('And congrats to Boyhood', 22),
#   ('Julianne Moore Wins The Award For Actress In A Woo', 22),
#   ('GMA Actress', 21),
#   ('Performance By An Actor In A', 21),
#   ('Meryl Streep', 20),
#   ('Congrats to Julianne Moore for winning Actress in a for Still Alice', 20),
#   ('Actor Eddie Redmayne The Theory', 20),
#   ('Actor Eddie Redmayne The Theory of Everything', 20),
#   ('TheWrap Actor', 20),
#   ('Congrats to Eddie Redmayne for Performance By An Actor In', 20),
#   ('WhoWhatWear Congrats', 20),
#   ('Boyhood wins for Richard Linklaters', 20),
#   ('The Song', 18),
#   ('Actress in a Julianne Moore for Still Alice', 18),
#   ('EDDIE REDMAYNE', 18),
#   ('THE THEORY OF EVERYTHING', 18),
#   ('Julianne Moore Wins', 18),
#   ('Black List', 17),
#   ('Boyhood’ Wins For', 17),
#   ('Nominated were MarkRuffalo Actor SteveCarell Actor', 17),
#   ('Eddie Redmayne Wins the for Actor', 17),
#   ('Variety “The Song of Bernadette', 16),
#   ('Congrats Actress', 16),
#   ('Actor in a is Eddie Redmayne', 16),
#   ('Eddie Redmayne for Theory of Everything', 16),
#   ('Stephen Hawking', 16),
#   ('Deadline ‘Boyhood’ Wins For', 16),
#   ('USAWrestling Nominated', 16),
#   ('MarkRuffalo Actor SteveCarell Actor D', 16),
#   ('Performance by an Actress in a Julianne Moore – Still Alice', 15),
#   ('Eddie Redmayne The Theory of Everything', 15),
#   ('Actor in a goes to Eddie Redmayne for his role in The Theory of Everything',
#    15),
#   ('TimesFilm Actor', 15),
#   ('HuffPostEnt Boyhood', 15),
#   ('KTLA BoyhoodMovie', 15),
#   ('Congratulations Actress in a Julianne Moore juliannemoore Still', 14),
#   ('Congrats Actress in a Julianne Moore juliannemoore Still Alice', 14),
#   ('Julianne Moore STILL ALICE', 14),
#   ('Eddie Redmayne wins Actor', 14),
#   ('Eddie Redmanye', 14),
#   ('Eddie Redmayne THE THEORY OF EVERYTHING', 14),
#   ('ForbesLife And', 14),
#   ('Richard Linklater Congrats', 14),
#   ('Goes to Boyhood directed by Richard Linklater Congrats', 14),
#   ('Julianne Moore Wins The Award For Actress In A', 14),
#   ('Julianne Moore Wins The Award For Actress In A Woo hoo Against', 14),
#   ('Actress in a goes to Julianne Moore', 13),
#   ('Girl Julianne Moore', 13),
#   ('Performance by an Actress in a Girl Julianne Moore – Still Alice', 13),
#   ('Actress in a is Julianne Moore', 13),
#   ('Actor in a goes to Eddie Redmayne', 13),
#   ('Eddie Redmayne for The Theory of Everything', 13),
#   ('Eddie Redmayne wins for actor in a for The Theory of Everything', 13),
#   ('America We', 13),
#   ('One more award America We’re so close…who do you have for Convince', 13),
#   ('Congratulations to juliannemoore for her Win for Actress', 13),
#   ('ABC THIS JUST IN Boyhood', 13),
#   ('Boyhood Wins The win marked the third award for the title on Sund', 13),
#   ('Richard Linklater', 12),
#   ('JULIANNE MOORE', 12),
#   ('Goes To', 12),
#   ('ANCALERTS Actress', 12),
#   ('QuarterQuellOrg Congratulations Actress', 12),
#   ('ForbesLife Actress', 12),
#   ('ForbesLife Eddie Redmayne', 12),
#   ('HungerGamesDWTC Congratulations', 12),
#   ('WINNER Boyhood', 12),
#   ('Julianne Moore Wins The Award For Actress In', 12),
#   ('Congratulations to juliannemoore for her win Actress', 12),
#   ('Actor Eddie Redmayne', 11),
#   ('The Grand Budapest Hotel', 11),
#   ('Julianne Moore wins Actress in a for her role in Still Alice', 11),
#   ('Eddie Radmayne', 11),
#   ('Actor in a goes to Eddie Radmayne for The Theory of Everything', 11),
#   ('CineplexMovies Actor', 11),
#   ('Congratulations to the amazing Julianne Moore juliannemoore for her Actress',
#    11),
#   ('Pemenang Actor', 11),
#   ('Pemenang Actor in a Eddie Redmayne The Theory of Everything', 11),
#   ('GMA One', 11),
#   ('Everything Eddie Redmayne Actor', 11),
#   ('The Theory of Everything Eddie Redmayne Actor', 11),
#   ('HGNewsChannel Congratulations', 11),
#   ('Actress Julianne Moore', 10),
#   ('Eddie Redmayne Theory', 10),
#   ('The Imitation Game', 10),
#   ('STILL ALICE', 10),
#   ('Actress Julianne Moore Still Alice', 10),
#   ('Actress in Julianne Moore for Still Alice', 10),
#   ('ANCALERTS Actor', 10),
#   ('TVAfterDark Eddie Redmayne', 10),
#   ('HGJabberjays Congratulations', 10),
#   ('Congratulations to Boyhood', 10),
#   ('Boyhood Wins At Richard Linklater Accepts Win For Director', 10),
#   ('Boyhood Wins The Hollywood', 10),
#   ('Jennifer Aniston', 9),
#   ('THE IMITATION GAME', 9),
#   ('David Oyelowo', 9),
#   ('Patricia Arquette', 9),
#   ('Jack Black', 9),
#   ('Culturalist Congratulations', 9),
#   ('LifeandStyle YAYYY', 9),
#   ('Showbiz Eddie Redmayne', 9),
#   ('Showbiz AND ANOTHER ONE', 9),
#   ('Last but not least Boyhood', 9),
#   ('Actress in Julianne Moore Still Alice', 8),
#   ('TVGuideMagazine Actress', 8),
#   ('The stunning Julianne Moore wins for Actress in a for Still Alice', 8),
#   ('Pemenang Actress', 8),
#   ('Pemenang Actress in a Julianne Moore Still Alice', 8),
#   ('Performance by an Actor in a Eddie Redmayne for The Theory of Everything',
#    8),
#   ('TVGuideMagazine Actor', 8),
#   ('CBSThisMorning Eddie Redmayne', 8),
#   ('The Theor', 8),
#   ('Eddie Redmayne wins the Award for actor in a for his performance in The Theor',
#    8),
#   ('Director Richard Linklater', 8),
#   ('Boyhood wins for Director Richard Linklater is a Houston', 8),
#   ('Congrats to Richard Linklater', 8),
#   ('LiveinLimbo Last', 8),
#   ('Awani Director Richard Linklaters Boyhood', 8),
#   ('Congrats juliannemoore for winning Actress', 8),
#   ('Julianne Moore Wins the for Actress', 8),
#   ('Boyhood Photo', 8),
#   ('Tweet AccessHollywood For', 7),
#   ('Julianne Moore wins Actress in a for Still Alice', 7),
#   ('Winning Julianne Moore', 7),
#   ('Winning Julianne Moore for Still Alice', 7),
#   ('Julianne Moore win the Award', 7),
#   ('Showbiz The', 7),
#   ('NewsBreaker WINNER Actor', 7),
#   ('Gwyneth Paltrow', 7),
#   ('Yay HUGE CONGRATS to Eddie Redmayne for his Actor', 7),
#   ('Actor in a Eddie Redmanye for The Theory of Everything', 7),
#   ('Zapit Congrats', 7),
#   ('Zapit Congrats to Eddie Redmayne Actor', 7),
#   ('Well done to Eddie Redmayne', 7),
#   ('Julianne Moore Actress', 7),
#   ('IAmJohnSparks Congratulations', 7),
#   ('And Boyhood', 7),
#   ('APEntertainment Boyhood', 7),
#   ('NewsBreaker WINNER Boyhood BoyhoodMovie', 7),
#   ('TheWrap Boyhood', 7),
#   ('KHOU Boyhood', 7),
#   ('AnonContent Congrats', 7),
#   ('Houston native Richard wins a for and Director', 7),
#   ('AlzheimersAus Congrats', 7),
#   ('Boyhood Wins At Boyhood nabbed at the Go', 7),
#   ('PERFORMANCE BY AN ACTOR IN A', 6),
#   ('Channing Tatum', 6),
#   ('Performance by an Actress in a Julianne Moore Still Alice', 6),
#   ('Culturalist Congratulations to juliannemoore Winner for Actress', 6),
#   ('CBSThisMorning Julianne Moore', 6),
#   ('Eddie Redmayne Web Eddie Wins the Award for Actor', 6),
#   ('WINNER Eddie Redmayne', 6),
#   ('Actor – WINNER Eddie Redmayne', 6),
#   ('Eddie Redmayne wins actor in a for The Theory of Everything', 6),
#   ('Actor in a Eddie Redmayne for The Theory of Everything', 6),
#   ('The award for Actor in a goes to Eddie Redmayne for The Theory of Everything',
#    6),
#   ('VIPteam Yay HUGE CONGRATS', 6),
#   ('ShowbizIT Actor', 6),
#   ('GuardianUS Eddie Redmayne', 6),
#   ('StylistMagazine Well', 6),
#   ('Eddie Redmayne wins Actor in a for his amazing performance as Stephen Hawking',
#    6),
#   ('CNNLADavid BOYHOOD', 6),
#   ('GlobalGrind Boyhood', 6),
#   ('Boyhood wins for Are', 6),
#   ('Read muirkates ★★★★★ review of Boyhood', 6),
#   ('Winners Full List The', 6),
#   ('BillBishopKHOU Houston', 6),
#   ('Eddie Redmayne Wins the for Actor in a The Awards', 6),
#   ('Photoset Benedict', 6),
#   ('Boyhood Wins the for The Awards were presented on Sunday', 6),
#   ('The Winners Imitation GameSelmaThe Theory', 6),
#   ('VOTE Tweet AccessHollywood For', 5),
#   ('Black List SELMA FOXCATCHER', 5),
#   ('Noms Boyhood Foxcatcher The Imitation Game Selma The Theory', 5),
#   ('David Oyelowo has arrived Hes up for Actor', 5),
#   ('PERFORMANCE BY AN ACTRESS IN A', 5),
#   ('Clive Owen', 5),
#   ('Oprah Winfrey', 5),
#   ('Performance by an Actress in a Julianne Moore for Still Alice', 5),
#   ('Goes To Julianne Moore', 5),
#   ('ManProject Actress', 5),
#   ('Actress in a is Julianne Moore for Still Alice', 5),
#   ('GuardianUS Julianne Moore', 5),
#   ('Winner Actor', 5),
#   ('Actor in a goes to Eddie Redmayne for What', 5),
#   ('Everything I', 5),
#   ('Actor in a goes to Eddie Redmayne Theory of Everything', 5),
#   ('Actor in goes to Eddie Redmayne', 5),
#   ('Everything YES', 5),
#   ('ERedmayneWeb Eddie Redmayne Web Eddie Wins', 5),
#   ('Awards Winners', 5),
#   ('MOVIECLIPS Eddie Redmayne', 5),
#   ('Of course Meryl Streep', 5),
#   ('ANCALERTS Boyhood', 5),
#   ('JUST IN Boyhood', 5),
#   ('Boyhood beats out Selma for the Award', 5),
#   ('CTVTelevision This', 5),
#   ('The for the on the goes to Boyhood', 5),
#   ('CNNIBNBreaking Boyhood', 5),
#   ('TheBlazeNOW BREAKING', 5),
#   ('Julianne Moore Wins the for Actress in a The were presented Sunday', 5),
#   ('Eddie Redmayne Wins the for Actor in a The Awards were presented on Sunday',
#    5),
#   ('Beverly H', 5),
#   ('Boyhood Wins the for The Awards were presented on Sunday night at the Beverly',
#    5),
#   ('TimesFilm Read', 5),
#   ('Actress in a nominee Jennifer Aniston for Black List', 4),
#   ('Benedict Cumberbatch', 4),
#   ('Actor in a nominee David Oyelowo in Black List', 4),
#   ('ElvisDuranShow Who', 4),
#   ('Who will win – Noms Boyhood Foxcatcher The Imitation Game Selma The Theory',
#    4),
#   ('SmileMoki VOTE Tweet AccessHollywood For', 4),
#   ('Jake Gyllenhaal', 4),
#   ('Gone Girl', 4),
#   ('The Theory Of Everything', 4),
#   ('MariaVictoriaBG Actress', 4),
#   ('Actress in a – Julianne Moore – Still Alice', 4),
#   ('Julianna Moore', 4),
#   ('Winner Actress', 4),
#   ('GossipCop ACTRESS Goes To Julianne Moore', 4),
#   ('TVGMDamian Actress', 4),
#   ('Matthew McConaughey', 4),
#   ('Actress Julieanne Moore Still Alice', 4),
#   ('Actress in a juliannemoore for Still Alice', 4),
#   ('Actress in a juliannemoore Still Alice', 4),
#   ('Eddie Redmayne THE THEORY OF EVERYTHING Actor', 4),
#   ('STyipwaiyee The', 4),
#   ('Goes To Eddie Redmayne', 4),
#   ('FilmFataleNYC Actor', 4),
#   ('Tough category Eddie Redmayne wins Actor in a for Theory of Everything',
#    4),
#   ('Actor in a The Theory of Everything', 4),
#   ('Julianne Moore Won Actor', 4),
#   ('Eddie Redmayne and Julianne Moore Won Actor and Actress', 4),
#   ('Actor in a goes to Eddie Redmayne for The Theory of Everything because Stephen Hawking',
#    4),
#   ('Eddie Redmayne YES', 4),
#   ('One more award Who', 4),
#   ('Everything Gran Estre', 4),
#   ('Actor in a Eddie Redmanye The Theory of Everything Gran Estre', 4),
#   ('Congrats Actor in a Eddie Redmanye The Theory of Everything', 4),
#   ('CineplexMovies Of', 4),
#   ('ManProject Boyhood', 4),
#   ('Boyhood IFC Films', 4),
#   ('BoyhoodMovie Winner', 4),
#   ('LanceUlanoff Boyhood', 4),
#   ('CBSShowbiz Boyhood', 4),
#   ('BoyhoodMovie Wooohooo', 4),
#   ('And the award for goes to BoyhoodMovie Wooohooo', 4),
#   ('West End', 4),
#   ('Congrats to West End amp Broadway veteran Eddie Redmayne on winning the for Actor',
#    4),
#   ('VhIndia The', 4),
#   ('WPTV The', 4),
#   ('Award For', 4),
#   ('Boyhood wins Award For', 4),
#   ('TheInsider A', 4),
#   ('Wins For Richard Linklater', 4),
#   ('DeccanChronicle BoyhoodMovie', 4),
#   ('Julianne Moore Wins the for Actress in a The', 4),
#   ('Boyhood Wins The win marked the third award for the title on Sunday', 4),
#   ('Hollywood Boyhood Wins The', 4),
#   ('Julianne Moore Wins The Award For Actress In A Woo hoo Aga', 4),
#   ('Eddie Redmanye Im', 4),
#   ('Actor in a Eddie Redmanye Im', 4),
#   ('Boyhood Wins At Boyhood nabbed Pi', 4),
#   ('Michael Keaton Actor', 4),
#   ('Michael Keaton Actor in a Comedy or Photo', 4),
#   ('Julianne Moore Actress in a Photo', 4),
#   ('Boyhood Wins Hollywood', 4),
#   ('Eddie Redmayne Actor in a The Theory of Everything', 4),
#   ('Photoset Eddie Redmayne', 4),
#   ('Satisha Satisha', 4),
#   ('Shailene Woodley', 4),
#   ('VOTE Tweet', 3),
#   ('Up for Actress', 3),
#   ('NeilRosenApples NY Review', 3),
#   ('Watch a NeilRosenApples NY Review', 3),
#   ('The Theory of Everything', 3),
#   ('Eddie Redmayne Theory of Everything', 3),
#   ('JK Simmons', 3),
#   ('Amy Adams', 3),
#   ('Who you think will wing Vote here billbrownstein says Boyhood', 3),
#   ('PERFORMANCE BY AN ACTORACTRESS IN A', 3),
#   ('Channing Tatum introduces nominee Foxcatcher', 3),
#   ('WINNER Actress', 3),
#   ('JULIANNE MOORE Still Alice', 3),
#   ('Actress in a JULIANNE MOORE Still Alice', 3),
#   ('Julianne More', 3),
#   ('Actress in a goes to Julianne More for Still Alice', 3),
#   ('Actress In A Julianne Moore Still Alice', 3),
#   ('WINNER Julianne Moore STILL ALICE Actress', 3),
#   ('Julianne Moore STILL ALICE Actress', 3),
#   ('CineplexMovies Actress', 3),
#   ('YES Actress', 3),
#   ('Still Alice YES', 3),
#   ('Mel YES Actress', 3),
#   ('Mel YES Actress in a Julianne Moore juliannemoore Still Alice', 3),
#   ('Congratulations Actress', 3),
#   ('Congratulations Actress in a Julianne Moore juliannemoore Still Alice', 3),
#   ('Julianne Moore picks up Actress In a for Still Alice', 3),
#   ('Congrats to Julianna Moore', 3),
#   ('Julianne Moore wins actress in a for Still Alice', 3),
#   ('Actress goes to Julianne Moore', 3),
#   ('Congrats to for juliannemoore’s win Performance by an Actress', 3),
#   ('NewsBreaker WINNER Actress', 3),
#   ('Julianne Moore takes the award for Actress', 3),
#   ('ShowbizIT Actress', 3),
#   ('Julianne Moore Still Alice No', 3),
#   ('Actress in a Julianne Moore Still Alice No', 3),
#   ('Matthew Mcconaughey', 3),
#   ('The lovely wins the actress in a for Congrats', 3),
#   ('WINNER Actor', 3),
#   ('Actor Eddie Redmayne for The Theory of Everything', 3),
#   ('EDDIE REDMAYNE The Theory', 3),
#   ('Actor in a EDDIE REDMAYNE The Theory of Everything', 3),
#   ('WINNER Eddie Redmayne THE THEORY OF EVERYTHING Actor', 3),
#   ('Eddie Redmayne wins the for Actor in a for The Theory of Everything', 3),
#   ('Eddie Redmayne wins the for the Actor', 3),
#   ('Eddie Redmanye The Theory Of Everything', 3),
#   ('Actor in Eddie Redmanye The Theory Of Everything', 3),
#   ('GossipCop ACTOR Goes To Eddie Redmayne', 3),
#   ('Eddie Redmayne Theory Of Everything', 3),
#   ('Actor goes to Eddie Redmayne Theory Of Everything', 3),
#   ('Eddie Redmayne Yay', 3),
#   ('Everything Yes', 3),
#   ('Actor in a Eddie Redmanye The Theory of Everything Yes', 3),
#   ('Winning Eddie Redmayne', 3),
#   ('Winning Eddie Redmayne for The Theory of Everything', 3),
#   ('Double YES Actor', 3),
#   ('Double YES Actor in a Eddie Redmanye The Theory of Everything', 3),
#   ('HQ Actor', 3),
#   ('LIVE Actor', 3),
#   ('StarryMag Actress', 3),
#   ('Eddie Redmanye Actor', 3),
#   ('KHOU The', 3),
#   ('CSTsizzle Actor', 3),
#   ('Everything Calls', 3),
#   ('Actor in a The Theory of Everything Calls', 3),
#   ('Lead Actor', 3),
#   ('Actor in a Eddie Redmayne for Thank god He', 3),
#   ('Everything Congrats Eddie', 3),
#   ('Actor in a Eddie Redmanye The Theory of Everything Congrats Eddie', 3),
#   ('TheSunShowbiz Actress', 3),
#   ('Eddie Redmayne But', 3),
#   ('Brits OWNED', 3),
#   ('IAmJohnSparks Eddie Redmayne', 3),
#   ('KARKNews Actor', 3),
#   ('PIXNews Who', 3),
#   ('Still Alice ได้ Actress in a ของ Julianne Moore', 3),
#   ('OnAirWithRyan One', 3),
#   ('Everythings Eddie Redmayne', 3),
#   ('The Theory of Everythings Eddie Redmayne wins the Actor', 3),
#   ('And the winner for is Boyhood', 3),
#   ('GossipCop Goes To BOYHOOD', 3),
#   ('Last award of the night goes to Boyhood', 3),
#   ('The final award of the tonight for the category goes to Boyhood', 3),
#   ('Boyhood wins Award for – over Selma', 3),
#   ('Boyhood No', 3),
#   ('Well deserved mashable goes to ‘Boyhood', 3),
#   ('Congratulations BoyhoodMovie', 3),
#   ('Congratulations Boyhood', 3),
#   ('The big award wins the for Congratulations', 3),
#   ('Boyhood Yay', 3),
#   ('CELEBUZZ And', 3),
#   ('HLNTV Boyhood', 3),
#   ('Congrats BoyhoodMovie', 3),
#   ('Happy dance Congrats', 3),
#   ('Eddie Redmayne wins Actor Eddie Redmayne', 3),
#   ('Culturalist Congratulations to BoyhoodMovie Winner', 3),
#   ('ReutersIndia Boyhood', 3),
#   ('TheAPJournalist Actor', 3),
#   ('THESOURCE Boyhood', 3),
#   ('Boyhood See', 3),
#   ('Picture Comedy', 3),
#   ('Picture Comedy or Musical', 3),
#   ('Eddie Redmayne Wins the Actor', 3),
#   ('Awards The', 3),
#   ('Boyhood wins big at the Awards The', 3),
#   ('Boyhood Proves That Unique Storytelling Can Win Big With The Award For — We',
#    3),
#   ('Congrats to Actor', 3),
#   ('Our Austin', 3),
#   ('Congrats to Boyhood for winning the for a Our Austin', 3),
#   ('Boyhood VIA HuffingtonPost', 3),
#   ('Winner Julianne Moore Still Alice', 3),
#   ('Actress in a Winner Julianne Moore Still Alice', 3),
#   ('TheSunShowbiz Boyhood', 3),
#   ('TelegraphFilm Boyhood', 3),
#   ('Eddie Actor in a Theory of Everything', 3),
#   ('Photoset Eddie Redmayne accepting his for Performance', 3),
#   ('Director Richard Linklaters year masterpiece Boyhood', 3),
#   ('Satisha Satisha s seconds ago Boyhooyd', 3),
#   ('My opinion tht Actress in a Winner for Shailene Woodley', 3),
#   ('DarwinMovie Actress', 3),
#   ('Eddie Redmayne bags the coveted Actor in a for The Theory of Everything',
#    3),
#   ('Itsoktobeyouorg Video', 3),
#   ('Itsoktobeyouorg Video of Julianne accepting her Actress in a Award for Still Alice',
#    3),
#   ('Actor in a nominee SteveCarell in Black List', 2),
#   ('Actor in a nominee Benedict Cumberbatch in Black List', 2),
#   ('Tweet accesshollywood For', 2),
#   ('A Beautiful Mind Day', 2),
#   ('Performance by an Actor in a russellcrowe A Beautiful Mind Day', 2),
#   ('Film Awards Predictions Selma Movie Musical', 2),
#   ('Which Would You Win', 2),
#   ('NY Watch', 2),
#   ('Rosamund Pike', 2),
#   ('Actor in a is going to go to Jake Gyllenhaal', 2),
#   ('Boyhood Comedy Birdman Animated Film The Lego Movie', 2),
#   ('Actress – Award', 2),
#   ('The Song of Bernadette', 2),
#   ('Predictions Boyhood', 2),
#   ('Predictions Actress', 2),
#   ('Predictions Actor', 2),
#   ('Boyhood Foxcatcher The Imitation Game Selma', 2),
#   ('SabrinaMonclair Actor In', 2),
#   ('Ballot Bold for who will win Italic who should win – Boyhood', 2),
#   ('Nudger Selma', 2),
#   ('For Ive', 2),
#   ('Collin announces the clip for The Imitation Game', 2),
#   ('Theater News Cinemark Who', 2),
#   ('Congrats AVAETC Oprah', 2),
#   ('Selma is winning Make', 2),
#   ('Elizabeth Taylor annoucing the award at the Awards', 2),
#   ('Theory Of Everything', 2),
#   ('AMY ADAMS', 2),
#   ('Congratulations Amy Adams', 2),
#   ('Comedy Patricia Arquette', 2),
#   ('Actress in a – Musical or Comedy Patricia Arquette – Boyhood', 2),
#   ('Congrats Actress in a Patricia Arquette', 2),
#   ('PATRICIA ARQUETTE', 2),
#   ('Predictions Selma Comedy Birdman', 2),
#   ('If Rosamund Pike does not win a for actress in a Im', 2),
#   ('Jack Black introduces Boyhood', 2),
#   ('MickCote Who', 2),
#   ('If Benedict Cumberbatch', 2),
#   ('Actor Michael Keaton', 2),
#   ('Actor Michael Keaton for Birdman', 2),
#   ('DirectionerYanG Nominee', 2),
#   ('WendyCasting Who', 2),
#   ('Actress Julianne Moore for Still Alice', 2),
#   ('Actress Julianne Moore STILL ALICE', 2),
#   ('Actress in a Moore for Still Alice', 2),
#   ('WINNER Julianne Moore', 2),
#   ('Actress – WINNER Julianne Moore for Still Alice', 2),
#   ('Still Alice SBSNews', 2),
#   ('Actress Julianna Moore Still Alice', 2),
#   ('The award for Actress in a goes to Julianne Moore for “Still Alice', 2),
#   ('The for Actress', 2),
#   ('The for Actress in a goes to Julianne Moore for Still Alice', 2),
#   ('NYDNEntertain The', 2),
#   ('Awww Actress Julianne Moore Still Alice', 2),
#   ('Actress goes to Julianne Moore for Still Alice', 2),
#   ('Julianne Moore in Still Alice', 2),
#   ('Actress in a Winner juliannemoore for Still Alice', 2),
#   ('Actress Julianne Moore Still Alice Was MM', 2),
#   ('Civil War', 2),
#   ('Actress Julianne Moore Still Alice Was MM talking like a Civil War', 2),
#   ('JULIANNE MOORE STILL ALICE', 2),
#   ('ACTRESS JULIANNE MOORE STILL ALICE', 2),
#   ('LIVE Its', 2),
#   ('Julliane Moore', 2),
#   ('Its our prediction Julliane Moore wins Actress', 2),
#   ('Actress in a winner is Julianne Moore for Still Alice', 2),
#   ('Julianne Moore Actress Still Alice', 2),
#   ('Congrats Julianne Moore For Actress In A Still Alice', 2),
#   ('Actress Julieanne Moore for Still Alice', 2),
#   ('KNXDavid Julianne Moore', 2),
#   ('Julianne Moore wins Actress for for Still Alice', 2),
#   ('TeamID Congrats', 2),
#   ('Julliane Moore GermanDelgado', 2),
#   ('Actress in a Julliane Moore', 2),
#   ('Actress Moore Still Alice', 2),
#   ('VibeFilm Actress', 2),
#   ('Actress in a es para Julianne Moore Still Alice', 2),
#   ('Thought Reese was gonna take it Actress', 2),
#   ('Congrats juliannemoore Actress', 2),
#   ('PHOTO Actress Julianne Moore Actress', 2),
#   ('StylistMagazine Congrats', 2),
#   ('Steve Carell Benedict Cumberbatch Jake Gyllenhaal David Oyelowo Eddie Redmayne',
#    2),
#   ('Julianne Moore wins Actress for her performance in Still Alice', 2),
#   ('Lead Actress', 2),
#   ('Julianne Moore takes home the for Actress', 2),
#   ('Actor In A Eddie Redmayne The Theory', 2),
#   ('The award for Actor in a goes to Eddie Redmayne for “The Theory of Everything',
#    2),
#   ('Actor in a – Eddie Redmayne – The Theory of Everything', 2),
#   ('MTTSFilmblog Congratulations Actress', 2),
#   ('Still A', 2),
#   ('Actor Eddie Redmayne The Theory Of Everything', 2),
#   ('Actor Eddie Redmayne THE THEORY OF EVERYTHING', 2),
#   ('Actor Winner Eddie Redmayne for The Theory of Everything', 2),
#   ('Everything SBSNews', 2),
#   ('Actor In A Eddie Redmayne The Theory Of Everything', 2),
#   ('Everything Congrats', 2),
#   ('Actor in a goes to Eddie Redmayne Yay', 2),
#   ('ACTOR EDDIE REDMAYNE THE THEORY OF EVERYTHING', 2),
#   ('Everything Eddie', 2),
#   ('Actor in a Eddie Redmanye The Theory of Everything Eddie', 2),
#   ('Actress in a goes to juliannemoore for Still Alice', 2),
#   ('Eddie Redmayne The Theory Everything', 2),
#   ('Eddie Redmayne of THE THEORY OF EVERYTHING winner Actor', 2),
#   ('Everything Great', 2),
#   ('Actor in a Eddie Redmanye The Theory of Everything Great', 2),
#   ('Eddie Redmanye The', 2),
#   ('Wow Amazing Congrats Eddie Redmayne Actor', 2),
#   ('ManProject Actor', 2),
#   ('THIS CineplexMovies Actor', 2),
#   ('Eddie Redmayne The Theory Of Everything', 2),
#   ('Wow Actor', 2),
#   ('Wow Actor in a Eddie Redmanye The Theory of Everything', 2),
#   ('KNXDavid Eddie Redmayne', 2),
#   ('VhIndia Eddie Redmayne', 2),
#   ('Eddie Redmayne wins for The Theory of Everything in the Actor category Gwyneth Paltrow',
#    2),
#   ('Eddie Raynmane', 2),
#   ('Actor In A goes to Eddie Redmayne', 2),
#   ('Lead Actor in a – goes to Eddie Redmayne – The Theory of Everything', 2),
#   ('DrunkHaymitchPN Actor', 2),
#   ('Newcomer Eddie Redmayne wins the Actor in a for his depiction of Stephen Hawking',
#    2),
#   ('Haaaay bikor HuffingtonPost Actor in a goes to Eddie Redmayne in The Theory of Everything',
#    2),
#   ('Congrats Eddie Redmanye', 2),
#   ('Eddie Redmayne wins actor in a So', 2),
#   ('VibeFilm Actor', 2),
#   ('KPRCLocal Actor', 2),
#   ('Eddie Redmanye CONGRATULATIOS', 2),
#   ('Finally Actor', 2),
#   ('Finally Actor in a Eddie Redmanye The Theory of Everything', 2),
#   ('CBSShowbiz Eddie Redmayne', 2),
#   ('Eddie Redmayne GermanDelgado', 2),
#   ('Actor Mejor Actor in a Eddie Redmayne', 2),
#   ('DailyStar Julianne Moore', 2),
#   ('Eddie Redmanye se lleva el premio en Actor in a por The Theory of Everything',
#    2),
#   ('WOOO EDDY REDMAYNE WON THE FOR ACTOR FOR A', 2),
#   ('Wellwellwell Actor', 2),
#   ('Wellwellwell Actor in a goes to Eddie Redmayne But we Brits', 2),
#   ('If Selma', 2),
#   ('ScreenSlam Actress', 2),
#   ('Who 😯EW Actor goes to Eddie Redmayne', 2),
#   ('LDNCalling Bingo Eddie Redmayne Actor', 2),
#   ('Bingo Eddie Redmayne Actor in a Break', 2),
#   ('Yessssss wins Actor', 2),
#   ('Theater News CineplexMovies Actress', 2),
#   ('Theater News CineplexMovies Actor', 2),
#   ('Culturalist Retweet to congratulate juliannemoore Actress', 2),
#   ('Congrats Actor', 2),
#   ('Everything YESSSS', 2),
#   ('Steven Hawking', 2),
#   ('Eddie Redmanye Actor in a as Steven Hawking in The Theory of Everything',
#    2),
#   ('Hawking EW Actor', 2),
#   ('Hawking EW Actor goes to Eddie Redmayne', 2),
#   ('AGarfieldblog Congrats Actor', 2),
#   ('Down to the end here What', 2),
#   ('Woooow Congrats Actor', 2),
#   ('EarthCDBD Still Alice', 2),
#   ('Eddie Redmayne wins for Actor', 2),
#   ('Okay Meryl', 2),
#   ('Congratulations to Eddie Redmayne for his for Actor', 2),
#   ('Boyhood Foxcatcher The Imitation Game Selma The Theory', 2),
#   ('Boyhood Foxcatcher The Imitation Game Selma The Theory of Everything', 2),
#   ('And the final award of the night goes to Boyhood', 2),
#   ('Called it – WINNER Boyhood', 2),
#   ('Boyhood We', 2),
#   ('Shocker Boyhood', 2),
#   ('The perfect Meryl Streep presents the award for The goes to Boyhood', 2),
#   ('Boyhood Must', 2),
#   ('Congratulations Years', 2),
#   ('Boyhood OH No', 2),
#   ('The last award of the night goes to Boyhood', 2),
#   ('Epic Boyhood BoyhoodMovie', 2),
#   ('Epic Boyhood', 2),
#   ('JUST IN', 2),
#   ('Ethan Hawke', 2),
#   ('Wow wins the for Did', 2),
#   ('ScreenGonzo Winner Boyhood', 2),
#   ('Boyhood BoyhoodMovie So', 2),
#   ('PhilippineStar The Theory', 2),
#   ('Winner in a Boyhood', 2),
#   ('BOYHOOD Nothing', 2),
#   ('The for goes to BOYHOOD Nothing', 2),
#   ('Boyhood BoyhoodMovie Movie', 2),
#   ('BoyhoodMovie The', 2),
#   ('The will be interesting Excellent', 2),
#   ('AQufat Take A', 2),
#   ('Se veia Boyhood', 2),
#   ('Boyhood’ sumcara Visitgt', 2),
#   ('PodgeTown Boyhood', 2),
#   ('Boyhood YES So', 2),
#   ('Boyhood BoyhoodMovie YESSSSSS', 2),
#   ('Boyhood Final Score', 2),
#   ('WPXI Last', 2),
#   ('OH MY GOD BOYHOOD WINS', 2),
#   ('CharterCom The', 2),
#   ('GlobalGrind Actress', 2),
#   ('YES Boyhood BoyhoodMovie', 2),
#   ('Awards Winners Boyhood', 2),
#   ('And the for goes to Boyhood', 2),
#   ('Boyhood A', 2),
#   ('Boyhood A good night for them with wins for Linklater and Arquette', 2),
#   ('TDotTV The', 2),
#   ('Congrats to Boyhood', 2),
#   ('Yes Boyhood wins the for By', 2),
#   ('Melhor filme mashable goes to ‘Boyhood', 2),
#   ('Actor Eddie Remayne TOUGH Category', 2),
#   ('Yeahhhh Boyhood', 2),
#   ('Congrats Boyhood Still', 2),
#   ('Boyhood BoyhoodMovie Se', 2),
#   ('Samurainight OF COURSE Boyhood', 2),
#   ('SBellissimo Actress Julieanne Moore Still Alice', 2),
#   ('Well deserved Boyhood', 2),
#   ('Everything VIA HuffingtonPost', 2),
#   ('For a Richard Linklater', 2),
#   ('Well deserved🙌 Actor in a Eddie Redmanye The Theory of Everything', 2),
#   ('CreativeFuture Congratulations Boyhood BoyhoodMovie', 2),
#   ('Boyhood won Linklater', 2),
#   ('Category Congrats', 2),
#   ('Boyhood BoyhoodMovie What', 2),
#   ('Jonathan Seh', 2),
#   ('Deadline ‘Boyhood’ Wins For Richard Linklater and IFC’s Jonathan Seh', 2),
#   ('KNXDavid Boyhood', 2),
#   ('Boyhood’ Wins For via Deadline', 2),
#   ('MargaretCarrero Boyhood', 2),
#   ('Well deserved What a phenomenal film voxdotcom Boyhood', 2),
#   ('StupidLearner Seegt', 2),
#   ('The nd Awards', 2),
#   ('Ayangbeb Readgt', 2),
#   ('Actor in a Eddie Redmanye The Theory of Everything”gtmerecido Es', 2),
#   ('TheWrap Boyhood Yes So', 2),
#   ('Boyhood Yes So so well deserved See', 2),
#   ('And finally the last award of the night Boyhood', 2),
#   ('Director Richard Linklaters Boyhood', 2),
#   ('Yeah BuzzFeedNews Boyhood', 2),
#   ('Buuuuuu IMDb Winner Boyhood', 2),
#   ('Yep Amazing', 2),
#   ('Currently featured in HD on my Plex cnnbrk “Boyhood', 2),
#   ('Boyhood Watch', 2),
#   ('BoyhoodMovie Award', 2),
#   ('Beverly Hills More', 2),
#   ('Boyhood won the award at Sunday’s Awards in Beverly Hills More', 2),
#   ('CosmoIndonesia And', 2),
#   ('SirCoosh JUST IN', 2),
#   ('Jonathan Sehring', 2),
#   ('Boyhood’ Wins For Richard Linklater and IFC’s Jonathan Sehring', 2),
#   ('Boyhood Cr BBCNewsEnts Yes', 2),
#   ('Boyhood is the winner of nd Award', 2),
#   ('Boyhood BoyhoodMovie Yes', 2),
#   ('Boyhood BoyhoodMovie WooHoo Go', 2),
#   ('Wins Actress', 2),
#   ('Film paling natural o Boyhood', 2),
#   ('Theater News Cinemark', 2),
#   ('Wohoo Awani Director Richard Linklaters Boyhood', 2),
#   ('News Didnt', 2),
#   ('News Fox Boyhood', 2),
#   ('BreaknNews BBCBreaking Richard Linklaters Boyhood', 2),
#   ('Hope Boyhood', 2),
#   ('Boyhood wins at the Boyhood', 2),
#   ('Award Winners DeMille Award George Clooney Boyhood Actor', 2),
#   ('McMicroDesign Boyhood Wins The', 2),
#   ('Wins Actor', 2),
#   ('Celebrilizer Boyhood Wins', 2),
#   ('Boyhood Wins At Boyhood nabbed Pict', 2),
#   ('Eddie Re', 2),
#   ('Eddie Redmayne Wins The Award For Actor In A His performance was beyond phenomenal Eddie Re',
#    2),
#   ('The For', 2),
#   ('AOL Winner', 2),
#   ('BoyhoodMovie Bravo', 2),
#   ('Boyhood Wins Read', 2),
#   ('WINNERS LIST Boyhood', 2),
#   ('BeyondTheRental Congrats', 2),
#   ('News Boyhood Wins', 2),
#   ('Proves That Unique Storytelling Can Win Big With The Award For', 2),
#   ('One of my fav movies mashable goes to ‘Boyhood', 2),
#   ('Nominees Boyhood Foxcatcher Selma The Grand Budapest', 2),
#   ('Boyhood Wins At Richard Linklater Accepts Win For Boy', 2),
#   ('Madmo Magnificentnominated', 2),
#   ('Eddie Redmayne Wins The Award For Actor In A His Kim Jung Un Is Dumb', 2),
#   ('Winner Shailene Woodley', 2),
#   ('Winner Eddie Redmayne The Theory', 2),
#   ('Actor in a Winner Eddie Redmayne The Theory of Everything', 2),
#   ('CNN Breaking News', 2),
#   ('Boyhood” takes at CNN Breaking News', 2),
#   ('Eddie Redmayne Wins Actor in a Redmayne physicist Stephen', 2),
#   ('Boyhood CONGRATS BoyhoodMovie Again', 2),
#   ('Boyhood wins for Telegraph', 2),
#   ('Boyhood named Boyhood', 2),
#   ('News Exclus Boyhood Wins', 2),
#   ('Moore Actress', 2),
#   ('EddieRedmayneP Eddie Actor', 2),
#   ('Boyhood Wins At Accepts Win', 2),
#   ('Gives A Beautiful Accept', 2),
#   ('Julianne Moore Wins The Award For Actress In A amp Gives A Beautiful Accept',
#    2),
#   ('Boyhood Congratulations Get', 2),
#   ('Yayyyyy My', 2),
#   ('WhoSay BoyhoodMovie', 2),
#   ('Zen Events Group Boyhood Wins', 2),
#   ('Everything Photo', 2),
#   ('Eddie Redmayne Actor in a The Theory of Everything Photo', 2),
#   ('Congratulations to BoyhoodMovie with for and Director', 2),
#   ('News Boyhood Wins At Richard Linklater Accepts Win For Director', 2),
#   ('Awards Boyhood', 2),
#   ('Eddie Redmayne Woke', 2),
#   ('Eddie Redmayne Woke up and learned he had won Actor award in a for Thats',
#    2),
#   ('Los Angeles Jan Boyhood', 2),
#   ('Boyhood named Los Angeles Jan Boyhood', 2),
#   ('Just woke up and saw BOYHOOD won at Perfect', 2),
#   ('SonyPIX Director Richard Linklaters', 2),
#   ('The Winners', 2),
#   ('QueenLanaShai My', 2),
#   ('Sorry Not Sorry Selma', 2),
#   ('Winners FILM Boyhood Musical', 2),
#   ('Winners FILM Boyhood Musical or Comedy', 2),
#   ('Boyhood Wins Hollywood Share With Friends Enter', 2),
#   ('Comingofage tale Boyhood', 2),
#   ('Zestaw zdjęć Benedict', 2),
#   ('Congrats to Eddie Redmanye for winning Actor', 2),
#   ('SonyPIX Eddie Redmayne', 2),
#   ('Bilderserie Benedict', 2),
#   ('Full Show Boyhood Wins', 2),
#   ('Awards Lead Actor Eddie Redmayne Lead ActressJulianne Moore DirectorRichard Linklater',
#    2),
#   ('Yes Boyhood Here Are Your Winners', 2),
#   ('Ive now see all five nominees for a for the tonight and Im', 1),
#   ('Ive now see all five nominees for for the tonight and Im', 1),
#   ('BOYHOOD PERFORMANCE BY AN ACTRESS IN A', 1),
#   ('JENNIFER ANISTON', 1),
#   ('Tweet accesshollywood For at I pick Great', 1),
#   ('Ive now see all five nominees for the tonight and Im', 1),
#   ('Tweet AccessHollywood For at I pick IntoTheWoods the Win', 1),
#   ('Cake Theory', 1),
#   ('Everything Still Alice Gone Girl', 1),
#   ('Wild GG', 1),
#   ('Cake Theory of Everything Still Alice Gone Girl amp Wild', 1),
#   ('Nominee for Performance in a Duvall', 1),
#   ('SELMA Crossing', 1),
#   ('Also excited to see DavidOyelowoo take home a for Actor in a for SELMA Crossing',
#    1),
#   ('Series are the big deal at the all excellent Not', 1),
#   ('Who will win – Noms Boyhood Foxcatcher The Imitation Game Selma The Theory of Everything',
#    1),
#   ('Kstewartfans Congratulations', 1),
#   ('Kstewartfans Congratulations to juliannemoore on her nomination for Actress',
#    1),
#   ('I Boyhood', 1),
#   ('What do you think VOTE Tweet AccessHollywood For', 1),
#   ('Retweet if you want to win the for at tonights Awards', 1),
#   ('Awards Actor', 1),
#   ('Steve Carell', 1),
#   ('Photoset moviegifsthatrock nd Awards Actor in a Steve Carell', 1),
#   ('Performance in a – Actor Eddie Redmayne – The Theory of Everything', 1),
#   ('Performance in a – Actress Julianne Moore – Still Alice', 1),
#   ('Nominated for Awards', 1),
#   ('Jake Gyllenhaal to win actor in for Nightcrawler', 1),
#   ('Actress in a is going to go to Rosamund Pike', 1),
#   ('Actor – Award', 1),
#   ('Reese Witherspoon Wild', 1),
#   ('Actress nominee Reese Witherspoon Wild', 1),
#   ('Será Variety', 1),
#   ('Rosamund Pike Gone Girl', 1),
#   ('Predictions Actress in a Rosamund Pike Gone Girl', 1),
#   ('Predictions Actor in a Eddie Redmayne Theory of Everything', 1),
#   ('Eddie Redmayne Steve Carell Benedict Cumberbatch David Oyelowo Jake Gyllenhaal',
#    1),
#   ('Actor in a Eddie Redmayne Steve Carell Benedict Cumberbatch David Oyelowo Jake Gyllenhaal',
#    1),
#   ('IN MINUTES Pegging', 1),
#   ('Patricia Arquette Boyhood', 1),
#   ('Predictions Actress in a Patricia Arquette Boyhood', 1),
#   ('JK Simmons Whiplash', 1),
#   ('Predictions Actor in a JK Simmons Whiplash', 1),
#   ('Ballot Bold', 1),
#   ('HE MUST WIN ACTOR IN A', 1),
#   ('NotMattParent Ballot Bold', 1),
#   ('If David Oyelowo', 1),
#   ('If David Oyelowo wins tonight hell be the th black actor in history to win the Actor',
#    1),
#   ('Boyhood Foxcatcher The', 1),
#   ('The nominations for the nd Awards are Boyhood Foxcatcher The', 1),
#   ('Boyhood Foxcatcher', 1),
#   ('The are underway which gets YOUR vote for – Boyhood Foxcatcher', 1),
#   ('The Winners As They Come In The', 1),
#   ('The Winners As They Come In The winners are bolded below Boyh', 1),
#   ('Big predictions for tonight for Actor', 1),
#   ('Big Predictions', 1),
#   ('Big Predictions for tonight in GoneGirlMovie for Actress', 1),
#   ('Julianne Moore Rosamund Pike Reese Witherspoon Felicity Jones Jennifer Aniston',
#    1),
#   ('Actress in a Julianne Moore Rosamund Pike Reese Witherspoon Felicity Jones Jennifer Aniston',
#    1),
#   ('Wants Actress', 1),
#   ('Pike Musical', 1),
#   ('ComedyThe Grand Budapest Hotel', 1),
#   ('Wants Actress in a Pike Musical or ComedyThe Grand Budapest Hotel', 1),
#   ('Actor goes to JK Simmons', 1),
#   ('The award for Actor in a goes to JK Simmons for his role in Whiplash', 1),
#   ('J K Simmons', 1),
#   ('Actor in a JK Simmons', 1),
#   ('ACTOR IN A FOR JK SIMMONS For Ive', 1),
#   ('Really hope Rosamund Pike wins the Actress in a tonight her performance in Gone Girl',
#    1),
#   ('VibeFilm ACTOR IN A FOR JK SIMMONS For Ive', 1),
#   ('Who would you like to see win the award for Actor', 1),
#   ('Boyhood Actress', 1),
#   ('Boyhood Actress in a Jennifer Aniston', 1),
#   ('If Eddie Redmayne', 1),
#   ('If Eddie Redmayne doesnt win actor in a for The Theory of Everything then Ill',
#    1),
#   ('Our Predictions', 1),
#   ('Rosamund Pike Steve Carell', 1),
#   ('Our Predictions goes to amp Rosamund Pike Steve Carell', 1),
#   ('Colin introduces one of the nominees for The Imitation Game', 1),
#   ('Selma Director AVAETC', 1),
#   ('Im only watching the on twitter My predictions Selma Director', 1),
#   ('They just presented the nominees for the Any', 1),
#   ('There are some incredible films nominated tonight for Who', 1),
#   ('KillGameMovie Help', 1),
#   ('KillGameMovie Twitter', 1),
#   ('Help us tonight during the KillGameMovie Twitter', 1),
#   ('Original Song', 1),
#   ('Original Song goes to Glory', 1),
#   ('AshleyReynolds I', 1),
#   ('Elizabeth Taylor', 1),
#   ('Theory Of Everything has a legit chance at winning butI give that edge to Boyhood',
#    1),
#   ('Clive Owen announces the clip for The Theory of Everything', 1),
#   ('Clive Owen presents in a nominee The Theory of Everything', 1),
#   ('Clive Owen introduces one of the nominees for The Theory Of Everything',
#    1),
#   ('Actress In A Movie', 1),
#   ('Actress In A Movie goes to Amy Adams', 1),
#   ('And its Amy Adams for Actress', 1),
#   ('Eish the performance by an actor in a category is tight They', 1),
#   ('BuzzFeedRewind Elizabeth Taylor', 1),
#   ('Big Eyes', 1),
#   ('Actress in a Musical or Comedy goes to Amy Adams for ‘Big Eyes’ Thought',
#    1),
#   ('Actress in a – Musical or Comedy goes to Patricia Arquette', 1),
#   ('Actress in a Patricia Arquette for Boyhood', 1),
#   ('Next year Ill', 1),
#   ('If Rosamund Pike', 1),
#   ('Betting on Boyhood', 1),
#   ('Jack Black announces the clip for Boyhood', 1),
#   ('Jack Black introduces one of the nominees for Boyhood', 1),
#   ('Comedy Musical', 1),
#   ('Who do you have as your picks for Both and Comedy Musical', 1),
#   ('Is A Most Violent Year', 1),
#   ('Is A Most Violent Year nominated for Or', 1),
#   ('Steve Carrell', 1),
#   ('If either Steve Carrell or Jake Gyllenhaal dont win the for Actor in a Im',
#    1),
#   ('Literally waiting for the moment for Actor', 1),
#   ('All I', 1),
#   ('All I really want to know is who won Actor in whatever the title is the one Benedict amp Eddie',
#    1),
#   ('JAKE GYLLENHAAL PERFORMANCE BY AN ACTOR IN A', 1),
#   ('Boyhood Is', 1),
#   ('Vote now for which film you think will take billbrownstein says Boyhood Is',
#    1),
#   ('Awards Boyhood Foxcatcher', 1),
#   ('Set de fotos moviegifsthatrock nd Awards Boyhood Foxcatcher', 1),
#   ('Vote now for which film you think will take billbrownstein says Boyhood',
#    1),
#   ('CONGRATS Nbc', 1),
#   ('Actress TV', 1),
#   ('WTF Shoulda', 1),
#   ('Ava Viola', 1),
#   ('The amp Actress TV winners simply do not make sense WTF Shoulda been Ava Viola',
#    1),
#   ('THE AFFAIR', 1),
#   ('The award winners have been all over the place tonight Heres to Benedict Cumberbatch for Actor',
#    1),
#   ('LauraCumbow If Rosamund Pike', 1),
#   ('Oprah Winfrey introduces nominee for Selma', 1),
#   ('Felicity Jones', 1),
#   ('Rosemund Pike', 1),
#   ('For the actress in a I am on between Felicity Jones and Rosemund Pike', 1),
#   ('Winfrey announces the clip for Selma', 1),
#   ('Oprah take the stage to introduce nominee for Selma', 1),
#   ('Just give to Foxcatcher or Boyhood', 1),
#   ('The Foxcatcher', 1),
#   ('Channing Tatum announces the clip for The Foxcatcher', 1),
#   ('Wait what are the noms for in or Horror', 1),
#   ('The Grand Budapest Hotel in wuuuuuu cc Eather', 1),
#   ('Jennifer Aniston Rosamund Pike Felicity Jones Julianne Moore Reese Witherspoon',
#    1),
#   ('Actress – Jennifer Aniston Rosamund Pike Felicity Jones Julianne Moore Reese Witherspoon',
#    1),
#   ('Reminder Actress', 1),
#   ('Rosamund Pike RWitherspoon Felicity Jones Jen Aniston', 1),
#   ('Reminder Actress in a nominees are juliannemoore Rosamund Pike RWitherspoon Felicity Jones Jen Aniston',
#    1),
#   ('STILL ALICEs Julianne Moore Actress', 1),
#   ('To nobodys surprise but well deserved STILL ALICEs Julianne Moore Actress',
#    1),
#   ('Actress is Julianne Moore', 1),
#   ('Winner of for Actress In A Julianne Moore Still Alice', 1),
#   ('Congratulations Julianne Moore', 1),
#   ('Actress in a goes to Julianne Moore – Still Alice', 1),
#   ('Julianne Moree', 1),
#   ('The for the Actress in a goes to Julianne Moree for Still Alice', 1),
#   ('Yay Actress', 1),
#   ('Yay Actress in a Julianne Moore juliannemoore Still Alice', 1),
#   ('ACTRESS Goes To Julianne Moore', 1),
#   ('Actress in a goes to Julianna Moore for Still Alice', 1),
#   ('Congrats to Julianne Moore for her Actress', 1),
#   ('Actress in goes to Julianne Moore for ‘Still Alice', 1),
#   ('ACTRESS IN A Julianne Moore Still Alice', 1),
#   ('Winner Actress in a Julianne Moore Still Alice', 1),
#   ('Julianne Moore wins Actress for Still Alice', 1),
#   ('Actress Award', 1),
#   ('Actress Award goes to For', 1),
#   ('Still Alice This', 1),
#   ('Actress in a goes to Julianne Moore for Still Alice This', 1),
#   ('Actress in a Julianne Moore – Still Alice', 1),
#   ('The winner of Actress in a goes to Julianne Moore Still Alice', 1),
#   ('And the Actress in a isJulianne Moore', 1),
#   ('Actress In a goes to Julianne Moore for Still Alice', 1),
#   ('Still Alice Love', 1),
#   ('Julianne Moore wins for Actress for Still Alice Love', 1),
#   ('Winner for Actress in a is Julianne Moore', 1),
#   ('Actress award winner Julianne Moore from Still Alice', 1),
#   ('Congratulations to juliannemoore Winner for Actress', 1),
#   ...],
#  'best motion picture - comedy or musical': [('The Grand Budapest Hotel',
#    8119),
#   ('Amy Adams Big Eyes', 2044),
#   ('Actress in a or Amy Adams Big Eyes', 1693),
#   ('Michael Keaton MichaelKeaton Birdman', 1347),
#   ('Actor in a or Michael Keaton MichaelKeaton Birdman', 1335),
#   ('BBCBreaking The Grand Budapest Hotel', 694),
#   ('Culturalist Retweet', 682),
#   ('Amy Adams', 657),
#   ('Michael Keaton', 580),
#   ('Big Eyes', 451),
#   ('Winner or The Grand Budapest Hotel', 290),
#   ('IMDb Winner', 289),
#   ('Actress in a or goes to Amy Adams Big Eyes', 255),
#   ('VanityFair The Grand Budapest Hotel', 245),
#   ('Congrats Michael Keaton', 219),
#   ('Congrats Michael Keaton wins Actor', 218),
#   ('THE GRAND BUDAPEST HOTEL', 216),
#   ('Winner Actor in a or Michael Keaton for ‘Birdman', 215),
#   ('IMDb Winner Actor', 214),
#   ('The Grand Budapest Hotel’ Wins', 164),
#   ('Amy Adams Takes Home The For Actress', 162),
#   ('For Actor', 144),
#   ('THR MichaelKeaton', 140),
#   ('AARP For Actor', 140),
#   ('Actress in a or goes to Amy Adams for ‘Big Eyes', 137),
#   ('The Grand Budapest Hotel Wins', 120),
#   ('Amy Adams Takes Home The For Actress — Or', 115),
#   ('Wes Andersons The Grand Budapest Hotel', 115),
#   ('Grand Budapest Hotel', 113),
#   ('Michael Keaton Birdman', 113),
#   ('Michael Keaton Wins The Award For Actor In A Or', 111),
#   ('THR The Grand Budapest Hotel', 94),
#   ('Amy Adams wins the Actress in a or for the film Congrats', 90),
#   ('The Grand Budapest Hotel wins or Congrats', 89),
#   ('Michael Keaton Wins The Award For Actor In A Or What', 77),
#   ('Actor in a or goes to Michael Keaton in Birdman', 75),
#   ('HuffingtonPost Actor', 75),
#   ('Actress in a or goes to Amy Adams for Big Eyes', 74),
#   ('Amy Adams wins Actress', 71),
#   ('Big Eyes GMA', 71),
#   ('Congratulations Amy Adams for winning Actress in a or for Big Eyes', 70),
#   ('ABC Actress', 69),
#   ('Actor In A Or', 68),
#   ('Actor in a or goes to Michael Keaton for Birdman', 67),
#   ('ForbesLife Congratulations Amy Adams', 66),
#   ('Actress In A or goes to Amy Adams in Big Eyes', 65),
#   ('Birdman GMA', 64),
#   ('ABC Actor', 61),
#   ('The Grand Budapest Hotel GMA', 61),
#   ('HuffingtonPost Actress In A', 60),
#   ('Actress In A', 56),
#   ('Fandango Congrats', 56),
#   ('Actor in a or Michael Keaton Birdman', 52),
#   ('THR Amy Adams', 50),
#   ('The winner of or is Wes Andersons The Grand Budapest Hotel', 50),
#   ('ForbesLife The', 49),
#   ('And MichaelKeaton', 46),
#   ('And MichaelKeaton wins the for Actor', 46),
#   ('Wes Anderson fans rejoice The Grand Budapest Hotel', 46),
#   ('GMA Wes Anderson', 45),
#   ('USATODAY The Grand Budapest Hotel', 42),
#   ('Wins Or', 40),
#   ('Amy Adams Actress In A', 38),
#   ('Actor in a or goes to Michael Keaton', 37),
#   ('The for or goes to The Grand Budapest Hotel', 37),
#   ('Congratulations to Amy Adams Actress In', 36),
#   ('Or Amy Adams', 36),
#   ('Amy Adams Takes Home The For Actress — Or Amy Adams', 35),
#   ('WhoWhatWear Congratulations', 34),
#   ('Michael Keaton aka Batman wins Actor', 34),
#   ('Amy Adams Wins', 33),
#   ('NerdistDotCom Michael Keaton', 33),
#   ('Amy Adams Wins Actress', 32),
#   ('THR Amy Adams Wins Actress', 30),
#   ('Congrats to The Grand Budapest Hotel', 30),
#   ('Michael Keaton Wins', 30),
#   ('Amy Adams wins Actress in a or for Big Eyes', 29),
#   ('Actress in a or Amy Adams', 28),
#   ('Actress ina a Or', 28),
#   ('Grand Budapest Hotel’ Wins Or', 25),
#   ('WhoWhatWear The Grand Budapest Hotel', 24),
#   ('Pemenang or The Grand Budapest Hotel', 24),
#   ('Marilyn Monroe GG Actress', 23),
#   ('Some Like It Hot', 23),
#   ('Marilyn Monroe GG Actress in a or for Some Like It Hot', 23),
# ...
#   ('Remember I told you guys it was really GOOD 😉 The Affair', 1),
#   ('Well deserved Actor Kevin Spacey', 1),
#   ('Yeahhhhh Actor Kevin Spacey KevinSpacey HouseofCards', 1),
#   ('Yeahhhhh Actor Kevin Spacey', 1),
#   ('Winner for The Affair', 1),
#   ('NewsHunt This', 1),
#   ('This is just the beginning of my revenge Actor', 1),
#   ('FinallyCongratulations Actor Kevin Spacey KevinSpacey HouseofCards', 1),
#   ('JennyMcShane Finally', 1),
#   ('Mannnderzz Actor Kevin Spacey KevinSpacey HouseofCards', 1),
#   ('Mannnderzz Actor Kevin Spacey', 1),
#   ('Claire Danes Viola Davis Julianna Margulies Ruth Wilson Robin Wright', 1),
#   ('Actress – Claire Danes Viola Davis Julianna Margulies Ruth Wilson Robin Wright',
#    1),
#   ('Er The Affair SHOTheAffair', 1),
#   ('Er The Affair', 1),
#   ('Oh well Actress in a Ruth Wilson The Affair', 1),
#   ('WINNER Actress', 1),
#   ('SIIIII Actress', 1),
#   ('FSulgani Actress', 1),
#   ('Actress in a goes to Ruth Wilson The Affair', 1),
#   ('Nooooooi What Actress', 1),
#   ('Nooooooi What Actress in a Ruth Wilson The Affair', 1),
#   ('PERFORMANCE BY AN ACTRESS IN A', 1),
#   ('Ruth Wilson – “The Affair', 1),
#   ('Weekly Episodic', 1),
#   ('So which show won Weekly Episodic', 1),
#   ('RUTH WILSON THE AFFAIR PERFORMANCE BY AN ACTRESS IN A', 1),
#   ('MariaVictoriaBG Actress', 1),
#   ('Actress in a Ruth Wilson The Affair SHOTheAffair ancora The Affair', 1),
#   ('Ruth Wilson SHOTheAffair NBC', 1),
#   ('Woo Well', 1),
#   ('Woo Well done Ruth Wilson', 1),
#   ('CSTsizzle Actress', 1),
#   ('I Actor Kevin Spacey KevinSpacey HouseofCards', 1),
#   ('The Actress', 1),
#   ('Nomination List', 1),
#   ('My romantic orientation The Actress in a Nomination List', 1),
#   ('Ruth Wilson takes home the for Actress in a for her role on SHOTheAffair” Grosa',
#    1),
#   ('Insomma pare sia show da recuperare The Affair', 1),
#   ('Showtime Actress', 1),
#   ('Bien x ella y Showtime Actress in a Ruth Wilson The Affair', 1),
#   ('Ruth Wilson The Affair SHOTheAffair NOOOO FCK', 1),
#   ('Hot Actress', 1),
#   ('Hot Actress in a Ruth Wilson The Affair', 1),
#   ('Yay Actress', 1),
#   ('Yay Actress in a Ruth Wilson The Affair', 1),
#   ('Ruth Wilson The Affaif', 1),
#   ('Actress in a Ruth Wilson The Affaif', 1),
#   ('SamJones And', 1),
#   ('Oh GlobalGrind Actress', 1),
#   ('Oh GlobalGrind Actress in a Ruth Wilson for The Affair', 1),
#   ('IT IS THE BreakingNews The Affair', 1),
#   ('WPXI Actress', 1),
#   ('Ruth Wilson The Affair SHOTheAffair Umm', 1),
#   ('Actress in a Ruth Wilson The Affair SHOTheAffair Umm', 1),
#   ('Amen to the sex scenes GlobalGrind Actress in a Ruth Wilson for The Affair',
#    1),
#   ('KarenProfilio IMDb Winner Performance', 1),
#   ('And the goes to The Affair', 1),
#   ('Ruth Wilson The Affair SHOTheAffair YAY Im', 1),
#   ('Actress in a Ruth Wilson The Affair SHOTheAffair YAY Im', 1),
#   ('Ruth Wilson The Affair SHOT', 1),
#   ('Luise Performance', 1),
#   ('Luise Performance by an Actor in a Kevin Spacey for “House of Cards', 1),
#   ('KPRCLocal Actor Kevin Spacey KevinSpacey HouseofCards', 1),
#   ('Congrats Actor Kevin Spacey KevinSpacey HouseofCards', 1),
#   ('Congrats Actor Kevin Spacey', 1),
#   ('Ruth Wilson The Affair SHOTheAffair YASSSSSSS', 1),
#   ('SM Actor Kevin Spacey KevinSpacey HouseofCards', 1),
#   ('ThitiaOfficial Actor Kevin Spacey KevinSpacey HouseofCards', 1),
#   ('MaxClyde GameOfThrones', 1),
#   ('Ruth Wilson The Affair SHOTheAffair Great', 1),
#   ('Actress in a Ruth Wilson The Affair SHOTheAffair Great', 1),
#   ('AWARDS TV AND TV MOVIE WINNERS', 1),
#   ('BREAKFAST NEWS THE ND List', 1),
#   ('List of winners The', 1),
#   ('MokinoID Actor', 1),
#   ('Yes Actor Kevin Spacey KevinSpacey HouseofCards', 1),
#   ('Yes Actor Kevin Spacey', 1),
#   ('Well deserved ❤️❤️❤️ Actor Kevin Spacey', 1),
#   ('Game of Thrones', 1),
#   ('Bed LanaParrilla', 1),
#   ('QueenLanaShai Bed LanaParrilla', 1),
#   ('Actor Kevin Spacey KevinSpacey HouseofCards AsimYasin AleeKhayam', 1),
#   ('Claire Danes Reacts', 1),
#   ('Claire Danes Reacts to Losing for Actress', 1),
#   ('ManuVFM Actress', 1),
#   ('ManuVFM Actor Kevin Spacey KevinSpacey HouseofCards', 1),
#   ('ManuVFM The Affair SHOTheAffair', 1),
#   ('YAYY Actress', 1),
#   ('Wohooo Frank Underwood Actor Kevin Spacey KevinSpacey HouseofCards', 1),
#   ('Wohooo Frank Underwood Actor Kevin Spacey', 1)],
#  'best television series - comedy or musical': [('Jeffrey Tambor', 702),
#   ('Actor in a or Jeffrey Tambor jeffreytambor Transparent', 669),
#   ('HereisGina Rodriguez', 86),
#   ('Congrats to HereisGina Rodriguez on her Actress', 85),
#   ('Winner or Transparent', 68),
#   ('IMDb Winner', 67),
#   ('Transparenttv Congrats', 40),
#   ('Actor in a or for his role on Transparenttv Congrats', 39),
#   ('Jeffrey Tambor Transparent', 21),
#   ('Actor in a or Jeffrey Tambor Transparent', 13),
#   ('Actor in a or Jeffrey Tambor', 9),
#   ('Jeffrey Tambor TRANSPARENT', 9),
#   ('Actor in a or is Jeffrey Tambor', 9),
#   ('Pemenang or Transparent', 7),
#   ('Congrats HereisGina Rodriguez Actress', 6),
#   ('Or WINNER Transparent', 6),
#   ('Transparent Amazon', 6),
#   ('NewsBreaker WINNER Actor', 6),
#   ('Actor in a or Jeffrey Tambor jeffreytambor Transpar', 6),
#   ('Actor in a or goes to Jeffrey Tambor in Transparent', 6),
#   ('Pemenang Actor', 6),
#   ('Pemenang Actor in a or Jeffrey Tambor Transparent', 6),
#   ('Gina Rodriguez', 5),
#   ('CreativeFuture Congrats HereisGina Rodriguez Actress', 4),
#   ('Winning Transparent', 4),
#   ('Or WINNER Gina Rodriguez', 3),
#   ('Actress – Or WINNER Gina Rodriguez', 3),
#   ('NewsBreaker WINNER', 3),
#   ('Or WINNER Jeffrey Tambor WOW Congrats', 3),
#   ('Actor – Or WINNER Jeffrey Tambor WOW Congrats', 3),
#   ('Actor in a or jeffreytambor Transparent', 3),
#   ('Congrats to jeffreytambor Actor', 3),
#   ('Actor in a or goes to Jeffrey Tambor', 3),
#   ('WPXI Actor', 3),
#   ('Actor in a Jeffrey Tambor', 3),
#   ('Performance by an Actress in a or Gina Rodriguez for Jane the Virgin', 2),
#   ('Actress in a – or Gina Rodriguez – Jane the Virgin', 2),
#   ('Congrats to HereisGina on her Actress', 2),
#   ('Or Girls Jane The Virgin Orange Is The New Black Silicon Valley Transparent',
#    2),
#   ('Congrats or Transparent', 2),
#   ('Preview Red Carpet Photos', 2),
#   ('Transparent wins or Preview Red Carpet Photos', 2),
#   ('Neeee The', 2),
#   ('Congratulations jillsoloway via or Transparent', 2),
#   ('Or Louis CK Don Cheadle Ricky Gervais William H Macy Jeffrey Tambor', 2),
#   ('Actor – Or Louis CK Don Cheadle Ricky Gervais William H Macy Jeffrey Tambor',
#    2),
#   ('Actor in a or “Louie', 2),
#   ('Performance by an Actor in a or Jeffrey Tambor for Transparent', 2),
#   ('Actor in a – or Jeffrey Tambor – Transparent', 2),
#   ('And Jeffrey Tambor', 2),
#   ('Actor in or Jeffrey Tambor Transparent', 2),
#   ('CreativeFuture Congrats', 2),
#   ('PERFORMANCE BY AN ACTRESS IN A', 1),
#   ('OR Gina Rodriguez', 1),
#   ('Gina Rodriguez – “Jane the Virgin', 1),
#   ('Gina Rodriguez Jane', 1),
#   ('Gina Rodriguez Jane the Virgin', 1),
#   ('GINA RODRIGUEZ JANE THE VIRGIN PERFORMANCE BY AN ACTRESS IN A OR', 1),
#   ('MariaVictoriaBG Actress', 1),
#   ('HereIsGina NBC', 1),
#   ('Rodriguez on her Actress', 1),
#   ('Transparent” Amazon', 1),
#   ('GINA RODRIGUEZ', 1),
#   ('Performance by an Actress', 1),
#   ('Transparent transparenttv Great', 1),
#   ('Transparent transparenttv brilliant So', 1),
#   ('Smh or Transparent', 1),
#   ('TransparentTV NBC', 1),
#   ('Transparent transparenttv Whoa go Amazon', 1),
#   ('Great show Congratulations or Transparent', 1),
#   ('Transparent wins TV in Incredible', 1),
#   ('Scan Red Carpet Photos', 1),
#   ('Transparent transparenttv wins or Scan Red Carpet Photos', 1),
#   ('More proof that the Internet', 1),
#   ('Amazon Video MT', 1),
#   ('Finally found something to watch on Amazon Video', 1),
#   ('THIS IS A FUCKING JOKE', 1),
#   ('Buen speech or Transparent', 1),
#   ('ORANGE IS THE NEW BLACK', 1),
#   ('Transparent Show', 1),
#   ('Transparent Show creator Soloway', 1),
#   ('KHOU Transparent', 1),
#   ('Transparent wins the award for or Congratulations', 1),
#   ('Micah Fitzerman Blue', 1),
#   ('Congrats to Micah Fitzerman Blue for Transparent', 1),
#   ('In a fair world Archer', 1),
#   ('Yeayy I', 1),
#   ('Yeayy I am more than happy or Transparent', 1),
#   ('Appropriate timing tooIMDb Winner or Transparent', 1),
#   ('Amazon Studios', 1),
#   ('Wow or is Transparent transparenttv from Amazon Studios', 1),
#   ('PipEntFocus YAY TRANSPARENT', 1),
#   ('Yeah You', 1),
#   ('Yeah You go girls or Transparent', 1),
#   ('ShowTimeLegends Amazons', 1),
#   ('Yay Amazon', 1),
#   ('Yay Amazon “IMDb Winner or Transparent', 1),
#   ('IHeardThatMovie Winner', 1),
#   ('So glad Transparent won or at it truly is a stunning available soon on Stan',
#    1),
#   ('TelegraphTV Congratulations', 1),
#   ('PERFORMANCE BY AN ACTOR IN A', 1),
#   ('OR Jeffrey Tambor', 1),
#   ('Jeffrey Tambor – “Transparent', 1),
#   ('Performance in a – or of an Actor goes to Jeffrey Tambor for Transparent',
#    1),
#   ('WINNER Actor', 1),
#   ('The for Actor', 1),
#   ('JEFFREY TAMBOR TRANSPARENT PERFORMANCE BY AN ACTOR IN A', 1),
#   ('Wow Actor', 1),
#   ('Wow Actor in a or jeffreytambor Transparent', 1),
#   ('Yea“nbcJeffreyTambor wins Actor in a or for his role on Transparenttv Congrats',
#    1),
#   ('CSTsizzle Actor', 1),
#   ('JeffreyTambor NBC TransparentTV', 1),
#   ('Yeayy Actor', 1),
#   ('Yeayy Actor in a or Jeffrey Tambor jeffreytambor Transparent', 1),
#   ('IndoEnts Actor', 1),
#   ('Jeffrey Tambom Transparent', 1),
#   ('Actor in a or goes to Jeffrey Tambom Transparent', 1),
#   ('MariaVictoriaBG Actor', 1),
#   ('Emotional speech from jeffreytambor Actor in a or for Transparent', 1),
#   ('Congrats AmazonStudios', 1),
#   ('ShowTimeLegends Actor', 1),
#   ('Impt win or Transparent', 1),
#   ('Awards Winners', 1),
#   ('OR Transparent', 1),
#   ('Awards Winners for – OR Transparent', 1),
#   ('FANdemoniumNet Congrats', 1),
#   ('Hot Actor', 1),
#   ('Hot Actor in a or jeffreytambor Transparent', 1),
#   ('Transparent YES YES YES', 1),
#   ('AWDDirectors Congratulations', 1),
#   ('Beautiful or Transparent', 1),
#   ('Actor in a or jeffreytambor in transparenttv Great', 1),
#   ('MokinoID Actor', 1),
#   ('Gina Rodriguez won Actress', 1)],
#  'best mini-series or motion picture made for television': [('Made for Fargo',
#    1044),
#   ('Fargo FargoFX', 1043),
#   ('The Winners or a Made', 45),
#   ('The Winners', 44),
#   ('FargoFX Congrats', 41),
#   ('The for or Made for goes to FargoFX Congrats', 40),
#   ('And Billy Bob Thornton', 32),
#   ('And Billy Bob Thornton wins Actor in a or Made', 32),
#   ('Made for goes to Fargo', 27),
#   ('Fargo GMA', 26),
#   ('MATT BOMER FOR THE NORMAL HE', 25),
#   ('Actor in or Made', 25),
#   ('Billy Bob Thornton', 16),
#   ('Billy Bob Thornton wins Actor in a or Made', 10),
#   ('GuardianUS Billy Bob Thornton', 9),
#   ('TVLine FARGO', 7),
#   ('Congratulations to FargoFX team JoeyKingActress for your win of or Made',
#    7),
#   ('Fargo FX', 6),
#   ('ArenasEnt Congratulations', 6),
#   ('Billy Bob Thornton wins Actor', 5),
#   ('Or Made For WINNER Fargo', 4),
#   ('Made For', 4),
#   ('Fargo wins or Made', 4),
#   ('Joanne Froggatt Downton Abbe', 3),
#   ('Jeremy Renner', 3),
#   ('FXs Fargo', 3),
#   ('Fargo takes the award for or Made', 3),
#   ('GuardianUS Fargo', 3),
#   ('Billy Bob Thornton Fargo', 3),
#   ('NewsBreaker WINNER', 3),
#   ('Matt Bomer The Normal', 3),
#   ('Maggie Gyllenhaal wins Actress in a or Made', 3),
#   ('KcEazyworld ACTRESS IN A OR MADE FOR Joanne Froggatt Downton Abbe', 2),
#   ('Or Made For Fargo The Missing The Normal Olive Kitteridge True Detective',
#    2),
#   ('Jennifer Lopez', 2),
#   ('Congrats to Fargo for winning or Made', 2),
#   ('OR MADE FOR', 2),
#   ('StarNews And', 2),
#   ('True Detective', 2),
#   ('Was hoping for True Detective or Made for Fargo', 2),
#   ('Yeess or Made for Fargo', 2),
#   ('Its a win for Fargo or Made', 2),
#   ('The for Actor in a or made for goes toBilly Bob Thornton for Fargo', 2),
#   ('PERFORMANCE BY AN ACTOR IN A OR MADE FOR Billy Bob Thornton', 2),
#   ('Billy Bob Thornton – “Fargo', 2),
#   ('Billy Bob Thornton FargoFX', 2),
#   ('Actor or Made for goes to Billy Bob Thornton', 2),
#   ('Performance by an Actor in a or a Made for Billy Bob Thornton for Fargo',
#    2),
#   ('Congratulations to FargoFX or Made', 2),
#   ('Actor in a or Made for Billy Bob Thornton for Fargo', 2),
#   ('Fargo gana or Made', 2),
#   ('Fargo has won the for or made for The', 2),
#   ('The winner for Actor', 2),
#   ('Winner or Made for Fargo', 2),
#   ('KcEazyworld ACTOR IN A OR MADE FOR Matt Bomer The Normal', 2),
#   ('Maggie Gyllenhaal An Honorable Woman', 2),
#   ('GuardianUS Maggie Gyllenhaal', 2),
#   ('Awards Winners', 2),
#   ('ACTRESS IN A OR MADE FOR Joanne Froggatt Downton Abbe', 1),
#   ('Actress in a or Made for Froggatt', 1),
#   ('Jennifer Lopez and Jeremy Renner', 1),
#   ('Barack Obama', 1),
#   ('Jeremy Renner doing his Barack Obama impression The', 1),
#   ('Or Made For', 1),
#   ('Or Made For goes to Fargo', 1),
#   ('FARGO OR MADE FOR', 1),
#   ('Deserved or Made for Fargo', 1),
#   ('Woooo or Made for Fargo', 1),
#   ('Congratulations or Made for Fargo', 1),
#   ('Well deserved Congrats or Made for Fargo', 1),
#   ('Fuck yeah Fargo “nbc The for or Made for goes to FargoFX Congrats', 1),
#   ('Made for Fago', 1),
#   ('Fargo FargoFX FargoFX', 1),
#   ('Didnt see that or Made for Fargo', 1),
#   ('Jennifer Lopez and Jeremy Renner present the award for or Made For', 1),
#   ('Fargo FargoFX All', 1),
#   ('Made for Fargo FargoFX All', 1),
#   ('Fargo wins for or Made', 1),
#   ('Made for goes to FXs Fargo', 1),
#   ('Terechte winnaar or Made for Fargo', 1),
#   ('Made for goes to Fargo GMA woo It', 1),
#   ('Congrats or Made for Fargo', 1),
#   ('Bob Thornton', 1),
#   ('Actor in a or Made for Bob Thornton for Fargo', 1),
#   ('Fargo You', 1),
#   ('Actor in a or Made for Why its Billy Bob Thornton for Fargo You go Fargo',
#    1),
#   ('JohnBhtx Was', 1),
#   ('TelegraphTV Its', 1),
#   ('Fargo FargoFX Yeeeeaha', 1),
#   ('Made for Fargo FargoFX Yeeeeaha', 1),
#   ('Performance By', 1),
#   ('Billy Bob Thornton Fargo wins Performance By an Actor in a or Made', 1),
#   ('Actor In A Made For', 1),
#   ('Actor In A Made For goes to Billy Bob Thornton', 1),
#   ('BILLY BOB THORNTON FARGO PERFORMANCE BY AN ACTOR IN A OR MADE FOR', 1),
#   ('Congrats Billy Bob Thornton', 1),
#   ('Congrats Billy Bob Thornton for winning Performance by an Actor in a or Made',
#    1),
#   ('Billy Bob Thornton wins Actor in a or a Made', 1),
#   ('Fargo YES My', 1),
#   ('Made for Fargo YES My', 1),
#   ('FargoFX Congrats Wheres AHSFX', 1),
#   ('The for or Made for goes to FargoFX Congrats Wheres', 1),
#   ('LOL ABC', 1),
#   ('Billy Bob Thornton FargoFX NBC', 1),
#   ('Actor in a or Made for Billy Bob Thornton', 1),
#   ('Billy Bob', 1),
#   ('Actor in A or Made For to Billy Bob', 1),
#   ('StarNews The', 1),
#   ('FXs FARGO', 1),
#   ('Yesir or Made for Fargo', 1),
#   ('Yahoo gt or Made for Fargo', 1),
#   ('CreativeFuture Congratulations', 1),
#   ('The Real Winner', 1),
#   ('The Real Winner or Made for Fargo', 1),
#   ('WhoSay Actor', 1),
#   ('FargoFX NBC', 1),
#   ('Thought True Detective', 1),
#   ('Made for Fargo wins Thought True Detective', 1),
#   ('Made for Actor to the great Billy Bob Thornton', 1),
#   ('The FX', 1),
#   ('Made for Fargo FargoFX”such a great show Brilliant', 1),
#   ('Agreed or Made for Fargo', 1),
#   ('The for or Made for goes to Fargo', 1),
#   ('Joanne Froggatt Downton Abbey', 1),
#   ('Actress in a or Made for Joanne Froggatt Downton Abbey', 1),
#   ('Im going to watch this or Made for Fargo', 1),
#   ('The Winners or a Made for Mi', 1),
#   ('KisiFmBogor The Winners', 1),
#   ('ShowTimeLegends FXs Fargo', 1),
#   ('ACTOR IN A OR MADE FOR Matt Bomer The Normal', 1),
#   ('Matt Bomer', 1),
#   ('Performance by an Actor in a Role in a or Made for Matt Bomer', 1),
#   ('Performance by an Actor in a Role in a or Made for Matt', 1),
#   ('IHeardThatMovie Winner', 1),
#   ('LazerFeedNews The Winners', 1),
#   ('OMG SO HAPPY', 1),
#   ('Congratulations to Fargo for winning or Made', 1),
#   ('Maggie Gyllenhaal', 1),
#   ('Fargo FargoFX YAAAAAAAAAAS', 1),
#   ('Yay or Made for Fargo', 1),
#   ('Fargo FargoFX Shouldve', 1),
#   ('Made for Fargo FargoFX Shouldve', 1),
#   ('Bob Fargo Hes', 1),
#   ('Actor in a or a Made for Bob Fargo Hes', 1),
#   ('Thats my Jam or Made for Fargo', 1),
#   ('MortonIchabod Yeess', 1)]}

# %%
def getPeopleWinners(nominees):
    final_winners = {}
    
    for award in nominees:
        winner = ' '.join(nominees[award][0][0])
        final_winners[award] = winner
        
    return final_winners

# %%
people_winners_dict = getPeopleWinners(nominees)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-170-481660e952d8> in <module>
# ----> 1 people_winners_dict = getPeopleWinners(nominees)
#
# NameError: name 'nominees' is not defined

# %%
winners_dict
# Out:
# {'cecil b. demille award': 'George Clooney',
#  'best performance by an actress in a motion picture - drama': 'Julianne Moore',
#  'best performance by an actor in a motion picture - drama': 'Eddie Redmayne',
#  'best performance by an actress in a motion picture - comedy or musical': 'Amy Adams',
#  'best performance by an actor in a motion picture - comedy or musical': 'Michael Keaton',
#  'best performance by an actress in a supporting role in a motion picture': 'Patricia Arquette',
#  'best performance by an actor in a supporting role in a motion picture': 'Simmons Whiplash',
#  'best director - motion picture': 'Richard Linklater',
#  'best screenplay - motion picture': 'Alexander Dinelaris',
#  'best original score - motion picture': 'Johann Johannsson',
#  'best performance by an actress in a television series - drama': 'Ruth Wilson',
#  'best performance by an actor in a television series - drama': 'Kevin Spacey',
#  'best performance by an actress in a television series - comedy or musical': 'Gina Rodriguez',
#  'best performance by an actor in a television series - comedy or musical': 'Jeffrey Tambor',
#  'best performance by an actress in a mini-series or motion picture made for television': 'Joanne Froggatt',
#  'best performance by an actor in a mini-series or motion picture made for television': 'Billy Bob',
#  'best performance by an actress in a supporting role in a series, mini-series or motion picture made for television': 'Joanne Froggatt',
#  'best performance by an actor in a supporting role in a series, mini-series or motion picture made for television': 'Matt Bomer'}

# %%
def compareToKB(nominees,kb):
    final_nominees = {}
        
    for i in nominees:
        award_nominees = []
        
        for j in nominees[i]:
            #print(j)
            if j[0] in kb:
                award_nominees.append(j[0])
                
        if not award_nominees:
            award_nominees = [i[0] for i in nominees[i][:5]]
        
        final_nominees[i] = award_nominees
        
    return final_nominees

# %%
media_nominees_dict = compareToKB(media_nominees, media)

# %%
media_nominees_dict
# Out:
# {'best motion picture - drama': ['Still Alice',
#   'The Song',
#   'The Grand Budapest Hotel',
#   'The Imitation Game',
#   'Gone Girl',
#   'The Theory of Everything',
#   'The Winners',
#   'Big Eyes'],
#  'best motion picture - comedy or musical': ['The Grand Budapest Hotel',
#   'Big Eyes',
#   'Mirror Mirror'],
#  'best animated feature film': ['How To Train Your Dragon',
#   'Train Your Dragon',
#   'How to Train Your Dragon',
#   'THR How',
#   'Train Your Dragon Wins'],
#  'best foreign language film': ['Force Majeure',
#   'The Hunger Games',
#   'The Raid'],
#  'best screenplay - motion picture': ['Winner AG Iñárritu Alexander Dinelaris Armando Bo for Birdman',
#   'IMDb Winner AG Iñárritu Alexander Dinelaris Armando Bo',
#   'Birdman GMA',
#   'Birdman Wins',
#   'YahooMovies Birdman'],
#  'best original score - motion picture': ['The Theory of Everything'],
#  'best original song - motion picture': ['Big Eyes'],
#  'best television series - drama': ['The Affair', 'Game of Thrones'],
#  'best television series - comedy or musical': ['Jeffrey Tambor',
#   'Actor in a or Jeffrey Tambor jeffreytambor Transparent',
#   'HereisGina Rodriguez',
#   'Congrats to HereisGina Rodriguez on her Actress',
#   'Winner or Transparent'],
#  'best mini-series or motion picture made for television': ['The Winners',
#   'True Detective']}

# %%
our_dict = {}

for award in OFFICIAL_AWARDS_1315_media:
    our_dict[award] = {
        'nominees' : media_nominees_dict[award],
        'winner' : [],
        'presenters' : []
    }

# %%
GG_OFFICIAL_AWARDS = ['Best Motion Picture - Drama','Best Motion Picture - Musical or Comedy','Best Director - Motion Picture',
'Best Original Score - Motion Picture','Best Original Song - Motion Picture','Best Foreign Language Film','Best Animated Feature Film','Best Television Series - Drama',
'Best Television Series - Comedy Or Musical','Best Screenplay - Motion Picture','Best Performance by an Actor in a Motion Picture - Drama',
'Best Performance by an Actress in a Motion Picture - Drama','Best Performance by an Actor In A Supporting Role in a Motion Picture',
'Best Performance by an Actress In A Supporting Role in a Motion Picture','Best Performance by an Actor In A Television Series - Drama','Best Performance by an Actress In A Television Series - Drama',
'Best Performance by an Actress in a Motion Picture - Comedy Or Musical','Best Performance by an Actor in a Motion Picture - Comedy Or Musical','Best Performance by an Actor In A Television Series - Comedy Or Musical',
'Best Performance by an Actress In A Television Series - Comedy Or Musical','Best Performance by an Actress in a Supporting Role in a Series','Best Performance by an Actor in a Supporting Role in a Series',
'Best Mini-Series or Motion Picture made for Television','Best Performance by an Actor in a Mini-Series or Motion Picture Made for Television','Best Performance by an Actress In A Mini-Series or Motion Picture Made for Television']

# %%
def separateAwards(award_list):
    possible_people_awards = ['actor',' actress', 'musician', ' singer', 'composer', 'director', 'producer',
                        'screenwriter', 'stage technician', 'author']

    people_awards = set()
    media_awards = set()

    for category in award_list:
        if any(job in category.lower() for job in possible_people_awards):
            people_awards.add(category)
        else:
            media_awards.add(category)

    return people_awards, media_awards

# %%
# from pprint import pprint

def easy_comp(award_list,true_dict,our_dict):
        
    # Input 
    # Dict of dictionaries 
    # Keys - Award Name
    # Values - Dictionary with keys (nominees, presenters, winner)
    
    # Output
    # Nested List (some elements are dictionarys)

    output = []

    for award in award_list:
        output.append([award,["Guess",our_dict[award]],[["True",true_dict[award]]]])

    
    return output

# For easy printing use pprint. It works nicely for updated comparison

# %%
easy_comp(OFFICIAL_AWARDS_1315_media,true_dict,our_dict)
# Out:
# [['best motion picture - drama',
#   ['Guess',
#    {'nominees': ['Still Alice',
#      'The Song',
#      'The Grand Budapest Hotel',
#      'The Imitation Game',
#      'Gone Girl',
#      'The Theory of Everything',
#      'The Winners',
#      'Big Eyes'],
#     'winner': [],
#     'presenters': []}],
#   [['True',
#     {'nominees': ['foxcatcher',
#       'the imitation game',
#       'selma',
#       'the theory of everything'],
#      'presenters': ['meryl streep'],
#      'winner': 'boyhood'}]]],
#  ['best motion picture - comedy or musical',
#   ['Guess',
#    {'nominees': ['The Grand Budapest Hotel', 'Big Eyes', 'Mirror Mirror'],
#     'winner': [],
#     'presenters': []}],
#   [['True',
#     {'nominees': ['birdman', 'into the woods', 'pride', 'st. vincent'],
#      'presenters': ['robert downey, jr.'],
#      'winner': 'the grand budapest hotel'}]]],
#  ['best animated feature film',
#   ['Guess',
#    {'nominees': ['How To Train Your Dragon',
#      'Train Your Dragon',
#      'How to Train Your Dragon',
#      'THR How',
#      'Train Your Dragon Wins'],
#     'winner': [],
#     'presenters': []}],
#   [['True',
#     {'nominees': ['big hero 6',
#       'the book of life',
#       'the boxtrolls',
#       'the lego movie'],
#      'presenters': ['kevin hart', 'salma hayek'],
#      'winner': 'how to train your dragon 2'}]]],
#  ['best foreign language film',
#   ['Guess',
#    {'nominees': ['Force Majeure', 'The Hunger Games', 'The Raid'],
#     'winner': [],
#     'presenters': []}],
#   [['True',
#     {'nominees': ['force majeure',
#       'gett: the trial of viviane amsalem',
#       'ida',
#       'tangerines'],
#      'presenters': ['colin farrell', "lupita nyong'o"],
#      'winner': 'leviathan'}]]],
#  ['best screenplay - motion picture',
#   ['Guess',
#    {'nominees': ['Winner AG Iñárritu Alexander Dinelaris Armando Bo for Birdman',
#      'IMDb Winner AG Iñárritu Alexander Dinelaris Armando Bo',
#      'Birdman GMA',
#      'Birdman Wins',
#      'YahooMovies Birdman'],
#     'winner': [],
#     'presenters': []}],
#   [['True',
#     {'nominees': ['the grand budapest hotel',
#       'gone girl',
#       'boyhood',
#       'the imitation game'],
#      'presenters': ['bill hader', 'kristen wiig'],
#      'winner': 'birdman'}]]],
#  ['best original score - motion picture',
#   ['Guess',
#    {'nominees': ['The Theory of Everything'], 'winner': [], 'presenters': []}],
#   [['True',
#     {'nominees': ['the imitation game',
#       'birdman',
#       'gone girl',
#       'interstellar'],
#      'presenters': ['sienna miller', 'vince vaughn'],
#      'winner': 'the theory of everything'}]]],
#  ['best original song - motion picture',
#   ['Guess', {'nominees': ['Big Eyes'], 'winner': [], 'presenters': []}],
#   [['True',
#     {'nominees': ['big eyes',
#       'noah',
#       'annie',
#       'the hunger games: mockingjay - part 1'],
#      'presenters': ['prince'],
#      'winner': 'selma'}]]],
#  ['best television series - drama',
#   ['Guess',
#    {'nominees': ['The Affair', 'Game of Thrones'],
#     'winner': [],
#     'presenters': []}],
#   [['True',
#     {'nominees': ['downton abbey (masterpiece)',
#       'game of thrones',
#       'the good wife',
#       'house of cards'],
#      'presenters': ['adam levine', 'paul rudd'],
#      'winner': 'the affair'}]]],
#  ['best television series - comedy or musical',
#   ['Guess',
#    {'nominees': ['Jeffrey Tambor',
#      'Actor in a or Jeffrey Tambor jeffreytambor Transparent',
#      'HereisGina Rodriguez',
#      'Congrats to HereisGina Rodriguez on her Actress',
#      'Winner or Transparent'],
#     'winner': [],
#     'presenters': []}],
#   [['True',
#     {'nominees': ['girls',
#       'jane the virgin',
#       'orange is the new black',
#       'silicon valley'],
#      'presenters': ['bryan cranston', 'kerry washington'],
#      'winner': 'transparent'}]]],
#  ['best mini-series or motion picture made for television',
#   ['Guess',
#    {'nominees': ['The Winners', 'True Detective'],
#     'winner': [],
#     'presenters': []}],
#   [['True',
#     {'nominees': ['the missing',
#       'the normal heart',
#       'olive kitteridge',
#       'true detective'],
#      'presenters': ['jennifer lopez', 'jeremy renner'],
#      'winner': 'fargo'}]]]]

# %%
media = set()

# %%
def main_exec(kb_p,kb_m):
    """
    Main execution file - how you run the program
    Itype: kb_p and kb_m are sets for our built KB's
    """
    
    # Call host search function
    # // To Do // - Insert function call (should write to JSON / return a variable to write later )
    
    # Call award entity recognition function
    # // To Do // - Insert function call (should write to JSON / return a variable to write later)
    
    # Set a variable to the hardcoded list
    hardcoded = GG_OFFICIAL_AWARDS
    
    # Segment out awards award categories
    people_awards, media_awards = seperateAwards(hardcoded)
    
    
    ## Functions below need to return a dictionary with following structure
    ## Key 1: Award Name, Value: Dictionary
    ## Key 2: [ Nominees, Winners, Presenters] 
    
    
    # Call people award search function - winner, nominee, presenter (potentially swap last two)
    ## // To DO // - Insert function call (only write to easy_comp now)
    
    
    # Call people award search function - winner, nominee, presenter (potentially swap last two)
    ## // To DO // - Insert function call ( only write to easy_comp now)
    
    
    # Merge dictionaries from two above functions
    # Return single dict for easy_comp
