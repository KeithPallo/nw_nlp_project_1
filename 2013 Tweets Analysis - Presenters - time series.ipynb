# %%
import pandas as pd
import numpy as np

import nltk
from nltk.probability import FreqDist
from nltk.tokenize import TweetTokenizer
from nltk.tokenize import sent_tokenize
from nltk.corpus import stopwords

import string
import math
import re
import datetime
import time
from collections import Counter
import statistics as st

# %%
data = pd.read_json('gg2013.json')

# %%
data = pd.DataFrame(data)

# %%
print(len(data))
# Out:
# 174643

# %%
print(data[:1])
# Out:
#                    id                                    text  \
# 0  290620657987887104  JLo's dress! #eredcarpet #GoldenGlobes
#
#          timestamp_ms                                           user contains
# 0 2013-01-14 00:45:38  {'screen_name': 'Dozaaa_xo', 'id': 557374298}    False

# %%
def timestampToUnix(t):
    return time.mktime(t.timetuple())

# %%
f = open('english.txt', 'r')
stopwords = f.read().splitlines()
#print(stopwords)

# %%
OFFICIAL_AWARDS_1315 = ['cecil b. demille award', 
                        'best motion picture - drama', 
                        'best performance by an actress in a motion picture - drama', 
                        'best performance by an actor in a motion picture - drama', 
                        'best motion picture - comedy or musical', 
                        'best performance by an actress in a motion picture - comedy or musical', 
                        'best performance by an actor in a motion picture - comedy or musical', 
                        'best animated feature film', 'best foreign language film', 
                        'best performance by an actress in a supporting role in a motion picture', 
                        'best performance by an actor in a supporting role in a motion picture', 
                        'best director - motion picture', 'best screenplay - motion picture', 
                        'best original score - motion picture', 'best original song - motion picture', 
                        'best television series - drama', 
                        'best performance by an actress in a television series - drama', 
                        'best performance by an actor in a television series - drama', 
                        'best television series - comedy or musical', 
                        'best performance by an actress in a television series - comedy or musical', 
                        'best performance by an actor in a television series - comedy or musical', 
                        'best mini-series or motion picture made for television', 
                        'best performance by an actress in a mini-series or motion picture made for television', 
                        'best performance by an actor in a mini-series or motion picture made for television', 
                        'best performance by an actress in a supporting role in a series, mini-series or motion picture made for television', 
                        'best performance by an actor in a supporting role in a series, mini-series or motion picture made for television']

# %%
def parseAward(award):
    award = re.split('\W+', award)
    award = [i for i in award if i not in stopwords]
    return award

# %%
def getAwardCategories():
    category_dict = dict()
    terms_counter = Counter()
    for a in OFFICIAL_AWARDS_1315:
        terms = parseAward(a)
        for t in terms:
            terms_counter[t] += 1
        category_dict[a] = terms
        
    return category_dict

# %%
def getTweetsForAward(category_dict, award):
    #df = pd.DataFrame(columns=['id', 'text', 'timestamp_ms', 'user'])
    l = []
    for tweet in data['text']:
        if all(term in tweet.lower() for term in category_dict[award]):
            l.append(data.loc[data.text == tweet])
    df = pd.concat(l)
    return df

# %%
def getTweetsInTimeRange(df):
    df['unixtime'] = df['timestamp_ms'].apply(lambda x:  timestampToUnix(x))
    
    mean = st.mean(df['unixtime'].values.tolist())
    stdev = st.stdev(df['unixtime'].values.tolist())
    starttime = mean - (stdev*1)
    endtime = mean + (stdev*1)
    
    starttime = datetime.datetime.fromtimestamp(starttime).strftime('%Y-%m-%d %H:%M:%S')
    endtime = datetime.datetime.fromtimestamp(endtime).strftime('%Y-%m-%d %H:%M:%S')
    
    mask = (data['timestamp_ms'] >= starttime) & (data['timestamp_ms'] <= endtime)
    df = data.loc[mask]
    print(len(df))
    return df

# %%
def getTweetsInTimeRange2(df):
    starttime = df['timestamp_ms'].min()
    endtime = df['timestamp_ms'].max()
    mask = (data['timestamp_ms'] >= starttime) & (data['timestamp_ms'] <= endtime)
    df = data.loc[mask]
    print(len(df))
    return df

# %%
def filter0(data, list1):
    result = []

    for tweet in data['text']:
        if all(term in tweet.lower() for term in list1):
            result.append(tweet)

    return result

# %%
def extractPresenters(data, list1):
    #print(data[0])
    result = []
    
    tt = TweetTokenizer(strip_handles=True, reduce_len=True, preserve_case=True)
    translator = str.maketrans('', '', string.punctuation)

    # strip stopwords, punctuation 
    #punctuation = list(string.punctuation)
    remove_terms = ['#goldenglobes', 'golden globes', '#goldenglobe', 'golden globe', 'goldenglobes', 'goldenglobe', 'rt', 'golden', 'globe', 'globes']    
    stop = remove_terms + list1
    
    for tweet in data:
        #print(tweet)
        tweet = re.sub("\d+", "", tweet) #strip nums
        tweet = re.sub(r'http\S+', '', tweet) #strip urls
        tweet = re.sub(r'#\S+', '', tweet) #strip hashtags
        #tweet = re.sub(r'[^\w\s]', '', tweet) #strip non-alphanumeric characters
        tweet = tweet.translate(translator)
        tweet = tweet.split() #tokenize
        tweet = [term for term in tweet if term.lower() not in stop] #remove stop words
        result.append(tweet)
        
    #print(result[:20])
        
    bgrams = [];

    for tweet in result:
        if tweet:
            bigram = list(nltk.bigrams(tweet))
            #print(bigram[:10])
            for bg in bigram:
                if bool(re.match('([A-Z][a-z]+)', bg[0])) and bool(re.match('([A-Z][a-z]+)', bg[1])):
                    #print(bg[0], bg[1])
                    bgrams.append(bg)
            #tweet = re.findall('([A-Z][a-z]+)', tweet)
            #if tweet:
                #bgrams += list(nltk.bigrams(tweet))
  
    fdist = nltk.FreqDist(bgrams)
    #print(fdist)
    
    try:
        temp = fdist.most_common(1)[0][0]
        name = ' '.join(temp)
    except:
        name = "nothing here"
    
    return fdist.most_common(5)

# %%
def getPresenters():
    category_dict = getAwardCategories()
    
    for award in OFFICIAL_AWARDS_1315:
        print(award)
        df = getTweetsForAward(category_dict, award)
        print(df[:5])
        df = getTweetsInTimeRange(df)
        print(df[:5])
        stopwords = category_dict[award] + ['Jessica', 'Chastain', 'Marion', 'Cotillard', 'Helen', 'Mirren', 'Naomi', 'Watts', 'Rachel', 'Weisz']
        results = filter0(df, ['present'])
        presenters = extractPresenters(results, category_dict[award])
        print(award, presenters)

# %%
getPresenters()
# Out:
# cecil b. demille award
#                        id                                               text  \
# 37780  290633958348165120  "Kristen Stewart e Simon Baker para anunciar o...
# 39286  290634456509861888  RT @TwiViciados: "Kristen Stewart e Simon Bake...
# 39708  290634618313523200  RT @HollywoodLegacy: Golden Globe History: In ...
# 42698  290635743464931329  RT @HollywoodLegacy: Golden Globe History: In ...
# 43172  290635944678277120  RT @HollywoodLegacy: Golden Globe History: In ...
#
#              timestamp_ms                                               user  \
# 37780 2013-01-14 01:38:30    {'screen_name': 'TwiViciados', 'id': 179564865}
# 39286 2013-01-14 01:40:28  {'screen_name': 'lesbianforstew_', 'id': 25471...
# 39708 2013-01-14 01:41:07         {'screen_name': 'rsethib', 'id': 22226042}
# 42698 2013-01-14 01:45:35      {'screen_name': 'TCM_Party', 'id': 401089025}
# 43172 2013-01-14 01:46:23  {'screen_name': 'JeffreyLuscombe', 'id': 17204...
#
#       contains
# 37780     True
# 39286     True
# 39708     True
# 42698     True
# 43172     True
# 29514
#                         id                                               text  \
# 112208  290654078231523330  RT @msleamichele: Inside the Golden Globes wit...
# 112209  290654077845655552  Anyone watching the Golden Globes? Apparently ...
# 112210  290654077359112192                           Back to Golden Globes...
# 112211  290654077132607488  I haven't even watched the Golden Globes yet.....
# 112212  290654076188884992  Seeing @jackantonoff at the golden globes made...
#
#               timestamp_ms                                               user  \
# 112208 2013-01-14 02:58:26  {'screen_name': 'Ana_Flaviaa99', 'id': 240354532}
# 112209 2013-01-14 02:58:26  {'screen_name': 'godfatherjames', 'id': 96860853}
# 112210 2013-01-14 02:58:26   {'screen_name': 'MizNeko_Kupo', 'id': 167637405}
# 112211 2013-01-14 02:58:26  {'screen_name': 'lawsbian_life', 'id': 894693974}
# 112212 2013-01-14 02:58:26    {'screen_name': 'hannahfin13', 'id': 458697499}
#
#        contains
# 112208    False
# 112209      NaN
# 112210      NaN
# 112211      NaN
# 112212      NaN
# cecil b. demille award [(('Alyssaeinman', 'KevalBaxi'), 93), (('Will', 'Ferrell'), 79), (('Kristen', 'Wiig'), 79), (('Wiig', 'Funny'), 77), (('Funny', 'Presenting'), 76)]
# best motion picture - drama
#                        id                                               text  \
# 10770  290625887748104192  The #GoldenGlobes are on now! Who do you think...
# 34533  290633126223441920  What are your #GoldenGlobes picks for Best Mot...
# 42026  290635578456817665  Best Motion Picture Drama should go for Life o...
# 62248  290639726728335360  Lincoln com certeza ganha BEST MOTION PICTURE ...
# 63933  290640065250615296  #Lincoln won best Motion Picture Drama #Golden...
#
#              timestamp_ms                                               user  \
# 10770 2013-01-14 01:06:25      {'screen_name': 'PsyQicInc', 'id': 562387235}
# 34533 2013-01-14 01:35:11         {'screen_name': 'Miramax', 'id': 17992258}
# 42026 2013-01-14 01:44:56       {'screen_name': 'bkkpacha', 'id': 107171260}
# 62248 2013-01-14 02:01:25     {'screen_name': '_LeoGouveia', 'id': 58085768}
# 63933 2013-01-14 02:02:46  {'screen_name': 'TheSportsGuyBAB', 'id': 45479...
#
#       contains
# 10770     True
# 34533     True
# 42026     True
# 62248     True
# 63933     True
# 15590
#                         id                                               text  \
# 151845  290667457897693184  @mcotillardfan Marion looked beautiful @ the G...
# 151846  290667457788641280  do you hear the people sing? singing the song ...
# 151847  290667457268551681  RT @BrookeandJulia1: RT IF YOU THINK BROOKE AN...
# 151848  290667457042063360  RT @_WarnABrother: The golden globes are fucki...
# 151849  290667456765239297  Golden Globes Backstage 2013: Adele's Going fo...
#
#               timestamp_ms                                               user  \
# 151845 2013-01-14 03:51:36     {'screen_name': 'SaraZaim1', 'id': 1072234898}
# 151846 2013-01-14 03:51:36  {'screen_name': '18hollywilson', 'id': 318115607}
# 151847 2013-01-14 03:51:36   {'screen_name': 'LoFrickinRaye', 'id': 27083059}
# 151848 2013-01-14 03:51:36  {'screen_name': 'tatyanastamper', 'id': 77520487}
# 151849 2013-01-14 03:51:36  {'screen_name': 'HollywoodNewz1', 'id': 297711...
#
#        contains
# 151845      NaN
# 151846      NaN
# 151847      NaN
# 151848      NaN
# 151849      NaN
# best motion picture - drama [(('Julia', 'Roberts'), 22), (('Christian', 'Bale'), 9), (('Will', 'Ferrell'), 8), (('Amy', 'Poehler'), 8), (('Tina', 'Fey'), 8)]
# best performance by an actress in a motion picture - drama
#                         id                                               text  \
# 149445  290666623361220608  Best Performance by an Actress in a Motion Pic...
# 149486  290666621071147008  BEST PERFORMANCE BY AN ACTRESS IN A MOTION PIC...
# 149618  290666675169271808  Best Performance by an Actress in a Motion Pic...
# 150589  290666890387406848  RT @MTVNews: Best Performance by an Actress in...
# 150691  290666968221102081  Best Performance by an Actress in a Motion Pic...
#
#               timestamp_ms                                             user  \
# 149445 2013-01-14 03:48:17         {'screen_name': 'MSNtv', 'id': 24034570}
# 149486 2013-01-14 03:48:17  {'screen_name': 'alves_andrea', 'id': 40535932}
# 149618 2013-01-14 03:48:30   {'screen_name': 'djaycoholyc', 'id': 34886146}
# 150589 2013-01-14 03:49:21    {'screen_name': 'natizitax', 'id': 100812697}
# 150691 2013-01-14 03:49:40    {'screen_name': 'RominaBond', 'id': 40014872}
#
#        contains
# 149445     True
# 149486     True
# 149618     True
# 150589     True
# 150691     True
# 12998
#                         id                                               text  \
# 147762  290665767719010304  RT @gmanews: .@LesMiserables wins Best Motion ...
# 147763  290665767693856768  RT @TeamCoco: Hopefully the #GoldenGlobes insp...
# 147764  290665767664496642  RT @teganandsara: So cool that Jodie Foster ca...
# 147765  290665767656116224  Basically Tina &amp; Amy killed it, @JLo  was ...
# 147766  290665767622557696  @LautererAnne: The only problem with #GoldenGl...
#
#               timestamp_ms                                               user  \
# 147762 2013-01-14 03:44:53   {'screen_name': 'iamkennethic', 'id': 159024837}
# 147763 2013-01-14 03:44:53   {'screen_name': 'AngelaCabrera', 'id': 32981039}
# 147764 2013-01-14 03:44:53     {'screen_name': 'taaaaastyg', 'id': 275830076}
# 147765 2013-01-14 03:44:53      {'screen_name': 'lewanthony', 'id': 23146191}
# 147766 2013-01-14 03:44:53  {'screen_name': 'LautererAnne', 'id': 1049451817}
#
#        contains
# 147762     True
# 147763      NaN
# 147764      NaN
# 147765      NaN
# 147766      NaN
# best performance by an actress in a motion picture - drama [(('George', 'Clooney'), 23), (('Julia', 'Roberts'), 13), (('Will', 'Ferrell'), 9), (('NotBillWalton', 'Batman'), 8), (('Jessica', 'Chastain'), 7)]
# best performance by an actor in a motion picture - drama
#                         id                                               text  \
# 151218  290667240745996288  Daniel Day-Lewis - Best Performance by an Acto...
# 151629  290667428701167616  Daniel Day-Lewis has just won Best Performance...
# 151987  290667472670056448  RT @LincolnMovie: Congrats to Daniel Day-Lewis...
# 152473  290667574683914244  RT @LincolnMovie: Congrats to Daniel Day-Lewis...
# 152498  290667573501112320  RT @LincolnMovie: Congrats to Daniel Day-Lewis...
#
#               timestamp_ms                                               user  \
# 151218 2013-01-14 03:50:45  {'screen_name': 'golden_globes', 'id': 105991003}
# 151629 2013-01-14 03:51:29   {'screen_name': 'rhettdavison', 'id': 247288142}
# 151987 2013-01-14 03:51:40     {'screen_name': 'Cp3Superman', 'id': 22106825}
# 152473 2013-01-14 03:52:04         {'screen_name': 'Nati3u', 'id': 378039259}
# 152498 2013-01-14 03:52:04        {'screen_name': 'JohnG500', 'id': 17665654}
#
#        contains
# 151218     True
# 151629     True
# 151987     True
# 152473     True
# 152498     True
# 16023
#                         id                                               text  \
# 152587  290667587732373504  Some fun Tweets about Bill Clinton at Golden G...
# 152588  290667587380064256  Re-watched Butter with @JohnnyG118, @DaniSue13...
# 152589  290667587254243328  RT @rdjfilmguide: And we have a shaky recordin...
# 152590  290667586960650241  RT @b50: I remember Sofia Vergara saying (twee...
# 152591  290667586209865729  RT @eonline: Best Actor in a Motion Picture, D...
#
#               timestamp_ms                                              user  \
# 152587 2013-01-14 03:52:07  {'screen_name': 'Jess_Chambers', 'id': 19207217}
# 152588 2013-01-14 03:52:07    {'screen_name': 'baharxcore', 'id': 272167513}
# 152589 2013-01-14 03:52:07     {'screen_name': 'tsuzureori', 'id': 76859944}
# 152590 2013-01-14 03:52:07  {'screen_name': 'VaguelyCrass', 'id': 413774442}
# 152591 2013-01-14 03:52:07      {'screen_name': 'RalphHipp', 'id': 15396453}
#
#        contains
# 152587      NaN
# 152588      NaN
# 152589      NaN
# 152590      NaN
# 152591     True
# best performance by an actor in a motion picture - drama [(('Julia', 'Roberts'), 22), (('Christian', 'Bale'), 9), (('Will', 'Ferrell'), 8), (('Amy', 'Poehler'), 8), (('Tina', 'Fey'), 8)]
# best motion picture - comedy or musical
#                        id                                               text  \
# 27067  290630489134481409  It's weird that they put comedy and musical in...
# 28134  290630758035501056  A nominee for #BestMotionPicture for A Comedy ...
# 28795  290631125905330176  Let's hope the Hollywood Foreign Press made th...
# 63576  290640048272072704  Best Actress in a Motion Picture Comedy/Musica...
# 64868  290640382453235712  Jennifer Lawrence better win for this! #Golden...
#
#              timestamp_ms                                               user  \
# 27067 2013-01-14 01:24:42    {'screen_name': 'thelilyriver', 'id': 83414986}
# 28134 2013-01-14 01:25:47  {'screen_name': 'ChasingCinema', 'id': 525493157}
# 28795 2013-01-14 01:27:14   {'screen_name': 'TylerHoltzman', 'id': 15073512}
# 63576 2013-01-14 02:02:41           {'screen_name': 's3nsi', 'id': 73888208}
# 64868 2013-01-14 02:04:01   {'screen_name': 'holly_caitlin', 'id': 21166924}
#
#       contains
# 27067     True
# 28134     True
# 28795     True
# 63576     True
# 64868     True
# 67421
#                        id                                               text  \
# 95659  290648436871659520  Mais que merecido ganhar o Amour #ForeignMovie...
# 95660  290648436737454080                               Zenkui #GoldenGlobes
# 95661  290648436708098049  RT @eliroth: Quentin's #GoldenGlobes speech ma...
# 95662  290648436682932224  RT @TheEllenShow: I can't believe how hard I l...
# 95663  290648436628389888  Well that was well planned! Arnold presents aw...
#
#              timestamp_ms                                               user  \
# 95659 2013-01-14 02:36:01  {'screen_name': 'MarianaORocha', 'id': 107070350}
# 95660 2013-01-14 02:36:01    {'screen_name': 'marcelitorm', 'id': 124193391}
# 95661 2013-01-14 02:36:01     {'screen_name': 'jmattsonjr', 'id': 192181161}
# 95662 2013-01-14 02:36:01     {'screen_name': 'kadymcel13', 'id': 236103197}
# 95663 2013-01-14 02:36:01    {'screen_name': 'paigesellis', 'id': 207694542}
#
#       contains
# 95659      NaN
# 95660      NaN
# 95661      NaN
# 95662      NaN
# 95663      NaN
# best motion picture - comedy or musical [(('Will', 'Ferrell'), 110), (('Alyssaeinman', 'KevalBaxi'), 97), (('Kristen', 'Wiig'), 96), (('Wiig', 'Funny'), 83), (('Jodie', 'Foster'), 82)]
# best performance by an actress in a motion picture - comedy or musical
#                        id                                               text  \
# 68678  290641160295297026  #GoldenGlobes Best Performance By An Actress I...
# 69759  290641372078301184  SILVER LININGS PLAYBOOK star JENNIFER LAWRENCE...
# 74585  290642319697399808  Best Performance by an Actress in a Motion Pic...
# 79180  290643712655110145  Best Performance by an Actress in a Motion Pic...
# 98680  290649168857411584  RT @ssetiawan: Best Performance by An Actress ...
#
#              timestamp_ms                                              user  \
# 68678 2013-01-14 02:07:07  {'screen_name': 'agastiazirtaf', 'id': 29381486}
# 69759 2013-01-14 02:07:57    {'screen_name': 'RamasScreen', 'id': 14808260}
# 74585 2013-01-14 02:11:43  {'screen_name': 'Layar_Tancep', 'id': 633875340}
# 79180 2013-01-14 02:17:15     {'screen_name': 'OrangeSoul', 'id': 29677190}
# 98680 2013-01-14 02:38:56         {'screen_name': 'arms87', 'id': 51337940}
#
#       contains
# 68678     True
# 69759     True
# 74585     True
# 79180     True
# 98680     True
# 89468
#                        id                                               text  \
# 43829  290636189495599104  RT @NegativeNatalie: dude. JENNIFER LOPEZ. AMA...
# 43830  290636189420122112               @guitarradorob https://t.co/qynNPl4M
# 43831  290636189403344896  Uhuuul! Life of Pi ganhando seu 1o de muitos. ...
# 43832  290636189403328513  I'm betting that guys' wife is not the most be...
# 43833  290636189390745600  I could look at Jason Statham all day! #Golden...
#
#              timestamp_ms                                               user  \
# 43829 2013-01-14 01:47:21      {'screen_name': 'muycatrina', 'id': 13556832}
# 43830 2013-01-14 01:47:21  {'screen_name': 'twilight_ZacE', 'id': 502324950}
# 43831 2013-01-14 01:47:21  {'screen_name': 'vanessamayfair', 'id': 52876846}
# 43832 2013-01-14 01:47:21     {'screen_name': 'HanSteffen', 'id': 157108373}
# 43833 2013-01-14 01:47:21       {'screen_name': 'klahines', 'id': 881422106}
#
#       contains
# 43829      NaN
# 43830      NaN
# 43831      NaN
# 43832      NaN
# 43833      NaN
# best performance by an actress in a motion picture - comedy or musical [(('Bill', 'Clinton'), 253), (('Kristen', 'Wiig'), 141), (('Will', 'Ferrell'), 135), (('Wiig', 'Funny'), 76), (('Funny', 'Presenting'), 76)]
# best performance by an actor in a motion picture - comedy or musical
#                         id                                               text  \
# 138658  290662596128948225  Best Performance by an Actor in a Motion Pictu...
# 139135  290662681139097600  Hugh Jackman has just won Best Performance by ...
# 141716  290663352219357184  RT @MTVNews: Way to go @RealHughJackman for Be...
# 142346  290663702594740226  RT @MTVNews: Way to go @RealHughJackman for Be...
# 142498  290663768508231682  RT @MTVNews: Way to go @RealHughJackman for Be...
#
#               timestamp_ms                                               user  \
# 138658 2013-01-14 03:32:17           {'screen_name': 'MSNtv', 'id': 24034570}
# 139135 2013-01-14 03:32:38   {'screen_name': 'rhettdavison', 'id': 247288142}
# 141716 2013-01-14 03:35:18         {'screen_name': 'tri4mut', 'id': 42318019}
# 142346 2013-01-14 03:36:41  {'screen_name': 'PKelleyAlvarado', 'id': 12287...
# 142498 2013-01-14 03:36:57       {'screen_name': '3houdyM_', 'id': 263652747}
#
#        contains
# 138658     True
# 139135     True
# 141716     True
# 142346     True
# 142498     True
# 5961
#                         id                                               text  \
# 140018  290662916343091201         Tina Fey just went there...😳 #GoldenGlobes
# 140019  290662916338880512  RT @glossedover: Jennifer Garner, Victor Garbe...
# 140020  290662916326322176  RT @goldenglobes: From the pressroom: Jodie Fo...
# 140021  290662916280172544  Hugh Jackman, maybe greatest human on the plan...
# 140022  290662916259201024  RT @BuzzFeed: Retweet if you're dying to know ...
#
#               timestamp_ms                                              user  \
# 140018 2013-01-14 03:33:34      {'screen_name': 'JCoops89', 'id': 387415706}
# 140019 2013-01-14 03:33:34       {'screen_name': 'stackdr', 'id': 174512728}
# 140020 2013-01-14 03:33:34     {'screen_name': 'jimeniwuis', 'id': 52414269}
# 140021 2013-01-14 03:33:34     {'screen_name': 'BooMarcus', 'id': 287860696}
# 140022 2013-01-14 03:33:34  {'screen_name': 'PammiePkh333', 'id': 770039270}
#
#        contains
# 140018      NaN
# 140019      NaN
# 140020      NaN
# 140021      NaN
# 140022      NaN
# best performance by an actor in a motion picture - comedy or musical [(('Alyssaeinman', 'KevalBaxi'), 14), (('Will', 'Ferrell'), 14), (('Bill', 'Clinton'), 12), (('Kristen', 'Wiig'), 11), (('Wiig', 'Funny'), 7)]
# best animated feature film
#                        id                                               text  \
# 39393  290634476541853696  RT @OfficialSMGNews: Hotel Transylvania is nom...
# 39660  290634586654900226  RT @OfficialSMGNews: Hotel Transylvania is nom...
# 39774  290634641378009088  RT @OfficialSMGNews: Hotel Transylvania is nom...
# 39881  290634689335668736  RT @OfficialSMGNews: Hotel Transylvania is nom...
# 40116  290634729122828290  RT @OfficialSMGNews: Hotel Transylvania is nom...
#
#              timestamp_ms                                               user  \
# 39393 2013-01-14 01:40:33  {'screen_name': 'RealSelenaFan', 'id': 119297224}
# 39660 2013-01-14 01:40:59  {'screen_name': 'fuckjelenadrama', 'id': 15830...
# 39774 2013-01-14 01:41:12     {'screen_name': 'isamartinv', 'id': 532350074}
# 39881 2013-01-14 01:41:24  {'screen_name': 'BieberGomezTour', 'id': 56318...
# 40116 2013-01-14 01:41:33      {'screen_name': 'BiaScotto', 'id': 131985875}
#
#       contains
# 39393     True
# 39660     True
# 39774     True
# 39881     True
# 40116     True
# 50227
#                        id                                               text  \
# 92725  290647383879081984    Matt LINDO forever My Joey !!!!!! #GoldenGlobes
# 92726  290647383799386112  RT @denisehutterz: Mejor canción original para...
# 92727  290647383744860160                 So many celebrities. #GoldenGlobes
# 92728  290647383740669953  In other news, I still love Robert Pattinson. ...
# 92729  290647383568707585  Tina Fey &amp; Amy Poehler are hilarious.  Lov...
#
#              timestamp_ms                                               user  \
# 92725 2013-01-14 02:31:50      {'screen_name': 'MiiPacheco', 'id': 58873738}
# 92726 2013-01-14 02:31:50  {'screen_name': 'AlbinoHerebia', 'id': 983166529}
# 92727 2013-01-14 02:31:50     {'screen_name': '_RHITARDED', 'id': 872904115}
# 92728 2013-01-14 02:31:50  {'screen_name': 'whenyouwereeast', 'id': 15608...
# 92729 2013-01-14 02:31:50          {'screen_name': 'csmjnn', 'id': 16939760}
#
#       contains
# 92725      NaN
# 92726      NaN
# 92727      NaN
# 92728      NaN
# 92729      NaN
# best animated feature film [(('Alyssaeinman', 'KevalBaxi'), 93), (('Will', 'Ferrell'), 85), (('Kristen', 'Wiig'), 85), (('Wiig', 'Funny'), 77), (('Funny', 'Presenting'), 76)]
# best foreign language film
#                        id                                               text  \
# 44236  290636280784629761  RT @AmourFilm: Keep your fingers crossed for #...
# 94530  290648111666323456  Sylvester Stallone and @Schwarzenegger present...
# 94669  290648176778682368  Best Foreign Language Film: Amour (Austria) #G...
# 94696  290648175931432960  Yep, AMOUR wins Best Foreign Language Film #Go...
# 94731  290648174094327808  Best foreign language film goes to Amour! #Gol...
#
#              timestamp_ms                                              user  \
# 44236 2013-01-14 01:47:43  {'screen_name': 'pwoblematique', 'id': 19537857}
# 94530 2013-01-14 02:34:44     {'screen_name': 'samtraspe', 'id': 135435635}
# 94669 2013-01-14 02:34:59      {'screen_name': 'yontefian', 'id': 20027344}
# 94696 2013-01-14 02:34:59   {'screen_name': 'TheFilmChair', 'id': 82661658}
# 94731 2013-01-14 02:34:59    {'screen_name': 'MelindaJane', 'id': 18031568}
#
#       contains
# 44236     True
# 94530     True
# 94669     True
# 94696     True
# 94731     True
# 40843
#                        id                                               text  \
# 84995  290645106602700800  RT @jianghomeshi: Spielberg has President Bill...
# 84996  290645106489454592  Hard pick “@glamour_fashion: Ladies and gents,...
# 84997  290645106447491073  RT @RichardCrouse: I knew Tommy Lee Jones remi...
# 84998  290645106430709761  The #GoldenGlobes is a show that hands out awa...
# 84999  290645106380398593  RT @The12Signs: John Krazinski from The Office...
#
#              timestamp_ms                                               user  \
# 84995 2013-01-14 02:22:47    {'screen_name': 'braedencaley', 'id': 16116073}
# 84996 2013-01-14 02:22:47      {'screen_name': 'VicoloMio', 'id': 373124336}
# 84997 2013-01-14 02:22:47   {'screen_name': 'matthewislife', 'id': 35085500}
# 84998 2013-01-14 02:22:47       {'screen_name': 'Saltydawg', 'id': 18129450}
# 84999 2013-01-14 02:22:47  {'screen_name': 'crystalambergee', 'id': 23674...
#
#       contains
# 84995      NaN
# 84996      NaN
# 84997      NaN
# 84998      NaN
# 84999      NaN
# best foreign language film [(('Will', 'Ferrell'), 89), (('Kristen', 'Wiig'), 88), (('Wiig', 'Funny'), 76), (('Funny', 'Presenting'), 76), (('Presenting', 'Video'), 76)]
# best performance by an actress in a supporting role in a motion picture
#                        id                                               text  \
# 17173  290627420141260800  Maggie Smith - Best Performance by an Actress ...
# 77653  290643371473657857  Best Performance by an Actress in a Supporting...
# 78652  290643601128574977  #GoldenGlobes Best Performance By An Actress I...
# 79038  290643681696948224  RT @Layar_Tancep: Best Performance by an Actre...
# 79252  290643710323077121  Winner,Best Performance by an Actress in a Sup...
#
#              timestamp_ms                                               user  \
# 17173 2013-01-14 01:12:31  {'screen_name': 'golden_globes', 'id': 105991003}
# 77653 2013-01-14 02:15:54   {'screen_name': 'Layar_Tancep', 'id': 633875340}
# 78652 2013-01-14 02:16:49   {'screen_name': 'agastiazirtaf', 'id': 29381486}
# 79038 2013-01-14 02:17:08        {'screen_name': 'adiit365', 'id': 51737964}
# 79252 2013-01-14 02:17:15       {'screen_name': 'OnlyDunya', 'id': 30931431}
#
#       contains
# 17173     True
# 77653     True
# 78652     True
# 79038     True
# 79252     True
# 59262
#                        id                                               text  \
# 34513  290633127691431937  well, id clap for him anyday. #goldenglobes #s...
# 34514  290633127506878464  RT @piersmorgan: ZING! 'When it comes to tortu...
# 34515  290633127448170496  @siervo82 sera q a mi @wwwbigbaldhead esta en ...
# 34516  290633127439777792  Damian Lewis wins Best Actor for Homeland, ded...
# 34517  290633127309758465  I can't believe how many guys are lusting afte...
#
#              timestamp_ms                                           user  \
# 34513 2013-01-14 01:35:11      {'screen_name': 'h3llur', 'id': 23527882}
# 34514 2013-01-14 01:35:11    {'screen_name': 'madsamjo', 'id': 25385702}
# 34515 2013-01-14 01:35:11  {'screen_name': 'romavical', 'id': 255202644}
# 34516 2013-01-14 01:35:11  {'screen_name': 'ScyShirley', 'id': 26395861}
# 34517 2013-01-14 01:35:11    {'screen_name': 'Chumplet', 'id': 49487929}
#
#       contains
# 34513      NaN
# 34514      NaN
# 34515      NaN
# 34516      NaN
# 34517      NaN
# best performance by an actress in a supporting role in a motion picture [(('Bill', 'Clinton'), 205), (('Kristen', 'Wiig'), 60), (('Will', 'Ferrell'), 54), (('Steven', 'Spielberg'), 24), (('United', 'States'), 20)]
# best performance by an actor in a supporting role in a motion picture
#                        id                                               text  \
# 13819  290626743050575873  Christoph Waltz - Best Performance by an Actor...
# 14357  290626842111651841  Best Performance by An Actor in A Supporting R...
# 15661  290626992229982208  :))) RT @larry411: BEST PERFORMANCE BY AN ACTO...
# 18429  290627743513722880  RT @Layar_Tancep: Best Performance by an Actor...
# 18753  290627809456582657  RT @ssetiawan: Best Performance by An Actor in...
#
#              timestamp_ms                                               user  \
# 13819 2013-01-14 01:09:49  {'screen_name': 'golden_globes', 'id': 105991003}
# 14357 2013-01-14 01:10:13       {'screen_name': 'ssetiawan', 'id': 48053374}
# 15661 2013-01-14 01:10:49   {'screen_name': 'BrunetteStew', 'id': 106195417}
# 18429 2013-01-14 01:13:48        {'screen_name': 'adiit365', 'id': 51737964}
# 18753 2013-01-14 01:14:04          {'screen_name': 'arms87', 'id': 51337940}
#
#       contains
# 13819     True
# 14357     True
# 15661     True
# 18429     True
# 18753     True
# 8454
#                        id                                               text  \
# 13120  290626571943948288  The golden globes have been on for less than t...
# 13121  290626571641954304     Absolutely loves watching The Golden Globes#fb
# 13122  290626571436425216  RT @livraz: Piadas de apresentação do Golden G...
# 13123  290626571293835264                                  Golden globes ✨🌟💫
# 13124  290626571071537153  please stop tweeting the golden globes cos i a...
#
#              timestamp_ms                                               user  \
# 13120 2013-01-14 01:09:08     {'screen_name': 'JoelGerb23', 'id': 193427505}
# 13121 2013-01-14 01:09:08       {'screen_name': 'emacgrass', 'id': 36713288}
# 13122 2013-01-14 01:09:08     {'screen_name': 'ma_marita_', 'id': 100117319}
# 13123 2013-01-14 01:09:08  {'screen_name': 'Jadore_Sophia', 'id': 237594374}
# 13124 2013-01-14 01:09:08         {'screen_name': 'jxmest', 'id': 441941799}
#
#       contains
# 13120      NaN
# 13121      NaN
# 13122      NaN
# 13123      NaN
# 13124      NaN
# best performance by an actor in a supporting role in a motion picture [(('Bradley', 'Cooper'), 11), (('Kate', 'Hudson'), 10), (('Amy', 'Poehler'), 6), (('Maggie', 'Smith'), 6), (('Que', 'James'), 4)]
# best director - motion picture
#                         id                                               text  \
# 86113   290645493808246785  RT @TVGMDamian: Bets director, motion picture ...
# 86963   290645710695706625  !!!!!!! “@MTVNews: Quentin Tarantino wins Best...
# 126701  290658837973852160  Ben Affleck wins #goldenglobes for best direct...
# 126858  290658873684135936  Best Director – Motion Picture: Ben Affleck, A...
# 126919  290658900024389632  Best Director Motion Picture- Ben Affleck #Gol...
#
#               timestamp_ms                                               user  \
# 86113  2013-01-14 02:24:20      {'screen_name': 'JJordan527', 'id': 19306610}
# 86963  2013-01-14 02:25:12        {'screen_name': '_AleCoop', 'id': 61047757}
# 126701 2013-01-14 03:17:21   {'screen_name': 'stevengregory', 'id': 16192212}
# 126858 2013-01-14 03:17:30       {'screen_name': 'MyFannia', 'id': 575695364}
# 126919 2013-01-14 03:17:36  {'screen_name': 'StevePanzarella', 'id': 20586...
#
#        contains
# 86113      True
# 86963      True
# 126701     True
# 126858     True
# 126919     True
# 33015
#                         id                                               text  \
# 135008  290661099269922816  kingofconeyisland: adele even wins golden glob...
# 135009  290661099076980736  RT @KiddKraddick: Jodi Foster just gave the mo...
# 135010  290661099022475264  RT @Alyssaeinman: @KevalBaxi just saw you pres...
# 135011  290661098921807875  My dad just turned off the golden globes to wa...
# 135012  290661098825334784  RT @THR: "Girls"  wins the #GoldenGlobe for Be...
#
#               timestamp_ms                                               user  \
# 135008 2013-01-14 03:26:20        {'screen_name': 'bionsay', 'id': 101564564}
# 135009 2013-01-14 03:26:20       {'screen_name': 'Damio_92', 'id': 412334220}
# 135010 2013-01-14 03:26:20       {'screen_name': 'Nancyk90', 'id': 940158217}
# 135011 2013-01-14 03:26:20  {'screen_name': 'yourdreamGEI_b', 'id': 164511...
# 135012 2013-01-14 03:26:20       {'screen_name': 'TingRoll', 'id': 545490535}
#
#        contains
# 135008      NaN
# 135009      NaN
# 135010      NaN
# 135011      NaN
# 135012      NaN
# best director - motion picture [(('Alyssaeinman', 'KevalBaxi'), 91), (('Will', 'Ferrell'), 32), (('George', 'Clooney'), 24), (('NotBillWalton', 'Batman'), 23), (('Julia', 'Roberts'), 22)]
# best screenplay - motion picture
#                        id                                               text  \
# 85460  290645304871628800  Robert Pattinson and Amanda Seyfried present t...
# 85464  290645304716455936  Robert Pattinson alert! Presenting Best Screen...
# 85510  290645357921193984  Best Screenplay - Motion Picture: Quentin Tara...
# 85842  290645456877391873  RT @nbc: Django Unchained takes home the award...
# 86066  290645495867650049  RT @nbc: Django Unchained takes home the award...
#
#              timestamp_ms                                               user  \
# 85460 2013-01-14 02:23:35      {'screen_name': 'samtraspe', 'id': 135435635}
# 85464 2013-01-14 02:23:35      {'screen_name': 'OKMagazine', 'id': 14353891}
# 85510 2013-01-14 02:23:47       {'screen_name': 'MarlowNYC', 'id': 24544452}
# 85842 2013-01-14 02:24:11  {'screen_name': 'SincerelyBhop', 'id': 189935217}
# 86066 2013-01-14 02:24:20     {'screen_name': 'kimilee116', 'id': 426973684}
#
#       contains
# 85460     True
# 85464     True
# 85510     True
# 85842     True
# 86066     True
# 41301
#                        id                                               text  \
# 77980  290643441476579330  ANNE MARAVILHOSA PASSA NA CARA DA NICOLÃO VAI ...
# 77981  290643441459814401  RT @goldenglobes: Best Supporting Actress in a...
# 77982  290643441438846977  is it me or do alot of the actresses have the ...
# 77983  290643441409470464  marion cotillard is gorgeous like always #gold...
# 77984  290643441380118528  THEY ARE PLAYING I DREAMED A DREAM. I'M DEAD #...
#
#              timestamp_ms                                               user  \
# 77980 2013-01-14 02:16:10    {'screen_name': 'crestomanci_', 'id': 51100187}
# 77981 2013-01-14 02:16:10     {'screen_name': 'howtobeyan', 'id': 110314556}
# 77982 2013-01-14 02:16:10   {'screen_name': 'Denise_C_Rod', 'id': 445906751}
# 77983 2013-01-14 02:16:10  {'screen_name': 'DaDustBuffalo', 'id': 284588586}
# 77984 2013-01-14 02:16:10  {'screen_name': 'avery__thompson', 'id': 36088...
#
#       contains
# 77980      NaN
# 77981      NaN
# 77982      NaN
# 77983      NaN
# 77984      NaN
# best screenplay - motion picture [(('Downey', 'Jr'), 57), (('Jodie', 'Foster'), 57), (('Robert', 'Downey'), 56), (('Bill', 'Clinton'), 51), (('Robert', 'Pattinson'), 18)]
# best original score - motion picture
#                        id                                               text  \
# 42728  290635741657194496  #LifeOfPie wins Best Original Score - Motion P...
# 42813  290635750272299008  #GoldenGlobes   Life of Pi (Mychael Danna) win...
# 42952  290635828315684868  RT @KNXDavid: #GoldenGlobes   Life of Pi (Mych...
# 42966  290635827703316481  Best Original Score - Motion Picture.... #Mich...
# 43032  290635829288783872  Best Original Score, Motion Picture: Michael D...
#
#              timestamp_ms                                               user  \
# 42728 2013-01-14 01:45:35    {'screen_name': 'vicivadeline', 'id': 38867859}
# 42813 2013-01-14 01:45:37        {'screen_name': 'KNXDavid', 'id': 47416539}
# 42952 2013-01-14 01:45:55         {'screen_name': 'KNX1070', 'id': 18149465}
# 42966 2013-01-14 01:45:55         {'screen_name': 'jcaci12', 'id': 31649258}
# 43032 2013-01-14 01:45:56  {'screen_name': 'rapplerdotcom', 'id': 330826792}
#
#       contains
# 42728     True
# 42813     True
# 42952     True
# 42966     True
# 43032     True
# 78816
#                        id                                               text  \
# 41749  290635497418665985  RT @TheOnion: Justin Timberlake Wins Golden Gl...
# 41750  290635497406099456  Demostrado que la realidad supera la ficción, ...
# 41751  290635497372545024   Tony Méndez presenta "Argo" en los #GoldenGlobes
# 41752  290635497359945728   quem é essa mulher que ta falando? #GoldenGlobes
# 41753  290635497309626368                J lo Looks Smokin HOT #GoldenGlobes
#
#              timestamp_ms                                               user  \
# 41749 2013-01-14 01:44:36         {'screen_name': 'cwidner', 'id': 20574223}
# 41750 2013-01-14 01:44:36           {'screen_name': 'm_29', 'id': 132263345}
# 41751 2013-01-14 01:44:36  {'screen_name': 'AP_Espectaculos', 'id': 37336...
# 41752 2013-01-14 01:44:36      {'screen_name': 'gagamycat', 'id': 545309690}
# 41753 2013-01-14 01:44:36  {'screen_name': 'HerMajestyMiggy', 'id': 76591...
#
#       contains
# 41749      NaN
# 41750      NaN
# 41751      NaN
# 41752      NaN
# 41753      NaN
# best original score - motion picture [(('Bill', 'Clinton'), 239), (('Kristen', 'Wiig'), 64), (('Will', 'Ferrell'), 58), (('Downey', 'Jr'), 58), (('Jodie', 'Foster'), 58)]
# best original song - motion picture
#                        id                                               text  \
# 18411  290627744553922560  Good luck to @taylorswift13 and @keithurban wh...
# 44849  290636506559815682  Original Song in Motion Picture: GO ADELE!!!! ...
# 45107  290636612986081281  Best Original Song - Motion Picture: Skyfall |...
# 45156  290636616106659840  #GoldenGlobes Best Original Song - Motion Pict...
# 45172  290636615330693120  Best Original Song Motion Picture goes to Adel...
#
#              timestamp_ms                                               user  \
# 18411 2013-01-14 01:13:48  {'screen_name': 'QX104winnipeg', 'id': 419756944}
# 44849 2013-01-14 01:48:37  {'screen_name': 'FusionRockRadio', 'id': 21923...
# 45107 2013-01-14 01:49:02  {'screen_name': 'juanda_duarte', 'id': 161177856}
# 45156 2013-01-14 01:49:03       {'screen_name': 'B_byJane', 'id': 124827659}
# 45172 2013-01-14 01:49:03     {'screen_name': 'JB_hasSWAG', 'id': 184471995}
#
#       contains
# 18411     True
# 44849     True
# 45107     True
# 45156     True
# 45172     True
# 58759
#                        id                                               text  \
# 37098  290633730563911680  RT @VanityFair: “Meryl Streep is not here toni...
# 37099  290633730475839488  Yo sabía que cada minuto libre que tuve el año...
# 37100  290633730396155905  Lots of new fave #glutenfree things to talk ab...
# 37101  290633730358382594  RT @stillnsync: “@TheOnion: Justin Timberlake ...
# 37102  290633730333241346             agora caiu de vez @tntbr #GoldenGlobes
#
#              timestamp_ms                                               user  \
# 37098 2013-01-14 01:37:35     {'screen_name': 'katemmurph', 'id': 785785393}
# 37099 2013-01-14 01:37:35      {'screen_name': 'crislopezg', 'id': 15790762}
# 37100 2013-01-14 01:37:35    {'screen_name': 'gfauthority', 'id': 554640902}
# 37101 2013-01-14 01:37:35   {'screen_name': 'always_nsync', 'id': 724584475}
# 37102 2013-01-14 01:37:35  {'screen_name': 'williamrodrigue', 'id': 48763...
#
#       contains
# 37098      NaN
# 37099      NaN
# 37100      NaN
# 37101      NaN
# 37102      NaN
# best original song - motion picture [(('Bill', 'Clinton'), 207), (('Kristen', 'Wiig'), 60), (('Will', 'Ferrell'), 54), (('Steven', 'Spielberg'), 24), (('United', 'States'), 23)]
# best television series - drama
#                        id                                               text  \
# 32640  290632540325289985  RT @goldenglobes: Best Television Series Actor...
# 32645  290632540107206657  RT @goldenglobes: Best Television Series Actor...
# 32685  290632538270089217  RT @goldenglobes: Best Television Series Actor...
# 32724  290632540845379584  RT @goldenglobes: Best Television Series Actor...
# 32736  290632594687684610  RT @goldenglobes: Best Television Series Actor...
#
#              timestamp_ms                                               user  \
# 32640 2013-01-14 01:32:51         {'screen_name': 'wasther', 'id': 46520373}
# 32645 2013-01-14 01:32:51      {'screen_name': 'xoxolvwbh', 'id': 491997122}
# 32685 2013-01-14 01:32:51    {'screen_name': 'Cam_Rumrill', 'id': 847327868}
# 32724 2013-01-14 01:32:52  {'screen_name': 'CaritoArroyave1', 'id': 38517...
# 32736 2013-01-14 01:33:04         {'screen_name': 'twicol', 'id': 104013499}
#
#       contains
# 32640     True
# 32645     True
# 32685     True
# 32724     True
# 32736     True
# 82445
#                        id                                               text  \
# 25178  290629864455823360  "Selena's at the Golden Globes sitting in the ...
# 25179  290629864350961664                     Watching the Golden Globes :))
# 25180  290629864162217984  Golden Globes: On the red carpet http://t.co/R...
# 25181  290629863881183232  RT @DadBoner: Unless The Golden Globes is a sh...
# 25182  290629863772131329  Photo: vivathebella: Megan Fox at the 70th Ann...
#
#              timestamp_ms                                               user  \
# 25178 2013-01-14 01:22:13  {'screen_name': 'iFadedOnBieber', 'id': 298539...
# 25179 2013-01-14 01:22:13  {'screen_name': 'rachelsharp917', 'id': 865113...
# 25180 2013-01-14 01:22:13           {'screen_name': 'TyBiz', 'id': 76422030}
# 25181 2013-01-14 01:22:13     {'screen_name': 'RM_Mathews', 'id': 154929223}
# 25182 2013-01-14 01:22:13    {'screen_name': 'youngertimes', 'id': 30182523}
#
#       contains
# 25178      NaN
# 25179      NaN
# 25180      NaN
# 25181      NaN
# 25182      NaN
# best television series - drama [(('Bill', 'Clinton'), 210), (('Kristen', 'Wiig'), 64), (('Will', 'Ferrell'), 57), (('Robert', 'Pattinson'), 36), (('Steven', 'Spielberg'), 25)]
# best performance by an actress in a television series - drama
#                        id                                               text  \
# 97163  290648825327144960  Claire Danes - Best Performance by an Actress ...
# 97244  290648848722952192  Claire Danes of "Homeland" wins Best Performan...
#
#              timestamp_ms                                               user  \
# 97163 2013-01-14 02:37:34  {'screen_name': 'golden_globes', 'id': 105991003}
# 97244 2013-01-14 02:37:40  {'screen_name': 'OnTheRedCarpet', 'id': 17497090}
#
#       contains
# 97163     True
# 97244     True
# 197
#                        id                                               text  \
# 97048  290648818570108928  RT @thecollegecrush: Lea Michele is soooo tan....
# 97049  290648818561716224  RT @goldenglobes: Best Foreign Film - Amour (A...
# 97050  290648818502991872  What the hell Lea Michele stop tanning! #golde...
# 97051  290648818494623745  RT @eliroth: Quentin's #GoldenGlobes speech ma...
# 97052  290648818414923778  Lea Michele spent a little too long in the spr...
#
#              timestamp_ms                                               user  \
# 97048 2013-01-14 02:37:32    {'screen_name': '_ShelbyJean_', 'id': 22226099}
# 97049 2013-01-14 02:37:32       {'screen_name': 'iamfercs', 'id': 114637016}
# 97050 2013-01-14 02:37:32         {'screen_name': 'anacili', 'id': 38254914}
# 97051 2013-01-14 02:37:32  {'screen_name': 'stopthatcandace', 'id': 27241...
# 97052 2013-01-14 02:37:32  {'screen_name': 'ChristinaJValle', 'id': 29368...
#
#       contains
# 97048      NaN
# 97049      NaN
# 97050      NaN
# 97051      NaN
# 97052      NaN
# best performance by an actress in a television series - drama [(('Nathan', 'Fillion'), 1), (('Lea', 'Michele'), 1), (('Tommy', 'Lee'), 1), (('Lee', 'Jones'), 1)]
# best performance by an actor in a television series - drama
#                        id                                               text  \
# 32768  290632593613934592  Best Performance by an Actor in a Television S...
# 34591  290633129016819713  Best Performance by an Actor in a Television S...
#
#              timestamp_ms                                              user  \
# 32768 2013-01-14 01:33:04  {'screen_name': 'Layar_Tancep', 'id': 633875340}
# 34591 2013-01-14 01:35:12     {'screen_name': 'RominaBond', 'id': 40014872}
#
#       contains
# 32768     True
# 34591     True
# 2261
#                        id                                               text  \
# 32596  290632479071678465  Wanting to watch the globes but dating an Amer...
# 32597  290632479038140417               It's Harold and Maude! #GoldenGlobes
# 32598  290632479000371200  HFPA call me maybe to brad! Lol ;) x #GoldenGl...
# 32599  290632478870343680  “@PerezHilton: Bradley Cooper looks great in a...
# 32600  290632478857760768  Nice hair Halle Berry! You really pulled that ...
#
#              timestamp_ms                                               user  \
# 32596 2013-01-14 01:32:37      {'screen_name': 'CazzKirkyP', 'id': 47169132}
# 32597 2013-01-14 01:32:37         {'screen_name': 'Sarvady', 'id': 23245171}
# 32598 2013-01-14 01:32:37      {'screen_name': 'AriaKumar', 'id': 126368129}
# 32599 2013-01-14 01:32:37  {'screen_name': 'Stephanaaayyy', 'id': 969071394}
# 32600 2013-01-14 01:32:37   {'screen_name': 'kstembrevilla', 'id': 62243178}
#
#       contains
# 32596      NaN
# 32597      NaN
# 32598      NaN
# 32599      NaN
# 32600      NaN
# best performance by an actor in a television series - drama [(('Salma', 'Hayek'), 2), (('Damian', 'Lewis'), 2), (('Robert', 'Pattinson'), 1), (('Amanda', 'Seyfried'), 1), (('Sofia', 'Vergara'), 1)]
# best television series - comedy or musical
#                        id                                               text  \
# 89373  290646379905290240  RT @goldenglobes: Best Actor in a Television S...
# 89391  290646379154509824  RT @goldenglobes: Best Actor in a Television S...
# 89434  290646377585856513  RT @goldenglobes: Best Actor in a Television S...
# 89471  290646396636368896  RT @goldenglobes: Best Actor in a Television S...
# 89513  290646395059318784  RT @goldenglobes: Best Actor in a Television S...
#
#              timestamp_ms                                               user  \
# 89373 2013-01-14 02:27:51    {'screen_name': 'bookishbelle', 'id': 23328883}
# 89391 2013-01-14 02:27:51  {'screen_name': 'lacasamagacine', 'id': 67180612}
# 89434 2013-01-14 02:27:51  {'screen_name': 'ourmoviereview', 'id': 108389...
# 89471 2013-01-14 02:27:55     {'screen_name': 'celsoibarra', 'id': 38360857}
# 89513 2013-01-14 02:27:55  {'screen_name': 'jmorenoportillo', 'id': 65540...
#
#       contains
# 89373     True
# 89391     True
# 89434     True
# 89471     True
# 89513     True
# 50378
#                        id                                               text  \
# 93417  290647535062753280  @Hansprincipe's tweets about the #GoldenGlobes...
# 93418  290647534844669952  Esos comentaristas pobres que hablan de los #g...
# 93419  290647534823694336  RT @EmWatson: O and Maggie! Maggie Smith won!!...
# 93420  290647534748188672  RT @hannahjso: That reference to Genovia reall...
# 93421  290647534643326976  RT @AnneFulenwider: Love that #annehathaway in...
#
#              timestamp_ms                                               user  \
# 93417 2013-01-14 02:32:26         {'screen_name': 'sofiakz', 'id': 68249217}
# 93418 2013-01-14 02:32:26        {'screen_name': 'teeblank', 'id': 30485526}
# 93419 2013-01-14 02:32:26       {'screen_name': 'Kiblerla', 'id': 846334824}
# 93420 2013-01-14 02:32:26  {'screen_name': 'CarolinaNauert', 'id': 416831...
# 93421 2013-01-14 02:32:26     {'screen_name': 'FlorSoteloC', 'id': 88557800}
#
#       contains
# 93417      NaN
# 93418      NaN
# 93419      NaN
# 93420      NaN
# 93421      NaN
# best television series - comedy or musical [(('Alyssaeinman', 'KevalBaxi'), 97), (('Will', 'Ferrell'), 83), (('Kristen', 'Wiig'), 83), (('Wiig', 'Funny'), 77), (('Funny', 'Presenting'), 76)]
# best performance by an actress in a television series - comedy or musical
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-41-b4ec6c2a94e2> in <module>
# ----> 1 getPresenters()
#
# <ipython-input-40-b79cf2bd5de0> in getPresenters()
#       4     for award in OFFICIAL_AWARDS_1315:
#       5         print(award)
# ----> 6         df = getTweetsForAward(category_dict, award)
#       7         print(df[:5])
#       8         df = getTweetsInTimeRange(df)
#
# <ipython-input-38-280e1036c893> in getTweetsForAward(category_dict, award)
#       5         if all(term in tweet.lower() for term in category_dict[award]):
#       6             l.append(data.loc[data.text == tweet])
# ----> 7     df = pd.concat(l)
#       8     return df
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/core/reshape/concat.py in concat(objs, axis, join, join_axes, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     226                        keys=keys, levels=levels, names=names,
#     227                        verify_integrity=verify_integrity,
# --> 228                        copy=copy, sort=sort)
#     229     return op.get_result()
#     230
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/core/reshape/concat.py in __init__(self, objs, axis, join, join_axes, keys, levels, names, ignore_index, verify_integrity, copy, sort)
#     260
#     261         if len(objs) == 0:
# --> 262             raise ValueError('No objects to concatenate')
#     263
#     264         if keys is None:
#
# ValueError: No objects to concatenate
